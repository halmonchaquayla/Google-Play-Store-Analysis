# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
pd.set_option('display.max_columns', 50)

# %%
df = pd.read_csv('data/app_info.csv')

# %%
df.head(20)
# Out:
#                           title  \
# 0                     Jelly Dye
# 1                   Solar Smash
# 2                    Comics Bob
# 3   Draw Puzzle - Draw one part
# 4                      Among Us
# 5                        Roblox
# 6                   High Heels!
# 7              Project Makeover
# 8                 Join Clash 3D
# 9                Pencil Rush 3D
# 10                 Girl Genius!
# 11                Magic Tiles 3
# 12            Water Sort Puzzle
# 13                  Giant Rush!
# 14                 Chat Master!
# 15       DOP 2: Delete One Part
# 16               Subway Surfers
# 17                Sculpt people
# 18         Tiles Hop: EDM Rush!
# 19                  Stacky Dash
#
#                                           description  \
# 0   Inject Color Dyes into Jellies. Enjoy the Perf...
# 1   Solar Smash is a planet destruction simulator,...
# 2   🗿 <b> Comics Bob – Mind-bending puzzles and cl...
# ...

# %%
df.isna().sum()
# Out:
# title                        0
# description                  0
# descriptionHTML              0
# summary                      0
# summaryHTML                  0
# installs                     0
# minInstalls                  0
# score                        0
# ratings                      0
# reviews                      0
# histogram                    0
# price                        0
# free                         0
# currency                     0
# sale                         0
# saleTime                    20
# originalPrice               20
# saleText                    20
# offersIAP                    0
# inAppProductPrice            4
# size                         0
# androidVersion               0
# androidVersionText           0
# developer                    0
# developerId                  0
# developerEmail               0
# developerWebsite             0
# developerAddress             0
# privacyPolicy                1
# developerInternalID          0
# ...

# %%
df['inAppProductPrice'].value_counts(normalize=True)
# Out:
# $0.99 - $19.99 per item     0.1250
# $0.99 - $99.99 per item     0.1250
# $2.99 - $4.99 per item      0.1250
# $2.99 per item              0.1250
# $0.99 - $4.99 per item      0.0625
# $0.49 - $199.99 per item    0.0625
# $0.99 per item              0.0625
# $1.99 per item              0.0625
# $2.49 per item              0.0625
# $0.99 - $2.99 per item      0.0625
# $0.99 - $10.99 per item     0.0625
# $2.99 - $8.99 per item      0.0625
# Name: inAppProductPrice, dtype: float64
