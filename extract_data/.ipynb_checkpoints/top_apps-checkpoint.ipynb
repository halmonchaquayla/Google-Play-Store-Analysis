# %%
import json #google play returns list of json
import pandas as pd #for creating a dataframe
from tqdm import tqdm #shows progress meter

# %%
# help highlights some of the json results
from pygments import highlight
from pygments.lexers import JsonLexer
from pygments.formatters import TerminalFormatter

# %%
from google_play_scraper import Sort, reviews, app #provides APIs to easily crawl the Google Play Store

# %%
app_packages = [
    'com.hbo.hbonow', 'com.tubitv', 'com.zhiliaoapp.musically', 'com.squareup.cash',
 'com.google.android.apps.nbu.paisa.user', 'com.disney.disneyplus', 'com.google.android.play.games',
 'com.shopify.arrive', 'us.zoom.videomeetings', 'com.paypal.android.p2pmobile', 'com.dd.doordash', 
 'com.instagram.android', 'com.whatsapp', 'com.snapchat.android', 'com.peacocktv.peacockandroid', 
 'com.venmo', 'com.contextlogic.wish', 'com.facebook.orca', 'com.walmart.android', 'org.telegram.messenger',
 'com.spotify.music', 'com.hulu.plus', 'com.discovery.discoveryplus.mobile', 'com.discord', 
 'com.univision.prendetv', 'com.netflix.mediaclient', 'com.teacapps.barcodescanner', 'com.americasbestpics', 
 'com.doordash.driverapp', 'com.amazon.avod.thirdpartyclient', 'com.amazon.mShop.android.shopping',
 'com.lemon.lvoverseas', 'com.ubercab', 'com.bamnetworks.mobile.android.gameday.atbat',
 'com.zzkko', 'com.facebook.katana', 'com.cleanteam.oneboost', 'com.particlenews.newsbreak', 
 'com.dominospizza', 'gov.irs', 'me.lyft.android', 'com.pinterest', 'com.roku.remote', 'com.google.android.apps.meetings',
 'co.mona.android', 'com.audible.application', 'com.ebay.mobile', 'video.like', 'com.adobe.reader', 
 'com.reddit.frontpage', 'com.vicman.toonmeapp', 'com.cleanteam.oneboost', 'cn.danatech.xingseus', 
 'com.offerup', 'com.ubercab.eats', 'com.particlenews.newsbreak', 'com.twitter.android',
 'com.fridaynight.funkinmodroblx', 'com.google.android.apps.chromecast.app', 'sg.bigo.live', 
 'com.grubhub.android', 'tv.twitch.android.app', 'com.nike.omega', 'com.microsoft.teams', 
 'com.onedebit.chime', 'com.ebay.mobile', 'video.reface.app', 'com.picsart.studio', 'com.bestbuy.android',
 'com.apple.movetoios', 'com.tmobile.tuesdays', 'com.life360.android.safetymapd', 'com.zillow.android.zillowmap', 
 'com.google.android.apps.meetings', 'com.Funimation.FunimationNow', 'com.google.android.apps.authenticator2', 
 'com.poshmark.app', 'com.pandora.android', 'com.coinbase.android', 'kjv.bible.kingjamesbible', 
 'com.google.android.apps.translate', 'com.vrbo.android', 'com.yelp.android', 'com.google.android.apps.youtube.music', 
 'com.booking', 'com.usablenet.mobile.walgreen', 'com.huanliao.tiya', 'com.experian.android',
 'com.google.android.apps.youtube.kids', 'com.myklarnamobile', 'com.womboai.wombo', 'com.fiton.android',
 'com.alibaba.intl.android.apps.poseidon', 'com.duolingo', 'com.cbs.tve', 'com.ten.mtodplay',
 'com.afterpaymobile.us', 'com.canva.editor', 'com.xfinity.digitalhome',
 'videoeditor.videorecorder.screenrecorder', 'com.amazon.dee.app', 'co.vulcanlabs.rokuremote',
 'com.hopper.mountainview.play', 'com.airydress.android', 'com.hp.printercontrol', 'com.etsy.android',
 'tv.pluto.android', 'com.dobroapps.anti.stress', 'com.creditkarma.mobile', 'wp.wattpad',
 'com.yum.pizzahut', 'com.subway.mobile.subwayapp03', 'com.fetchrewards.fetchrewards.hop',
 'com.thehomedepot', 'com.sweet.dream.client', 'com.konylabs.capitalone', 'com.cbs.app',
 'org.craigslist.CraigslistMobile', 'com.vidangel.thechosen', 'com.google.android.apps.adm',
 'com.opera.app.news', 'com.starbucks.mobilecard', 'com.symantec.securewifi', 'com.wayfair.wayfair',
 'com.instacart.client', 'com.target.ui', 'net.zedge.android', 'com.google.earth', 'com.kms.free', 
 'com.tophatter', 'com.ringapp', 'com.mercariapp.mercari', 'com.robinhood.android', 'com.lowes.android',
 'com.azure.authenticator', 'jp.ne.ibis.ibispaintx.app', 'com.root.clean.boost.explorer.filemanager', 
 'com.instabridge.android', 'com.appblockgames.freecraftexploration', 'mobi.abcmouse.academy_goo', 
 'com.outfit7.talkingnewsfree', 'com.chickfila.cfaflagship', 'com.tinder', 'com.mistplay.mistplay',
 'com.google.android.apps.subscriptions.red', 'com.clearchannel.iheartradio.controller',
 'com.sirius', 'org.thoughtcrime.securesms', 'com.goodrx', 'com.usps', 'com.media44seven.seventyfivehard',
 'com.planetfitness', 'com.app.green.vpn', 'com.bitstrips.imoji', 'com.avast.android.mobilesecurity',
 'com.amazon.mp3', 'qrcodereader.barcodescanner.scan.qrscanner', 'com.instabridge.android',
 'screenrecorder.recorder.editor', 'com.flatfish.cal.privacy', 'com.fast.cleaner.cpu.cool.powerful',
 'com.soundcloud.android', 'com.upside.consumer.android', 'com.airbnb.android', 'com.simejikeyboard', 
 'com.chase.sig.android', 'com.groupon', 'com.oculus.twilight', 'com.move.realtor', 'com.shazam.android', 
 'com.realbyteapps.moneymanagerfree', 'com.indeed.android.jobsearch', 'us.current.android', 
 'com.usps.myusps_mobile_app_android', 'com.yahoo.mobile.client.android.mail', 'com.microsoft.office.outlook',
 'com.viki.android', 'online.moneywell.app', 'com.scee.psxandroid', 'com.dramaton.slime', 
 'com.free.fast.proxy.lion.vpn', 'com.expedia.bookings', 'com.propel.ebenefits', 'com.affinity.rewarded_play',
 'com.camerasideas.instashot', 'com.microsoft.xboxone.smartglass', 'com.opera.browser', 
 'com.phonevalley.progressive', 'com.chewy.android', 'com.nexstreaming.app.kinemasterfree', 
 'com.callapp.contacts', 'com.lyrebirdstudio.cartoon', 'com.audiomack', 'com.mov.movcy', 
 'com.tdr3.hs.android', 'smartwatchstudios.app.gears3navigation', 'com.scannerradio_pro',
 'org.prowl.torque', 'xyz.mreprogramming.ultimateghostdetector', 'com.chillseekers.Necrophonic',
 'com.imageline.FLM', 'abdelrahman.wifianalyzerpremium', 'com.tocaboca.tocahospital',
 'com.teslacoilsw.launcher.prime', 'org.twisevictory.apps', 'com.scopely.headshot', 'net.zedge.android', 
 'com.soundcloud.android', 'com.miniclip.eightballpool', 'com.microblink.photomath', 
 'com.instagram.layout', 'com.supercell.clashofclans', 'com.emoji.coolkeyboard', 
 'com.yahoo.mobile.client.android.mail', 'com.slots.best.android',
 'com.google.android.play.games', 'com.zhiliaoapp.musically', 
 'com.classdojo.android', 'com.contextlogic.wish', 'com.draftkings.dknativermgGP', 'com.twitter.android',
 'com.ubercab', 'com.google.android.apps.docs.editors.docs', 'com.offerup', 
 'eu.bandainamcoent.pacman256', 'com.google.android.apps.translate', 'com.miniclip.agar.io',
 'com.waze', 'com.sxiaoao.meirenyu.english', 'com.bethsoft.falloutshelter',
 'com.clearchannel.iheartradio.controller', 'com.rubyseven.rsvideopoker', 'com.mobilityware.solitaire',
 'com.ikeyboard.emoji.emojione', 'com.invictus.impossiball', 'com.fanduel.android.self',
 'com.microsoft.office.outlook', 'com.nfl.fantasy.core.android',
 'com.sec.android.easyMover', 'com.igg.bzbee.deckheroes', 'com.imangi.templerun2', 'org.peakfinder.area.alps',
 'com.fivemobile.thescore',
 'com.nordcurrent.canteenhd', 'se.maginteractive.wordbrain', 'com.walmart.android', 'com.kathleenOswald.solitaireGooglePlay',
 'com.machinezone.gow', 'com.ebay.mobile', 'com.fingersoft.hillclimb', 
 'com.gameloft.android.ANMP.GloftDMHM', 'de.twokit.screen.mirroring.app.roku.pro', 'pro.cryptotab.android', 
 'com.tocaboca.tocaneighborhood', 'com.maxmpz.audioplayer.unlock', 'com.velo.vpn.pro', 'com.tocaboca.tocavacation', 
 'psplay.grill.com', 'com.yahoo.mobile.client.android.fantasyfootball', 'com.wakdev.nfctools.pro', 
 'de.twokit.screen.mirroring.app.pro', 'net.dinglisch.android.taskerm', 'com.filmic.filmicpro', 
 'com.tocaboca.tocaoffice', 'com.dev47apps.droidcamx', 'com.advasoft.touchretouch',
 'com.tocaboca.tocaschool', 'com.simplemobiletools.gallery.pro', 'com.star.ce5contact',
 'com.tocaboca.tocalab', 'de.twokit.video.tv.cast.browser.roku.pro', 'de.twokit.video.tv.cast.browser.firetv.pro',
 'de.twokit.video.tv.cast.browser.ultimate', 'com.matthewlberg.j23', 'com.digipom.easyvoicerecorder.pro',
 'org.kustom.widget.pro', 'com.t11.skyview', 'com.littleleaguerulebook', 'com.hydrix.laurene',
 'com.foxfi.key', 'com.tocaboca.tocapets', 'com.tocaboca.tocastable', 'com.alexvas.dvr.pro',
 'com.tocaboca.tocapetdoctor', 'ch.threema.app', 'mymacros.com.mymacros', 'com.tinyapps.videoplayer',
 'com.mxtech.videoplayer.pro', 'com.tocaboca.tocalifefarm', 'com.tocaboca.tocaafterschool',
 'com.itcentar.mobiledevelopment.ctm.easter', 'com.tocaboca.tocatown', 'com.monashuniversity.fodmap', 
 'com.tocaboca.tocahairsalon3', 'com.panda.gamepad', 'cc.fuze.forks', 'com.wilysis.cellinfo',
 'com.zombodroid.MemeGeneratorFullGplay', 'com.photopills.android.photopills', 'com.AlfaOBD.AlfaOBD',
 'de.twokit.screen.mirroring.app.firetv.pro', 'com.gypsyguide.tours.gypsyguidetour.mi.rh',
 'uk.co.randomvector.outline', 'com.wolfram.android.alpha', 'com.riteshsahu.SMSBackupRestorePro',
 'com.tinyapps.phonelaucherapps', 'com.g19mobile.gameboosterplus', 'dk.mymovies.mymovies3forandroidpro', 
 'com.astech.forscanlite', 'idm.internet.download.manager.plus', 'webappvn.com.mythemeProVersion',
 'com.simplemobiletools.calendar.pro', 'com.sonosaurus.tonalenergytuner', 'com.smartwatchstudios.app.camera', 
 'com.jndapp.cartoon.crayon.iconpack', 'com.alphaone.glowline.iconpack', 'com.borisov.strelokpro',
 'net.liveatc.liveatc_app', 'jp.ne.ibis.ibispaint.app', 'com.teamspeak.ts3client', 'com.kairos.duet', 
 'com.active.aps.c25k', 'com.autolauncher.motorcar', 'com.jndapp.line.neon.iconpack', 'ryan.ccw',
 'com.tocaboca.tocacity', 'com.ithersta.stardewvalleyplanner', 'com.forcereadiness.pdgpromote',
 'com.utorrent.client.pro', 'com.ambientdesign.artrage.playstore', 'org.fortheloss.sticknodespro',
 'com.flyersoft.moonreaderp', 'com.basevelocity.radarscope', 'com.tvremoteprm.remoterok.tv',
 'com.kodarkooperativet.blackplayerex', 'com.aryuthere.visionplus', 'com.darkopd.iconpack',
 'com.fldesign.black.pie.iconpack', 'org.kurzgesagt.app.Universe', 'com.pdp.deviceowner',
 'com.SpottedGhosts.SpiritTalker', 'com.tocaboca.tocamini', 'com.fluidtouch.noteshelf2',
 'com.dmacpro91.jb4_mobile', 'com.northamericanpharmacal.btd', 'com.extreamsd.usbaudioplayerpro', 
 'com.ventismedia.android.mediamonkeypro', 'com.jndapp.line.x.iconpack', 'com.intermedia.hd.camera.pro',
 'org.usdebtclock', 'com.circle.iconcircle.omegacircle.samplecircle', 'com.massimobiolcati.irealb',
 'com.elf.koalasampler', 'com.simplescan.scanner.pro', 'org.kustom.wallpaper.pro',
 'eu.thedarken.sdm.unlocker', 'com.cateater.stopmotionstudiopro', 'com.tocaboca.tocakitchensushi',
 'wordswag.stylishfont.gwyn', 'cs14.pixelperfect.iconpack.novadark', 'com.flatearthsun',
 'com.defianttech.diskdiggerpro', 'com.tools.netgel.netxpro', 'com.ndemiccreations.scenariocreator', 
 'com.Relmtech.RemotePaid', 'OCTech.Mobile.Applications.TouchScan', 'com.delphicoder.flud.paid',
 'hardman.bret.quickbend.pro', 'com.gammonapps.android.straightlinenavigator', 'com.rarevision.vhscamcorder',
 'org.readera.premium', 'gb.xxy.hr', 'com.acmeaom.android.myradarpro', 'com.chanel.weather.forecast.accu.pro',
 'com.aihamfell.techteleprompter', 'pro.gif.videotogif.gifeditor.gifmaker', 'com.pnn.obdcardoctor_full',
 'com.urbandroid.sleep.full.key', 'com.simplemobiletools.thankyou', 'org.asccp.app2019',
 'sheerkwgt.kustom.pack', 'net.techet.netanalyzer.an', 'com.sasanian.hondata_mobile', 'com.blaqmoji',
 'com.vs.veinseek', 'com.hantor.CozyMagPlus', 'slide.watchFrenzy.premium', 'com.vitotechnology.StarWalk2',
 'com.exelerus.apps.ghostradio', 'com.tinyapps.photowatchpro', 'com.kkppstudios.dreamvoices',
 'com.nynix.knots3d', 'com.cubemg.davincieye', 'org.hamstudy.mobile', 'com.tmsoft.whitenoise.full',
 'com.draco.ladb', 'com.tocaboca.tocanature', 'com.dmholdings.AudysseyMultEq', 'minar.wmwatch.pipboy',
 'color.line.dark', 'hiddencamdetector.futureapps.com.hiddencamdetectoradsfree', 'com.nstudio.weatherhere',
 'com.mixplorer.silver', 'com.appstar.callrecorderpro', 'com.atlogis.northamerica', 'pixbit.prime',
 'com.tocaboca.tocabuild', 'arproductions.andrew.worklogkey', 'org.oftn.rainpaper', 'com.myscript.nebo', 
 'com.progdigy.cdisplay', 'com.gypsyguide.tours.gypsyguidetour.mi.fit', 'com.freecloud.StackTheStates',
 'com.animatedknots.knots', 'com.rhmsoft.pulsar.pro', 'com.natewren.lines', 'com.freecloud.StackTheStates', 
 'com.antispycell', 'nl.ijsdesign.huedisco', 'com.a0soft.gphone.app2sd.pro', 'org.pbskids.dtigplayhomeuni', 
 'com.shenyaocn.android.usbcamerapro', 'com.darxide.android.crystalguide', 'com.stardewsaveeditor',
 'com.bubblesoft.android.bubbleupnp.unlocker', 'com.veamstudios.siteauditpro', 'com.newtek.ndi.hxcam',    
 'com.touchbyte.photosync.fullfeatured', 'org.golfclash.notebook', 'com.mreprogramming.ultimateemfdetectorpro',
 'com.klinker.android.twitter_l', 'supreme.icon.pack.ddt', 'com.flolivingalisavitti.myfloapp', 
 'com.incorporateapps.fakegps_route', 'air.com.rosettastone.mobile.CoursePlayer', 'com.ecomi.veve', 
 'com.appdashboard.android5e3c2848095cf', 'com.braksoftware.HumanJapanese', 'com.matchtech.cafe',
 'com.jaytronix.multitracker', 'com.magicfluids', 'com.intuit.turbotax.mobile', 'com.topps.bunt',
 'com.taggedapp', 'com.myyearbook.m', 'com.sgiggle.production', 'com.crunchyroll.crunchyroid',
 'com.qidian.Int.reader', 'com.dreame.reader', 'com.myfitnesspal.android', 'com.udemy.android',
 'com.naver.linewebtoon', 'com.bumble.app', 'co.hinge.app', 'com.google.android.apps.docs',
 'com.bydeluxe.d3.android.program.starz', 'com.dropbox.android', 'com.read.goodnovel', 
 'com.calm.android', 'com.imvu.mobilecordova', 'com.grindrapp.android', 'com.onepeloton.callisto', 
 'com.fitbit.FitbitMobile', 'com.espn.score_center', 'com.contentsfirst.tappytoon', 'io.comico',
 'com.microsoft.skydrive', 'com.udates', 'onxmaps.hunt', 'com.viacom.betplus', 'com.enflick.android.TextNow',
 'com.getsomeheadspace.android', 'video.chat.joi', 'com.skout.android', 'com.mobiledatalabs.mileiq',
 'com.alltrails.alltrails', 'com.tapastic', 'com.cyberstep.toreba.android', 'com.tangerine.live.cake',
 'com.cricut.designspace', 'air.com.myheritage.mobile', 'com.robokiller.app', 'com.nbaimd.gametime.nba2011',
 'com.appspartner.iflirts', 'com.nordvpn.android', 'com.affinityapps.blk', 'com.lastpass.lpandroid',
 'com.intuit.qbse', 'com.noahclient', 'com.europe.live', 'com.intsig.camscanner', 'com.dazn', 
 'com.nytimes.android', 'com.scorp.who', 'com.ancestry.android.apps.ancestry', 'com.fun.share',
 'com.lionsgate.pantaya', 'com.babbel.mobile.android.en', 'com.showtime.standalone', 'com.symantec.mobilesecurity', 
 'com.fitnow.loseit', 'com.ashleymadison.mobile', 'com.strava', 'com.newellmediallc.live.coco',
 'com.ultimateguitar.tabs', 'com.smule.singandroid', 'com.gc.android', 'younow.live', 'com.wonder',
 'com.guochao.faceshow', 'com.udemy.android', 'com.weieyu.yalla', 'io.faceapp', 'com.lezhin.comics', 
 'com.hily.app', 'com.yy.hiyo', 'com.weightwatchers.mobile', 'co.thefabulous.app', 'com.topps.slam', 
 'com.kii.safe', 'com.walkfit.weightloss.steptracker.pedometer', 'com.dobai.kis', 'com.sixdays.truckerpath', 
 'tunein.player', 'com.machipopo.media17', 'com.formulaone.production', 'com.yalla.yallalite',
 'com.microsoft.office.word', 'com.okcupid.okcupid', 'de.fastic.app', 'com.coffeemeetsbagel',
 'com.starmakerinteractive.starmaker', 'com.adhoclabs.burner', 'com.takimi.android', 'co.clover.clover', 
 'com.affinityapps.chispa', 'com.fortunescope', 'com.mico', 'com.gopro.smarty',
 'com.stardust.kissreader', 'com.aadhk.woinvoice', 'com.intuit.quickbooks', 'com.zhangyue.read', 
 'com.nick.noggin', 'com.groundspeak.geocaching.intro', 'com.fixdapp.two', 'write.read.story.webnovel.book.anystories',
 'com.asiainno.uplive', 'im.kumu.ph', 'com.sideline.phone.number', 'ai.replika.app', 'net.manta.comic',
 'com.cyberlink.powerdirector.DRA140225_01', 'com.hualai', 'com.infostream.seekingarrangement',
 'co.happybits.marcopolo', 'ly.omegle.android', 'com.wombatapps.carbmanager', 'com.dorna.officialmotogp',
 'com.gen.workoutme', 'com.weather.Weather', 'com.antivirus', 'com.exutech.chacha', 'com.bagatrix.mathway.android',
 'com.hkfuliao.chamet', 'com.lightricks.facetune.free', 'com.wb.goog.dcuniverse', 'com.grammarly.android.keyboard',
 'org.iggymedia.periodtracker', 'com.zodiactouch', 'com.callpod.android_apps.keeper', 'com.yanka.mc', 
 'com.badoo.mobile', 'com.lookout', 'com.textmeinc.textme', 'com.discovery.discoveryplus.androidtv',
 'com.yiwuzhibo', 'police.scanner.radio.broadcastify.citizen', 'com.quvideo.xiaoying', 
 'com.voicechat.live.group', 'net.novelfox.foxnovel', 'video.chat.peachat', 'pdf.tap.scanner', 
 'com.zhangyun.bravo', 'com.ratelekom.findnow', 'com.getepic.Epic', 'com.matchtech.solive',
 'com.thetileapp.tile', 'com.dramafever.shudder', 'com.kaylaitsines.sweatwithkayla', 
 'com.zhangyue.read.storytube', 'com.evernote', 'com.theepochtimes.news', 'com.lightricks.pixaloop',
 'com.fng.foxnation', 'com.fishbrain.app', 'com.adobe.lrmobile', 'com.psafe.msuite', 'mobi.mangatoon.comics.aphone',
'com.yelp.android',  'com.songsterr', 'cz.cfc.androidgp.sightwords', 'com.tocaboca.tocalab',
 'co.smartwatchface.watch.face.ranger.military', 'com.littleinferno.google', 
 'pl.idreams.pottery', 'com.imageline.FLM', 'com.bowengames.pullingusa', 'com.Relmtech.RemotePaid',
 'stericson.busybox.donate', 'com.paradoxplaza.kopp2', 'com.rcreations.WebCamViewerPaid',  
 'com.ui.LapseItPro', 'com.buak.link2sdplus', 'com.leosfortune', 'pl.vipek.camera2', 
 'com.jrtstudio.AnotherMusicPlayer.Unlocker', 'com.flyersoft.moonreaderp', 'com.corytrese.games.startraderselite', 
 'edu.terc.zoombinis', 'com.tocaboca.tocatown', 'com.magiccubesgames.VBC', 'com.inxile.BardTale',
 'com.agaming.zonaprojectx', 'com.t2kgames.civrev2', 'com.moletag.galaxy.s4.remote', 
 'com.glutenfreegames.catsimulator', 'air.com.starfall.ltr', 'com.bowengames.farmingusa',
 'com.vidstitch.pro', 'com.vl.infotrax.doterra', 'com.squareenixmontreal.hitmansniperandroid', 
 'joybits.doodlegod_hd', 'com.stmp.minimalface', 'com.doubleTwist.androidPlayerProKey',  
 'com.intsig.BizCardReader', 'com.mxtech.videoplayer.pro', 'org.ppsspp.ppssppgold',
 'com.bubblesoft.android.bubbleupnp.unlocker', 'air.com.sfbgames.HauntTheHouseTerrortown',
 'net.liveatc.liveatc_app', 'com.watch.richface.iron', 'com.disney.castleofillusion_goo', 
 'com.acmeaom.android.myradarpro', 'com.aitype.android.p', 'com.anishu.homebudget.full',
 'com.foursakenmedia.blockfortress', 'com.eightyeightgames.tenmillion', 'com.khg.doorkickers', 
 'com.magicnotion.kpmatchmaker', 'com.possiblegames.edge', 'com.hydrix.laurene',
 'com.andrewshu.android.redditdonation', 'com.lp.aeronautical.android', 'com.giantssoftware.fs14',
 'com.subatomicstudios', 'com.utorrent.client.pro', 'com.dotemu.neogeo.mslug3',  
 'air.net.machinarium.Machinarium.GP', 'emoji.keyboard.emoticonkeyboard.premium',
 'com.playcreek.DeathWorm', 'com.foursakenmedia.heroesandcastles2', 
 'com.GigaBitGames.Ultra4OffroadRacing', 'cc.fuze.forks', 'com.NamcoNetworks.MsPacMan',
 'com.superimposeapp.superimposeapp', 'com.basevelocity.radarscope', 'org.withouthat.acalendarplus', 
 'com.niftybytes.rhonna_android', 'com.marinetraffic.android', 'com.lightbot.lightbot',  
 'com.mobisystems.editor.office_registered', 'com.smartandroidapps.equalizer.unlock',   
 'com.incrementalinc.idleevolution', 'com.seacloud.bc', 'com.glutenfreegames.dogsimulator',
 'com.cloudmosa.puffin', 'com.aryuthere.visionplus', 'uk.co.nickfines.RealCalcPlus', 
 'com.tt2kgames.xcomew', 'com.jrummy.liberty.toolboxpro', 'age.of.civilizations.jakowski', 
 'com.DefiantDev.SkiSafari', 'com.starfall.StarfallABCs', 'com.shinycore.picsaypro', 
 'com.joko.minimapro', 'com.daysofwonder.tt.android', 'com.choiceofgames.versus1',  
 'com.oasisfeng.greenify.pro', 'com.square_enix.android_googleplay.FFVI', 'com.thaphlash.watch.navi', 
 'com.mtvn.SBmoviegame', 'com.atlogis.northamerica', 'org.prx.talbot', 'com.square_enix.android_googleplay.dq5', 
 'com.dlink.mydlinkplus', 'net.zhuoweizhang.pocketinveditor.pro', 'ca.rebootsramblings.musicboss', 'com.firelitstudios.monogram',
 'org.pbskids.dtgrrificfeelings', 'com.androidvilla.addwatermark', 'com.wdtinc.android.stormshield',
 'com.tocaboca.tocacity', 'com.smarterdroid.wififiletransferpro',
 'com.zombodroid.MemeGeneratorFullGplay', 'com.fermentergames.david', 'com.mobisystems.fonts',
 'com.msherwin.gamestudiotycoon2', 'air.cz.cfc.androidgp.AbbyBasicSkills', 'com.mtvn.SBminigame',
 'com.paulart.go.launcherex.theme.pipboy3000', 'com.dustywallet.qseer', 
 'com.mstream.etpc', 'com.gamenauts.klo', 'com.etterstudio.pnp', 'com.twodboy.worldofgoofull', 
 'com.subatomicstudios.fieldrunners2', 'org.topia.app', 'com.omgpop.dstpaid', 'com.nll.screenrecorder.license', 
 'com.thup.lunchbox', 'com.vertumus.rewun', 'com.gameloft.android.ANMP.GloftM4HM', 
 'steelersradio.activities', 'com.t11.skyview', 'slide.cameraZoom', 'com.exelerus.apps.ghostradio', 
 'com.square_enix.android_googleplay.dq1_gp', 'com.easytech.wc3', 'com.magiccubegames.barcodeknight', 
 'com.androvidpro', 'com.jupiterapps.stopwatch', 'com.kevinbradford.games.barnyardgames', 
 'fr.anuman.HomeDesign3DClassic', 'com.extreamsd.aemobile', 'com.nll.acr.license',
 'radiotime.player', 'com.watch.richface.futuristic', 'com.kevinbradford.games.theguidescompendium', 
 'com.vicman.photolabpro', 'com.onelouder.baconreader.premium', 'org.dmfs.caldav.icloud', 'net.kairosoft.android.gamedev3en',
 'com.rageconsulting.android.lightflow', 'com.SmartBomb.AJJump', 'joybits.doodlegod', 'com.tmsoft.whitenoise.full',
 'com.desaxedstudios.bassboosterpro', 'com.glutenfreegames.dragonsimulator', 'fishnoodle.koipond',
 'com.perracolabs.cp', 'gogo3.ennavcore2', 'com.urbandroid.lux.donate', 'com.kevinbradford.games.secondgrade',
 'com.vectorunit.red', 'com.goldsteintech.android', 'com.hitcents.stickmanepic', 'com.rockstar.maxpayne',
 'com.nstudio.weatherhere', 'com.hiqrecorder.full', 'com.crescentmoongames.deergod', 'com.fenlander.ultimatevaluediary',
 'com.benchevoor.huepro', 'cs.example.studiomusic', 'kr.aboy.tools', 'com.mtvn.blazegoogleHD',
 'com.blueirissoftware.blueiris', 'com.criticalhitsoftware.scanner50', 'com.glutenfreegames.falconsimulator', 
 'com.homeysoft.nexususb.importer', 'com.tbig.playerpro', 'com.lvlup.buddhify', 'de.android.telnet2', 
 'agamz.logic', 'com.blueline.signalcheck', 'com.kodarkooperativet.blackplayerex', 'com.flux.theme.flux', 
 'com.onecwireless.mahjong.full', 'org.lukeallen.bomberfull', 'com.levelup.beautifulwidgets', 
 'com.rerware.android.MyBackupPro', 'org.kman.AquaMail.UnlockerMarket', 'fishnoodle.spacescapewallpaper', 
 'com.digipom.easyvoicerecorder.pro', 'com.watch.richface.digital', 'com.tribeplay.pandaicecream', 
 'com.bitcount.cleartune', 'com.appxy.tinyscan', 'paulscode.android.mupen64plus', 
 'ep3.littlekillerz.ringstrail', 'com.dvidearts.angelswordrpg', 'com.worms2armageddon.app', 
 'com.teragon.daynight.pro', 'com.brainium.solitaire', 'com.xvideostudio.videoeditorpro', 'com.icons.glim', 
 'com.tesseractmobile.solitairemulti', 'com.antispycell', 'com.mediocre.grannysmith', 'com.tocaboca.tocanature',
 'com.skyhealth.fitnessbuddyandroid', 'uk.co.aifactory.chess', 'com.zenstudios.MarvelPinball', 
 'com.intellijoy.android.phonics', 'com.drillbooknext.DBN_Reader', 'mindware.mindgamespro', 'com.vertumus.cryten', 'com.mylegalheat.legalheat', 'polis.app.callrecorder.pro', 
 'com.laurencedawson.reddit_sync.pro', 'com.owncloud.android', 'com.tocaboca.tocabuild', 'com.watch.richface.dynamic',
 'com.tecarta.KJVStrongs', 'com.pixtogram.wear.lookbehind',  'com.senri.da', 'com.tollsmart.leonidiogansen.tolls', 
 'com.singlecellsoftware.caustickey', 'com.snailgameusa.tp', 'com.murka.scatterslots',
 'com.flavionet.android.cinema.pro', 'com.flukedude.impossiblegamelevelpack', 'com.goseet.VidTrimPro',
 'com.dena.west.FFRK', 'com.tinyco.familyguy', 'com.gsn.android.casino', 'com.nobstudio.chengshuwan.prisonLifeRPG', 
 'org.mrchops.android.digihudpro', 'com.iugome.lilknights', 'sg.gumi.bravefrontier', 'nl.palatamedia.miner', 
 'air.com.bitrhymes.bingo', 'com.com2us.smon.normal.freefull.google.kr.android.common', 'com.supercell.hayday', 
 'com.zynga.FarmVille2CountryEscape', 'com.ea.game.simpsons4_na', 'com.williamsinteractive.goldfish', 
 'com.zynga.livepoker', 'com.funplus.familyfarm', 'com.d3p.mpq', 'com.glu.stardomkim', 'com.stac.empire.main', 
 'com.igg.clashoflords2', 'com.withbuddies.dice.free', 'com.ember.stainz', 'com.cervomedia.spw',
 'jp.gree.warofnationsbeta', 'air.com.goodgamestudios.empirefourkingdoms', 'com.plarium.stormfallrob', 'com.ludia.dragons', 
 'com.ucool.hero', 'com.playrix.township', 'com.droidhen.game.poker', 'com.ballytechnologies.quickhitslots', 
 'com.king.pyramidsolitairesaga', 'com.gameloft.android.ANMP.GloftDOHM', 'com.kabam.doamobile',
 'com.ea.BejeweledBlitz_na', 'com.ucool.herohd', 'com.zynga.empires2', 'com.nexonm.dominations.adk', 
 'com.kixeye.vegaconflict', 'com.pennypop.monsters.live', 'en.co.atm.unison', 'com.g5e.secretsociety', 
 'com.dragonplay.liveholdempro', 'com.catdaddy.cat22', 'com.gamevil.dragonblaze1.android.google.global.normal', 
 'com.funzio.crimecity', 'com.socialquantum.acityint', 'com.naturalmotion.csrracing', 'com.fivestargames.slots', 
 'com.slotsfavorites.slots.android', 'ata.squid.kaw', 'net.novelfox.novelcat', 'com.reportallusa.landglide', 'com.ea.game.maddenmobile15_row', 
 'com.withbuddies.yahtzee', 'com.prettysimple.criminalcaseandroid', 'com.hulu.plus', 'com.bigduckgames.flow',
 'com.google.earth', 'com.mobilemotion.dubsmash', 'com.gotv.nflgamecenter.us.lite',
 'com.bigfishgames.dungeonbossf2pgoogle', 'com.com2us.acefishing.normal.freefull.google.global.android.common',
 'com.lucktastic.scratch', 'com.hotheadgames.google.free.rawsniper', 'com.talkatone.android',
 'com.tinder', 'com.cyberlink.youcammakeup', 'com.oovoo', 'com.vg.californiastraight2compton',
 'com.sgn.pandapop.gp', 'com.slots.classicvegas', 'com.rovio.angrybirds', 'com.robtopx.geometryjumplite',
 'com.jb.emoji.gokeyboard', 'com.imo.android.imoim', 'com.sgiggle.production', 'com.shazam.android',
 'com.remind101', 'tunein.player', 'com.abtnprojects.ambatana', 'com.yodo1.crossyroad', 
 'com.zentertain.photoeditor', 'com.espn.score_center', 'com.ea.games.r3_na',
 'com.explorationbase.ExplorationLite', 'com.contextlogic.geek',
 'com.microsoft.office.word', 'com.outfit7.mytalkingtomfree', 'com.julian.wildhunter', 
 'com.indeed.android.jobsearch', 'com.google.android.youtube', 'com.halfbrick.fruitninjafree', 
 'com.adobe.reader', 'co.vine.android', 'com.king.farmheroessaga',
 'com.enflick.android.TextNow', 'com.badoo.mobile', 'com.zynga.wwf2.free', 'com.riffsy.FBMGIFApp',
 'com.zillow.android.zillowmap', 'com.devuni.flashlight', 'com.smule.singandroid', 'jp.naver.line.android',
 'com.etermax.preguntados.lite', 'org.mozilla.firefox', 'com.creditkarma.mobile', 'com.imangi.templerun',
 'com.groupme.android', 'com.droidhang.cd2', 'com.groupon', 'com.linkedin.android', 'emoji.keyboard.emoticonkeyboard',
 'com.pinger.textfree', 'com.rovio.baba', 'com.amazon.kindle', 'com.pof.android',
 'com.google.android.apps.classroom', 'com.chase.sig.android', 'com.antivirus', 'com.duolingo',
 'com.sirma.mobile.bible.android', 'com.google.android.apps.chromecast.app',
 'com.tumblr', 'com.aim.racing', 'com.thirdrock.fivemiles', 'com.gamma.scan', 'com.dropbox.android',
 'com.mercariapp.mercari', 'com.giphy.messenger', 'com.picsart.studio',
 'air.com.sgn.juicejam.gp', 'com.viber.voip', 'com.leftover.CoinDozer',
 'com.outfit7.mytalkingangelafree', 'com.gamecircus.prizeclaw2', 
 'com.episodeinteractive.android.catalog', 'com.emojifamily.emoji.keyboard.font.twitteremoji',
 'air.com.playtika.slotomania', 'com.blizzard.wtcg.hearthstone', 'com.whaleshark.retailmenot',
 'com.audible.application', 'com.herman.ringtone', 'com.playstudios.myvegas',
 'com.ea.games.simsfreeplay_na', 'com.gogii.textplus',
 'com.cbs.app', 'com.infonow.bofa', 'com.powerschool.portal', 'com.wf.wellsfargomobile',
 'com.madfingergames.unkilled', 'me.pou.app', 'com.quvideo.xiaoying',
 'air.com.sgn.cookiejam.gp', 'com.disney.thoughtbubbles_goo', 'com.acmeaom.android.myradar',
 'com.bandagames.mpuzzle.gp', 'com.fgol.HungrySharkEvolution', 'com.zentertain.photocollage', 
 'com.accuweather.android', 'com.outplayentertainment.aliencreeps', 'com.mcdonalds.app',
 'com.google.android.apps.docs.editors.sheets', 'media.music.musicplayer', 'com.musicplayer.music',
 'com.Interactive707.VoxelCraft', 'com.fitbit.FitbitMobile',  'com.android.chrome', 'com.subway.mobile.subwayapp03', 
 'com.google.android.calendar', 'com.threed.bowling', 'com.nbcuni.nbc', 'com.paypal.android.p2pmobile',
 'com.handmark.expressweather', 'com.nextradioapp.nextradio', 'com.thehomedepot.coloryourworld', 'com.konylabs.capitalone',
 'com.eliferun.music', 'com.bigfishgames.gummydropgoogle', 'com.jb.gosms', 'com.king.petrescuesaga', 
 'com.socialnmobile.dictapps.notepad.color.note', 'com.contextlogic.home', 
 'com.gotv.crackle.handset', 'com.glu.deerhunt2', 'com.cardinalblue.piccollage.google', 
 'com.teamlava.bubble', 'com.quizlet.quizletandroid', 'com.invictus.daytonarush', 'com.king.alphabettysaga',
 'com.etsy.android', 'tv.twitch.android.app', 'com.smule.magicpiano', 'me.lyft.android', 
 'net.peakgames.mobile.spades.android', 'com.supercell.boombeach', 'com.digitalchemy.calculator.freedecimal',
 'com.bigbluebubble.singingmonsters.full', 'com.torch.lampe.flashlight', 'com.myfitnesspal.android',
 'com.topfreegames.bikeracefreeworld', 'com.pinkpointer.wordsearch',
 'air.com.nbcuni.com.nbcsports.liveextra', 'me.dreamsky.leagueofstickman', 'com.facebook.pages.app', 
 'com.midasplayer.apps.bubblewitchsaga2', 'com.ddi', 'com.ludia.jurassicworld',
 'com.usablenet.mobile.walgreen', 'com.ogqcorp.bgh', 'com.apusapps.launcher',
 'mobi.ifunny', 'com.pinger.textfree.call', 'com.ViperGames.StickmanDismount',
 'com.ea.game.pvzfree_row', 'com.wb.goog.mkx', 'com.starbucks.mobilecard', 'com.myyearbook.m',
 'com.selfawaregames.acecasino', 'com.aws.android', 'com.roblox.client', 'com.microsoft.skydrive',
 'com.apalon.myclockfree', 'es.socialpoint.DragonCity',
 'com.venticake.retrica', 'org.videolan.vlc', 'com.microsoft.office.excel', 'com.emoji.ikeyboard', 
 'com.poshmark.app', 'com.playtika.wsop.gp', 'com.fusionprojects.edmodo', 'com.cbs.sports.fantasy', 
 'com.halfbrick.jetpackjoyride', 'com.junerking.archery', 'com.zindagigames.test',
 'gbis.gbandroid', 'com.igg.castleclash', 'com.amazon.windowshop', 'com.ViperGames.StickmanWarriors',
 'com.crowdstar.covetfashion', 'com.lookout.stagefrightdetector', 'com.appnoxious.heptagon',
 'com.contextlogic.cute', 'com.uken.BingoPop', 'com.magicjack', 'air.com.sgn.bookoflife.gp', 
 'net.peakgames.amy', 'com.gramgames.tenten', 'com.rhapsody', 'com.ninjakiwi.bloonstdbattles',
 'com.zynga.hititrich', 'com.playtika.caesarscasino', 'com.scannerradio', 'com.dogbytegames.offroadlegends2', 
 'com.google.android.googlequicksearchbox','com.google.android.apps.docs.editors.slides', 
 'com.google.android.apps.youtube.kids', 'com.bigblueclip.picstitch', 'com.morecast.weather',
 'com.gsn.android.tripeaks', 'org.zwanoo.android.speedtest', 'com.pacificinteractive.HouseOfFun',
 'audio.mp3.music.player', 'com.google.zxing.client.android', 'mp3songs.mp3player.mp3cutter.ringtonemaker', 
 'air.au.com.metro.DumbWaysToDie2', 'com.freevpnintouch', 'com.madebyappolis.spinrilla', 'vStudio.Android.Camera360',
 'com.rovio.BadPiggies', 'com.kabam.marvelbattle','com.jsdev.instasize', 'com.turner.cnvideoapp', 
 'com.natenai.glowhockey', 'com.dictionary', 'hu.appcoder.solitaire','com.kiragames.unblockmefree', 
 'com.camerasideas.instashot', 'com.handmark.sportcaster', 'com.kabam.c4', 'com.bitstrips.imoji',
 'com.ea.game.easportsufc_row', 'com.yahoo.mobile.client.android.yahoo','com.trulia.android', 
 'com.ihandysoft.ledflashlight.mini', 'com.linecorp.LGTMTMG', 'com.wb.headsup', 'com.brainium.solitairefree', 
 'com.nekki.vector', 'com.pixel.gun3d', 'com.alibaba.aliexpresshd', 'com.playappking.busrush',
 'com.move.realtor', 'com.lumoslabs.lumosity', 'kr.core.technology.wifi.hotspot', 'com.mediocre.smashhit',
 'com.casino.slotzeus', 'org.xbmc.kodi', 'com.outfit7.talkingtom2free', 'com.baviux.voicechanger',
 'com.doubleugames.DoubleUCasino', 'net.flixster.android', 'com.socialnmobile.hd.flashlight',
 'com.utorrent.client', 'com.directv.dvrscheduler', 'com.sharkparty.monopolybingo',
 'com.expedia.bookings', 'com.lookout', 'com.orangenose.eggcar', 'com.textmeinc.textme', 
 'an.SpanishTranslate', 'com.yum.pizzahut', 'org.pbskids.video', 'com.google.android.apps.paidtasks', 
 'com.asgardsoft.words', 'com.google.android.apps.messaging', 'com.zynga.wizardofoz', 'com.att.mobiletransfer',  
 'com.twelvegigs.heaven.bingo', 'air.com.buffalo_studios.newflashbingo', 'com.midasplayer.apps.diamonddiggersaga',
 'com.hcg.cok.gp', 'com.emn8.mobilem8.nativeapp.bk', 'com.scee.psxandroid', 'me.dingtone.app.im', 
 'com.amazon.now', 'me.nextplus.smsfreetext.phonecalls', 'com.sirius', 'mobi.abcmouse.academy_goo', 
 'com.quelaba.sopaletras', 'com.life360.android.safetymapd', 'com.contextlogic.mama', 
 'com.ticketmaster.mobile.android.na', 'com.ea.game.pvz2_na', 'com.andrwq.recorder', 
 'wp.wattpad', 'com.tophatter', 'com.craftgames.worldcrft', 'com.droid27.transparentclockweather',
 'com.djinnworks.StickmanFootball', 'com.microsoft.office.powerpoint', 'com.Revsoft.Wabbitemu', 
 'com.adpmobile.android', 'at.ner.lepsWorld2', 'com.cocoplay.cocobride', 
 'com.dominospizza', 'com.outfit7.talkinggingerfree', 'com.tap4fun.reignofwar', 
 'com.att.myWireless', 'jp.gungho.padEN', 'com.slice', 'org.adblockplus.browser', 'goldenshorestechnologies.brightestflashlight.free', 
 'com.ea.game.simcitymobile_row', 'com.playfirst.cookingdashx', 
 'com.merriamwebster', 'com.ubercab.driver', 'com.tracfone.straighttalk.myaccount', 
 'com.williamsinteractive.jackpotparty', 'com.netmarble.mherosgb', 
 'com.kohls.mcommerce.opal', 'com.ktcccp.videofacetime', 'com.emojifamily.emoji.keyboard.style.coloremoji', 
 'com.microsoft.office.onenote', 'com.roku.remote', 'com.melodis.midomiMusicIdentifier.freemium', 'com.venmo', 'es.socialpoint.MonsterLegends',
 'com.glidetalk.glideapp', 'com.vg.sanandreasrealgangsters3d', 'mbinc12.mb32b', 'com.sbkgames.rallyracerdirt', 
 'com.amazon.mp3', 'com.google.android.apps.walletnfcrel', 'com.jb.zcamera', 'com.avast.android.mobilesecurity',
 'com.secretexit.turbodismount', 'com.fungamesforfree.colorfy',
 'com.bandainamcogames.dbzdokkanww', 'us.theworstapps.straightouttamememaker', 'us.porrassoft.volumebooster', 
 'com.tripadvisor.tripadvisor', 'net.playq.charmking', 'com.google.android.apps.googlevoice', 
 'com.hmobile.biblekjv', 'com.superluckycasino.nolimit.slots.vegas.android.free', 'com.nekki.shadowfight', 
 'com.shopkick.app', 'air.com.bigfishgames.fairwayrevengegooguniversalf2p',
 'com.telenav.app.android.scout_us', 'com.xfinity.cloudtvr', 'com.wordsmobile.nfl', 
 'com.radio.fmradio', 'com.redbox.android.activity', 'com.tencent.mm', 'com.okcupid.okcupid',
 'com.musicplayer.player.mp3player.white', 'jp.co.ofcr.cm00', 
 'com.rovio.Nibblers', 'hr.podlanica', 'com.ea.gp.bej3', 'com.mxtech.videoplayer.ad', 
 'com.joelapenna.foursquared', 'com.scimob.mathacademy', 'com.intsig.camscanner',
 'com.onecwireless.mahjong', 'com.mojang.minecraftpe', 'com.ninjakiwi.bloonstd5', 'com.robtopx.geometryjump', 
 'ilmfinity.evocreo.main.android', 'com.ultimateguitar.tabs', 'com.tdr3.hs.android', 'com.coffeestainstudios.goatsimulator', 
 'com.scottgames.fivenightsatfreddys', 'com.wb.goog.scribbleremix', 'com.wolfram.android.alpha', 
 'uk.co.atomapps.gravitysim3d', 'com.giantssoftware.fs16', 'com.kevinbradford.games.theguides', 
 'com.scottgames.fnaf4', 'com.and.games505.TerrariaPaid', 'com.trueaxis.trueskate', 'air.com.sarahnorthway.rebuild3', 
 'au.com.shiftyjelly.pocketcasts', 'com.teslacoilsw.launcher.prime', 'com.ustwo.monumentvalley',
 'com.northcube.sleepcycle', 'org.prowl.torque', 'com.teamspeak.ts3client', 'com.foxfi.key', 
 'com.maxmpz.audioplayer.unlock', 'com.scottgames.fnaf2', 'com.epsxe.ePSXe', 'com.cubesol.twentyonedaycontainer', 
 'com.squareenixmontreal.lcgo', 'net.dinglisch.android.taskerm', 'com.FireproofStudios.TheRoom',
 'com.rockstargames.gtasa', 'com.dreamsky.DiabloLOL', 'com.jundroo.SimplePlanes', 'com.coffeestainstudios.goatsimulator.mmo', 
 'com.halfbrick.fruitninja', 'com.rockstargames.gtavc', 'com.threeminutegames.lifeline.google', 
 'com.gamesoulstudio.backflipmadness', 'com.candyrufusgames.survivalcraft', 
 'slide.watchFrenzy.premium', 'com.jumpgames.RealSteel', 'com.koushikdutta.cast.license',
 'uk.co.yakuto.TableTennisTouch', 'com.FireproofStudios.TheRoom2', 'com.choiceofgames.wiseuseoftime', 
 'com.digibites.calendarplus', 'mahmed.net.synctuneswirelesspro', 'com.mtvn.sbmigoogleplay', 
 'com.hitcents.drawastickmanepic2', 'com.aspyr.swkotor', 'org.twisevictory.apps', 'eu.thedarken.sdm.unlocker', 
 'com.quvideo.xiaoying.pro', 'com.glutenfreegames.wolfsimulatortwo', 
 'com.shabu.startingstrength', 'air.com.flipline.papasfreezeriatogo', 'com.gravitysensation.sumotori', 
 'com.sevenminworkout', 'com.wb.goog.lbbg', 'com.turner.stevenrpg', 
 'com.f2zentertainment.pandemic', 'com.coffeestainstudios.goatsimulator.goatz',
 'com.ironhidegames.android.kingdomrushorigins', 'com.scottgames.fnaf3', 
 'com.urbandroid.sleep.full.key', 'com.nekki.vector.paid', 'air.com.sarahnorthway.rebuild2', 
 'com.ea.games.nfs13_na', 'com.intsig.lic.camscanner',
 'com.exozet.android.catan', 'com.eamobile.nbajam_na_wf', 'com.etermax.preguntados.pro', 
 'com.fueled.afterlight', 'com.square_enix.android_googleplay.FFT_en2', 
 'com.miclos.google.games.outthere', 'com.period.tracker.deluxe', 'com.headupgames.bridgeconstructor', 
 'com.digidust.elokence.akinator.paid', 'com.scannerradio_pro', 'com.astragon.cs2014', 
 'com.noodlecake.framed', 'com.jeremysteckling.facerrel', 'com.keramidas.TitaniumBackupPro', 
 'com.active.aps.c25k', 'com.jundroo.simplerockets', 'com.piksoft.turboscan', 'com.gau.go.launcherex.key',
 'com.natewren.piptecgreen', 'com.ngmoco.pocketgod', 'com.sonosaurus.tonalenergytuner', 'air.com.flipline.papaspizzeriatogo', 
 'com.apalon.weatherlive', 'android.uniwar', 'com.dictionary.paid', 'com.tocaboca.hairsalon2', 
 'com.mtvn.tmntrooftoprun', 'com.flukedude.impossiblegame', 'br.com.beholdstudios.knightspp',
 'com.kvadgroup.photostudio_pro', 'com.fds.infiniteflight', 'com.worms3.app', 'com.intellijoy.android.reading', 'com.rockstar.gta3',
 'com.ironhidegames.android.kingdomrushfrontiers', 'net.snclab.wifitetherrouter', 'com.oddworld.Stranger',
 'com.flavionet.android.camera.pro', 'com.explorationbase.Exploration', 
 'com.merriamwebster.premium', 'com.fastemulator.gbc', 'com.crittermap.backcountrynavigator.license',
 'ginlemon.flowerpro', 'com.wb.lego.marvel', 'com.realdrift.sipon', 'com.fsdigital.skinstudio', 
 'com.sikebo.materialistik.material.icons', 'com.topfreegames.bikeraceproworld', 'com.rockstargames.gtactw',
 'com.playdead.limbo.full', 'com.dynamixsoftware.printershare.premium', 
 'com.almalence.opencam_plus', 'com.freecloud.StackTheStates', 'com.bennettracingsimulations.dirttrackin', 
 'com.disney.WMW', 'com.pujie.wristwear.pujieblack', 'com.abundanthealth4u.refguide4eo',
 'com.hooolm.smokeandglass', 'com.notdoppler.earntodie', 'com.underwood.calendar', 'co.smartwatchface.odyssey.watch.face',
 'com.mozglabs.spacefantasy', 'com.remotefairy', 'air.com.flipline.papasburgeriatogo', 'com.headupgames.pixelheroes',
 'com.gun.bnc', 'com.alexvas.dvr.pro', 'com.koushikdutta.backup.license', 'au.com.penguinapps.android.babyfeeding.client.android.pro',
 'com.squareenixmontreal.hitmango', 'com.eightyeightgames.ymbab', 'air.Airship2', 'com.lonewolfgames.losttreasure',
 'com.appstar.callrecorderpro', 'co.smartwatchface.watch.face.aviator.android.wear', 'fi.bugbyte.harbinger', 'com.speedsoftware.rootexplorer',
 'com.wb.goog.injustice', 'air.com.kitchenscramble.goo', 'com.backflipstudios.android.dragonvale', 
 'com.darksummoner', 'com.purplekiwii.mb', 'com.com2us.golfstarworldtour.normal.freefull.google.global.android.common', 
 'com.topps.force', 'com.rovio.angrybirdsfriends', 'com.Seriously.BestFiends', 'jp.gree.modernwar', 
 'com.chillingo.ironforce.android.ajagplay', 'com.cjenm.sknights', 'com.kabam.wartune.android', 
 'com.disney.frozensaga_goo', 'com.innogames.foeandroid', 'com.tap4fun.galaxyempire2_android', 
 'com.plarium.vikings', 'com.bw.fallensouls', 'com.jellybtn.cashkingmobile',
 'air.com.slotgalaxy', 'com.spaceapegames.rivalkingdoms', 'com.com2us.soccerspirits.normal2.freefull.google.global.android.common', 
 'com.infiapps.slotbonanza', 'com.kongregate.mobile.adventurecapitalist.google', 'jp.co.siliconstudio.ageofishtaria',
 'net.wargaming.wot.blitz', 'com.purplekiwii.mbhexa', 'com.gamevil.kritikamobile.android.google.global.normal', 
 'itembox.crayfish.x', 'younow.live', 'com.happyuniverse.pub.zjdg', 
 'com.gameloft.android.ANMP.Gloft5DHM', 'com.nuclear.qmwow.platform.r2game', 'com.jellyblast.cmcm', 
 'com.bamnetworks.mobile.android.gameday.atbat', 'ata.squid.pimd', 'com.h5g.high5casino', 'com.naturalmotion.csrclassics', 
 'com.dn.games.dtmafia', 'com.risingtidegames.blackdiamondslots.beta', 
 'com.RocketGames.ClassicSlots', 'com.gsn.grandcasino', 'com.kabam.underworldandroid', 
 'com.rumbleentertainment.kingsroad', 'com.DgnGames.OldVegasSlots',
 'com.namcobandaigames.spmoja010E', 'com.superevilmegacorp.game', 'com.scopely.slotsvacation', 'com.rovio.ABstellapop', 
 'com.kabam.newcnhoc', 'com.gameloft.android.ANMP.GloftA8HM', 'com.gameinsight.tribez', 'klb.android.lovelive_en', 
 'com.gameloft.android.ANMP.GloftGHHM', 'com.teamlava.castlestory', 'com.igg.pokerdeluxe', 'com.gameloft.android.ANMP.GloftPOHM', 'com.igs.fafafa', 
 'com.nhnent.SKQUEST', 'com.plarium.tdreborn', 'com.rushmo.casinofrenzy', 'com.kabam.kocmobile', 
 'com.midasplayer.apps.papapearsaga', 'com.marvel.comics', 'ru.crazybit.experiment', 'com.ministone.game.RisingStarChef', 
 'com.zentertain.bigcasino', 'air.com.gamesys.mobile.slots.jpj', 'com.gamehivecorp.taptitans', 
 'air.com.spicerackmedia.bingoshowdown', 'com.cervomedia.spf', 'com.sharkparty.bingo',
 'com.nubee.valkyriecrusade', 'com.glu.contractkiller3', 'com.feelingtouch.dipan.slggameglobal', 
 'jp.co.a_tm.wol.en', 'com.wgt.android.golf', 'com.asobimo.avabel_gp_b3', 'com.ea.game.dragonage_na',
 'com.kongregate.mobile.tyrant.google', 'com.kiwi.shipwrecked', 'com.kiwi.westbound', 'com.tap4fun.kings_empire',
 'com.ember.cmdrz', 'com.diwip.vslots', 'com.pixelberrystudios.hwuandroid', 'com.gamehouse.slingo', 
 'com.rovio.gold', 'com.kamagames.pokerist', 'com.callpod.android_apps.keeper', 'air.com.sublinet.tastytale', 
 'com.kobojo.mutants', 'com.miniclip.plagueinc', 'com.gameloft.android.ANMP.GloftMMHM', 
 'com.cookapps.watersplash', 'com.theonegames.gunshipbattle', 'com.camelgames.fantasyland', 
 'com.gameinsight.airport', 'jp.naver.lineplay.android', 'com.kakao.talk',
 'com.feelingtouch.empirewaronline', 'com.weplaydots.twodotsandroid',
 'com.pixelberrystudios.hssandroid', 'air.MSPMobile', 'com.jnj.mocospace.android', 'jp.co.ponos.battlecatsen', 
 'com.evernote', 'com.scimob.wordacademy', 'eu.nordeus.topeleven.android', 'com.taggedapp', 
 'com.creativemobile.nno', 'com.joycity.warshipbattle', 'com.flaregames.rrtournament', 
 'com.loe.empire_gp', 'org.nanobit.cheftown', 'com.mobage.ww.a1439.Bingo_PartyLand_Android',
 'com.kiwi.goldrush', 'com.mobiledatalabs.mileiq', 'air.com.r2gamesusa.clickerheroes', 
 'com.teamlava.farmthree47', 'com.gamevil.monster.global', 'com.playstudios.myvegas.blackjack',
 'com.mavenhut.solitaire', 'us.kick9.k3000000013.c3101000001', 'com.zeptolab.thieves.google', 
 'com.unitedfun.prod.apollo', 'com.gameinsight.gplay.island2',
 'com.fungames.sniper3d', 'com.kii.safe', 'com.symantec.mobilesecurity', 'com.igg.clash_of_lords', 
 'jp.co.applibot.legend.android', 'com.belkatechnologies.clockmaker', 'com.luckyfish.omgfortune', 
 'com.topps.bunt', 'com.bagatrix.mathway.android', 'kr.co.angames.galaxyconflict.google.android',
 'com.zentertain.classicvegasslots', 'com.yousician.yousician', 'com.ea.game.pegglex_row',
 'com.lockwoodpublishing.avakinlife', 'com.pyrsoftware.pokerstars.net', 'onxmaps.hunt', 'com.nytimes.android', 
 'ru.mail.games.android.JungleHeat', 'com.miniclip.soccerstars', 'com.sq.dragonsworld', 'com.teamlava.restaurantstorytwo',
 'dk.tactile.beebrilliant', 'com.moonton.magicrush', 'air.com.pacific.enterprises.fruitland',
 'com.dccomics.comics', 'com.gamehouse.d11gp', 'com.gameloft.android.ANMP.GloftMTHM', 'com.netqin.ps',
 'com.rovio.angrybirdstransformers', 'com.glu.dino', 'com.ldw.virtualfamilies2',
 'com.concretesoftware.pbachallenge_androidmarket', 'com.magisto', 'com.coastalimages.enyo_blue', 'ie.udaltsoft.musicwatch', 'com.ideeo.miadvanced', 'fishnoodle.ncaa_helmet_notredame', 
 'air.BassNotesFlashCards', 'box.media.audiator.mp3.volume.boost.music.pro', 'com.skiracer.nautical_astore_ukirl', 
 'com.visualizeitfm.soccertracker', 'inteligeen.rocketdial.theme.takdarkmetal', 'n21.global.leadership', 
 'uno.studio.theme.launcherex.arrow', 'com.coastalimages.kirby_red', 'com.pld.readingrace1a', 'uk.co.mattsmithies.nbdtricks', 
 'com.zerotier.one', 'com.heathkit.crystalcalculator', 'dev.ukanth.ufirewall.donatekey', 
 'com.anesoft.quiz', 'com.reactiverobot.filtrate', 'com.eai.fob', 'pl.pwn.slownik_pwn_oxford',
 'com.teamhc.project8time1', 'com.strong.mind.bright.flowers.lwp.pro', 
 'com.tbig.playerpro.skins.takelegantglasblk', 'com.chordtrainer', 'com.tbig.playerpro.skins.takwhiteleather', 'com.strong.mind.multicolored.radiant.flowers.lwp',
 'com.modoohut.dialer.theme.takelegantmaterialgrey', 'com.planeth.gstflphbigelectrobundle2', 
 'com.tengallonapps.judge', 'com.ss.launcher2.theme.lifeisgood', 'net.BadComics.BabyFrogsGame', 'si.topapp.mymeasurespro', 
 'com.medicalgroupsoft.medical.nutients12.paid', 'com.pro7it.note5', 'ringtone.maker.pro',
 'air.zad.albedo', 'com.applemint.imissher', 'de.nachregenkommtsonne.myospherocontrolC',
 'com.michael.gospel.full', 'net.tolberts.android.roboninja.android.donate', 'com.olivierboite.android.hiddenapppro', 'com.orangeclover.tacnav', 'caipiroska.sltheme.highcontrast', 
 'com.reinto.hidatsapro', 'com.xuecs.accessdbpro', 'com.hg.islayzombies', 'com.leen.wallpaper.panda', 'com.elzite.omega.theme', 
 'com.kiku.fairypuffpro', 'au.com.wallaceit.pebblewatchfacescheduler', 'justinkruit.candycons.donation', 
 'com.matchgems.fantasy_mosaics_11', 'org.shreemaa.SpiritualBusiness', 'ro.yo3ggx.rxtxpro',
 'com.midsizemango.gleamiconpack', 'com.hyperq.info.aj6', 'net.artificialworlds.rabbitescape',
 'com.gregvestal.diceit', 'jrtstudio.music.ad.blocker', 'com.microids.peterandwendy', 
 'com.thehoodiestudio.halftimewatchface', 'com.baconbits.klwp.thegline', 'com.gamebrain.cartoonpro', 
 'mazzy.and.elevensesforone.android', 'net.ddroid.aw.watchface.mv20', 'org.kustom.obtekhud', 'com.verticalflat', 
 'ca.guylyhey.studfinder', 'com.emojiworld.lovemojistwo', 'com.coastalimages.exec_red', 'com.aardman.puzzleputt',
 'com.artscroll.SAEEI', 'com.zyrobotics.citycount', 'net.ddroid.aw.watchface.rv20', 'com.simba.chronus.marshmallow', 
 'com.b16h22.lynes', 'com.rustybrick.selichos', 'com.na.zwskin.marshmallow', 
 'com.cdapplications.until', 'com.sgs.CrazyTower2f', 'music.volume.equalizer.bassbooster.virtualizer.pay', 
 'loststars.apps.p7ghoul.loststars', 'com.myapps.wags76.myaccounts', 'com.Encov.Ember',
 'me.ccrama.slideforreddittabletuiunlock', 'com.kidslox.app', 'com.crescentmoongames.tinyempirepremium', 
 'org.kustom.achieve', 'com.fibrum.leviafanvr', 'com.alieninzen.FlippyGeometry', 'creamt.klwp',
 'com.coastalimages.turbulence', 'com.jb.gokeyboard.theme.punk.getjar', 'com.TheHohngCompany.Birdistry','com.frokkle.starmate',
 'com.ZachMoore.AliensinOrbit', 'com.coastalimages.sunkengi', 'com.benx9.tocaui',
 'uk.co.code4gamers.barclay_ravenscroft.ultra4_offroad_racing_gps', 'com.sagosago.Boats.googleplay', 
 'com.apocalypticcity3d.livewallpaper', 'com.kohlewrrk.outray', 'com.finishedresults.liveresults', 'com.devolver.hlm2',
 'com.bazola.isoworld.android', 'fr.thema.wear.watch.running', 'com.amphibius.house_of_zombies.android',
 'com.vadnere.laserbeamtheme', 'com.LiquidCity.PlanetBuilder', 'com.erega74.shimu.iconpack', 'com.coastalimages.sunkparency',
 'com.ddevicers.sketchyiconpack', 'com.gloczus.amnesiasmp_premium2', 'net.imontana.BroncoBuilder', 'com.artifexmundi.fairytalemysteries2.gp.full', 
 'com.hiltonsoftware.wingxpro7', 'com.chillingo.powerpingpong.android.gplay', 'sichris.patanoir', 'xertz.retro.mini.golf.master.pro',
 'pl.patrykgoworowski.cornieicons', 'voicedream.reader', 'mytown.hospital', 
 'co.smartwatchface.combo.watch.face', 'com.iceandfire.aRgon', 'com.jixipix.rippix', 'com.forcefield.forestspirit',
 'com.coastalimages.sungini', 'com.wmwatch.pradomaterialdesign', 'com.protongkd.iconpack', 
 'com.dazzler.ekodark', 'justinkruit.iconpack.colorcons', 'org.kustom.pages', 'com.kiku.fluffychupro',
 'com.tabom.projectseagirlus', 'com.gabysoft.flippixcivilizations',  'org.kustom.cardsstand', 'com.sponge.adarkdragon',
 'com.thaphlash.watch.remarkable', 'com.vg.feartheundeadzombies', 'com.doubleugames.doubleubingo', 
 'com.tg.craftcoppursuitblockythief', 'com.pocketpoints.pocketpoints', 'com.ustwo.watchfaces.bits', 'com.HGames.CraftBuilder', 
 'air.com.generamobile.kingcraft', 'com.google.android.apps.access.wifi.consumer', 'com.ikeyboard.theme.cheetah', 
 'com.integer.sharksharkrun', 'air.com.goblin.worldwondersescape',
 'com.labexception.motorivals', 'com.gau.go.launcherex.theme.weather2in1.shiningStar', 'fr.pated.seashine',
 'com.ikeyboard.theme.glamorflowers', 'com.titan.tplighthouse', 'com.my.might.glory.fantasy.strategy',
 'com.pearsoned.etext2he', 'church.life.app', 'com.seattle.apps.music.equalizer', 'kemco.execreate.asdivinediosfree',
 'com.djit.apps.edjing.expert.le', 'com.ikeyboard.theme.shiningheart', 
 'com.eweapons.customguns', 'com.playstation.untildawn', 'com.claires.android', 'com.spanishdict.spanishdict',
 'com.nuframe.plockit', 'com.dreamgame.bubblecat3', 'com.gau.go.launcherex.theme.FantasticLine',
 'com.i6.cardrivingsim3d', 'com.babyfirst.mypet', 'com.ikeyboard.theme.dubainight', 'com.arliehanes.girlskinspe',
 'com.gameon.bubblebustpp', 'com.tmsoft.spillzone', 'com.app.teamusa', 'com.crazycatsmedia.android_makebeachfood',
 'gokarting.minicadesmobile.com', 'air.ape018andro001', 'air.org.axisentertainment.BabyHazelTreeHouse',
 'com.magmamobile.game.BasketballShooter', 'com.km.camera3d', 'com.eweapons.ultimatetoygunssim', 
 'com.igames.darts2015', 'com.myfico', 'com.faceplus.bubble.breaker', 'com.square_enix.ffportal_w.googleplay',
 'com.ikeyboard.theme.firefly', 'com.EG.ZombieCrimeTown', 'com.champssports.champssports',
 'com.i6.pvr9', 'net.applabsinc.android_secretgarden', 'com.jb.gosms.theme.getjar.fdfirework',
 'com.pds.oceanrescue', 'com.goarro.Arro', 'com.mastercard.directexpress', 
 'kr.co.smartstudy.bedtime_android_googlemarket', 'com.integer.bikeracing', 'com.apusapps.theme.i_cosmos_cd6c246bcb',
 'com.vg.airport.city.cargo.plane', 'com.asus.themes.dragondynasty', 'com.tillmania.physicsboxing', 
 'com.livewallpapers3d.neonfish', 'com.cellit.cellitnews.wjar', 'com.nlightninproduction.beyondpool3d', 'com.i6.bikeraceoffroad3d',
 'com.agaming.zonaprojectx.lite', 'com.ikeyboard.theme.magicrainbow', 'church.usacatholic.mobile',
 'com.ng.jeopardy', 'jp.co.a_tm.android.plus_ribbon_stripe', 'com.ironbear.everrich',
 'com.kidsthree.princessfashionsalon', 'com.rmstudio.bierfest', 'com.mobirix.wordsearch', 'com.gtp.nextlauncher.theme.weatherex2in1.steamage',
 'com.dg.puzzlebrothers.mahjong.letthedogsout', 'com.detentiongames.hiddenobjectsnewyorkchicago',
 'jp.danball.eartheditor', 'com.sec.android.app.sbrowser', 'com.tapinator.cat.frenzy3d', 'com.rocketgames.casinoclassic',
 'air.com.ooblada.riddlestones', 'com.gamespuff.highway.racing.stunt.rider', 'com.mg.blockyarmycity', 'air.com.qublix.forestrescue',
 'com.hopper.mountainview.play', 'com.craftgames.plntcrft', 'com.windoweduniverse.dirtracingmobile3d', 'kemco.execreate.asdivinedios',
 'com.nightlightinteractive.ww', 'ru.gamedevteam.bd', 'com.i6.offroad_bike_rider_simulator', 
 'com.wawoo.gunshootwar2', 'air.org.axisentertainment.BabyHazelLearnAnimals',
 'com.coreapps.android.followme.pennstfcd15', 'com.frojo.dino.android', 'com.aa2.generaladaptiveapps', 
 'com.MadSallyGames.Scroodles', 'com.htc.cs.identity', 'com.sphero.bb8', 'com.roosterteeth.roosterteeth',
 'com.ezjoynetwork.juicerescue', 'com.ikeyboard.theme.toxiccell', 'com.ikeyboard.theme.punkskull', 
 'com.playdraft.playdraft', 'com.sundaytoz.kakao.shanghai.service', 'com.dogbytegames.blockyrush', 'com.fast.motorcycle.driver.twonullonesix',
 'com.ikeyboard.theme.revengealien', 'com.ikeyboard.theme.neonstar', 'com.globalegrow.app.dresslily',
 'com.vg.offroadtouristbusdriver', 'com.vdogames.callyscaves3', 'com.seattle.apps.volume', 
 'com.i6.pvr10', 'com.vmn.android.spike', 'com.jb.gosms.pctheme.edsuzi.fevvas.advanced',
 'de.kamibox.burger', 'com.timgames.findthedifferencetim3', 'com.wonder', 'com.nttsolmare.game.android.wihef',
 'com.idlegames.eldorado','com.adhoclabs.burner', 'com.zynga.scramble', 'com.airgames.bbw', 'sts.al',
 'com.fitnow.loseit', 'com.whitepages.search', 'com.creativemobile.DragRacing', 'me.tango.roadriot',
 'com.capcom.smurfsandroid', 'com.imvu.mobilecordova', 'com.cozi.androidfree', 'com.gameturn.aow', 
 'com.sparklingsociety.cityisland3', 'air.com.pixelfederation.TrainStationGame',
 'com.gameloft.android.ANMP.GloftM5HM', 'com.gameloft.android.ANMP.GloftIVHM', 
 'com.longtech.lastwars.gp', 'com.mtvn.Nickelodeon.GameOn', 'com.rsz.StickmanBattlefields',
 'com.vg.elitespyassassinmission', 'com.amctve.amcfullepisodes', 'com.pomelogames.bulletboy.google',
 'com.joydo.cnrjb2', 'com.rexetstudio.murdergameportable', 'com.com2us.imo.normal.freefull.google.global.android.common', 
 'com.kristanix.android.jigsawpuzzleepic', 'com.nttsolmare.game.android.biref',
 'eu.mvns.games', 'com.pokiemagic.playersparadisecasino', 'com.playmage.dragonera', 
 'com.casinogame.slots', 'com.madfingergames.deadtrigger2', 'com.innogames.tw2', 'com.skimble.workouts',
 'com.gameloft.android.ANMP.GloftTHHM', 'com.disney.maleficent_goo',
 'com.golflogix.ui', 'com.asobimo.iruna_en', 'com.turborilla.MadSkillsMotocross2',
 'com.udemy.android', 'com.abc.AgeofKingdomsHD', 'com.nhnent.SK10360',
 'com.tbegames.and.top_speed_racing', 'com.spx.ing004.google.s0',
 'com.calm.android', 'com.coffeemeetsbagel', 'com.geaxgame.pokerkingpro',
 'com.gameloft.android.ANMP.GloftTOHM', 'air.com.innogames.grepolis', 
 'com.pixonic.wwr', 'com.groundspeak.geocaching.intro', 'com.teletype.smarttruckroute', 'com.kiwi.volcanoisland',
 'com.teamlava.fashionstory47', 'com.my.evolution.android', 'com.kiwi.wabeta', 'com.atari.mobile.rct4m',  
 'com.onethumbmobile.celticheroes', 'com.lastpass.lpandroid', 'com.i6.city_race_bike_simulator',
 'com.huuuge.casino.slots', 'com.kiwi.skullislandexplorers', 'com.peoplefun.wordchums', 'com.rtsoft.growtopia',
 'wsj.reader_sp', 'air.com.sgn.paintmonsters.gp',  'com.teamlava.farmthree', 'com.sbardyuk.animalphotos', 'doglicksscreen.ihs.com',
 'com.appbasic.electricscreen', 'com.andromo.dev230101.app310734', 'com.andromo.dev230101.app315617', 
 'com.driftwood.wallpaper.sleepypanda.free', 'com.surmin.assistant', 'com.maxlab.fallingmoneywallpaperlte', 
 'com.livewallpapers3d.frozenbutterflies', 'com.andromo.dev230101.app313275',
 'org.androidworks.livewallpaperrosefree', 'com.shirobakama.wallpaper',
 'com.andromo.dev230101.app308793', 'de.j4velin.wallpaperChanger', 'fishnoodle.autumn_free', 
 'com.andromo.dev230101.app331542', 'com.andromo.dev230101.app332849', 
 'com.chiralcode.wallpaper.autumn', 'com.sd.google.sanriotownLiveWallpaper', 'com.RoseLiveWallpaperHDHQ',
 'org.tamanegi.wallpaper.multipicture', 'com.incredibleapp.wallpapershd', 'com.androidwasabi.livewallpaper.s4leaf', 
 'com.blackbirdwallpapers.orchids', 'com.teragon.skyatdawnlw.lite', 
 'mx.livewallpaper.clocklight', 'fishnoodle.snowfall', 'opotech.starfieldLWP', 'com.peaksel.islamicwallpapers',
 'com.harsh.material', 'com.whatsapp.wallpaper', 'com.chiralcode.wallpaper.forest', 'com.sharpregion.tapet', 
 'com.delphicoder.flud', 'com.vuze.torrent.downloader', 'com.bittorrent.client',
 'com.mobilityflow.torrent', 'com.akingi.torrent', 'com.mediaget.android', 'com.davidhodges.torrentsearch', 
 'com.brute.torrentolite', 'com.frostwire.android', 'com.AndroidA.DroiDownloader', 
 'connect.torrentpower', 'com.bittorrent.client.pro', 'org.transdroid.lite', 'hu.bute.daai.amorg.drtorrent', 'com.neogb.rtac', 
 'com.teeonsoft.ztorrent', 'roman10.media.converter.v7neon', 
 'com.bsplayer.bspandroid.free', 'com.ahoygames.okey', 'com.insolence.admclient',
 'com.mobilityflow.torrent.prof', 'com.archos.mediacenter.videofree', 
 'fr.lepetitpingouin.android.t411', 'com.delphicoder.flud.paid',
 'udk.android.reader', 'com.archos.mediacenter.videomtk' 
]

# %%
for number, letter in enumerate(app_packages):
    print(number, letter)
# Out:
# 0 com.hbo.hbonow
# 1 com.tubitv
# 2 com.zhiliaoapp.musically
# 3 com.squareup.cash
# 4 com.google.android.apps.nbu.paisa.user
# 5 com.disney.disneyplus
# 6 com.google.android.play.games
# 7 com.shopify.arrive
# 8 us.zoom.videomeetings
# 9 com.paypal.android.p2pmobile
# 10 com.dd.doordash
# 11 com.instagram.android
# 12 com.whatsapp
# 13 com.snapchat.android
# 14 com.peacocktv.peacockandroid
# 15 com.venmo
# 16 com.contextlogic.wish
# 17 com.facebook.orca
# 18 com.walmart.android
# 19 org.telegram.messenger
# 20 com.spotify.music
# 21 com.hulu.plus
# 22 com.discovery.discoveryplus.mobile
# 23 com.discord
# 24 com.univision.prendetv
# 25 com.netflix.mediaclient
# 26 com.teacapps.barcodescanner
# 27 com.americasbestpics
# 28 com.doordash.driverapp
# 29 com.amazon.avod.thirdpartyclient
# 30 com.amazon.mShop.android.shopping
# 31 com.lemon.lvoverseas
# 32 com.ubercab
# 33 com.bamnetworks.mobile.android.gameday.atbat
# 34 com.zzkko
# 35 com.facebook.katana
# 36 com.cleanteam.oneboost
# ...

# %%
app_infos = []

for ap in tqdm(app_packages):
    info = app(ap, lang='en', country='us')
    del info['comments']
    app_infos.append(info)
# Out:
# 100%|██████████████████████████████████████| 1925/1925 [07:53<00:00,  4.06it/s]

# %%
def print_json(json_object):
    json_str = json.dumps(
        json_object,
        indent=2,
        sort_keys=True,
        default=str
    )
    
    print(highlight(json_str, JsonLexer(), TerminalFormatter()))

# %%
print_json(app_infos[0])
# Out:
# {
#   "adSupported": null,
#   "androidVersion": "5.0",
#   "androidVersionText": "5.0 and up",
#   "appId": "com.hbo.hbonow",
#   "containsAds": false,
#   "contentRating": "Teen",
#   "contentRatingDescription": null,
#   "currency": "USD",
# ...

# %%
app_info_df = pd.DataFrame(app_infos)
app_info_df.head()
# Out:
#                                               title  \
# 0    HBO Max: Stream and Watch TV, Movies, and More
# 1                     Tubi - Free Movies & TV Shows
# 2                                            TikTok
# 3                                          Cash App
# 4  Google Pay: A safe & helpful way to manage money
#
#                                          description  \
# 0  HBO Max is the streaming platform that bundles...
# 1  Watch thousands of hit movies and TV series fo...
# 2  TikTok is THE destination for mobile videos. O...
# 3  Cash App is the easiest way to send, spend, sa...
# 4  Google Pay is a safe, simple, and helpful way ...
#
#                                      descriptionHTML  \
# 0  HBO Max is the streaming platform that bundles...
# 1  Watch thousands of hit movies and TV series fo...
# 2  TikTok is THE destination for mobile videos. O...
# 3  Cash App is the easiest way to send, spend, sa...
# 4  Google Pay is a safe, simple, and helpful way ...
#
# ...

# %%
app_info_df.to_csv('apps_info.csv', index=None, header=True)

# %%
app_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1925 entries, 0 to 1924
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   title                     1925 non-null   object
#  1   description               1925 non-null   object
#  2   descriptionHTML           1925 non-null   object
#  3   summary                   1925 non-null   object
#  4   summaryHTML               1925 non-null   object
#  5   installs                  1925 non-null   object
#  6   minInstalls               1925 non-null   int64
#  7   score                     1925 non-null   float64
#  8   ratings                   1900 non-null   float64
#  9   reviews                   1925 non-null   int64
#  10  histogram                 1925 non-null   object
#  11  price                     1925 non-null   float64
#  12  free                      1925 non-null   bool
# ...

# %% [markdown]
# # Get App Reviews

# %%
app_reviews = []

for ap in tqdm(app_packages):
    for score in range(1,6):
        for sort_order in [Sort.MOST_RELEVANT, Sort.NEWEST]:
            rvs = reviews(
            ap,
            lang='en',
            country='us',
            sort=sort_order,
            count= 200 if score == 3 else 100,
            filter_score_with=score
            )[0]
            
            for r in rvs:
                r['sortOrder'] = 'most_relevant' if sort_order == Sort.MOST_RELEVANT else 'newest'
                r['appID']= ap
            app_reviews.extend(rvs)

# %%
print_json(app_reviews[0])

# %%
app_reviews_df = pd.DataFrame(app_reviews)
app_reviews_df.shape

# %%
app_reviews_df.head()

# %%
app_reviews_df.to_csv('app_reviews.csv', index=None, header=True)
