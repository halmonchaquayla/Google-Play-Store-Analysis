# %%
import json #google play returns list of json
import pandas as pd
from tqdm import tqdm

# %%
# help highlights some of the json results
from pygments import highlight
from pygments.lexers import JsonLexer
from pygments.formatters import TerminalFormatter

# %%
from google_play_scraper import Sort, reviews, app

# %%
#top paid games/rated
app_packages = [
    'com.robtopx.geometryjump', 'com.marmalade.monopoly',
    'com.chucklefish.stardewvalley', 'com.and.games505.TerrariaPaid', 
    'com.clickteam.ultimatecustomnight',
    'com.rockstargames.gtasa', 'net.kairosoft.android.bouken2', 'com.playdead.limbo.full',
    'eu.bandainamcoent.verylittlenightmares', 'com.marmalade.gol2', 'com.scottgames.fnaf2',
    'com.and.games505.humanfallflat', 'com.scottgames.sisterlocation', 'com.dsemu.drastic',
    'com.scottgames.fnaf4', 'com.FireproofStudios.TheRoom', 'com.clickteam.freddyfazbearspizzeriasimulator',
    'com.prpr.musedash', 'com.humble.SlayTheSpire', 'com.rockstargames.gtavc', 
    'com.fastemulator.gba', 'com.ninjakiwi.bloonstd5', 'com.topgames100.ClassicSolitaireTycoon',
    'com.trueaxis.trueskate', 'com.squareenixmontreal.hitmansniperandroid', 
    'com.sofarsogood.incredibox', 'com.activision.boz', 'com.marmalade.golmobile',
    'com.playdigious.deadcells.mobile', 'com.steelwoolgames.fnaf.hw', 
    'com.explodingkittens.projectbombsquad', 'com.scottgames.fnaf3', 
    'it.rortos.realflightsimulator', 'com.marmalade.cluedogame', 'com.wb.goog.scribbleremix',
    'com.giantssoftware.fs20.google', 'com.ubisoft.assassinscreed.identity',
    'com.fizzd.connectedworlds', 'air.com.flipline.papasmochariatogo', 
    'com.piratesoutlaws.fabledgame', 'com.wb.goog.scribblenauts3', 'com.jds.batim',
    'com.topgames100.angry.knife', 'com.robotgentleman.game60seconds', 
    'com.corrodinggames.rts', 'com.t2ksports.nba2k20and', 'com.atari.mobile.rctclassic', 
    'com.rockstar.gta3', 'com.humblebundle.forager', 'air.com.flipline.papasfreezeriatogo',
    'com.DMAP.Ting_WD', 'com.square_enix.android_googleplay.FFVIII', 
    'com.headupgames.bridgeconstructorportal', 'com.babotech.NOHA', 'com.greenheartgames.gdt',
    'com.ironhidegames.android.kingdomrushfrontiers', 'com.FireproofStudios.TheRoom2',
    'com.fastemulator.gbc', 'com.fds.infiniteflight', 'com.ea.games.nfs13_na', 
    'com.coffeestainstudios.goatsimulator', 'com.rockstargames.bully', 
    'com.ironhidegames.android.ironmarines', 'com.FireproofStudios.TheRoom4',
    'com.wb.lego.marvel', 'com.square_enix.android_googleplay.chrono',
    'com.ustwo.monumentvalley', 'com.bluebraingames.houseofdavinci2',
    'com.FireproofStudios.TheRoom3', 'com.mazetheory.dwla', 'com.wb.goog.legojurassicworld',
    'com.codebrewgames.pocketcitygame', 'com.MontanaGames.Lowriders.Comeback2',
    'com.PlausibleConcept.BadNorthFull', 'com.etermax.preguntados.pro',
    'com.aspyr.swkotorii', 'com.damonplay.damonps2.pro.ppsspp', 'com.feralinteractive.rometw',
    'com.D3Go.mendel', 'com.giantssoftware.fs18.google', 'com.square_enix.android_googleplay.FFT_en2',
    'com.bethsoft.DOOM', 'com.aspyr.swkotor', 'com.eamobile.nbajam_na_wf',
    'com.rockstar.maxpayne', 'jp.konami.epjCastlevania2', 'com.tocaboca.tocaboo',
    'com.ironhidegames.android.kingdomrushorigins', 'com.ironhidegames.android.kingdomrush4',
    'com.KiotGames.BasketballPusher', 'com.bluebraingames.thehouseofdavinci', 
    'com.coffeestainstudios.goatsimulator.payday', 'com.pixelcurves.terlauncher',
    'com.square_enix.android_googleplay.FFVII', 'it.dbtecno.pizzaboygbapro',
    'com.kleientertainment.doNotStarvePocket', 'uk.co.aifactory.chess',
    'air.com.flipline.papassushiriatogo', 'com.marmalade.golv', 'com.noodlecake.gettingoverit',
    'com.wb.goog.lnjgo', 'com.halfbrick.fruitninja', 'com.tocaboca.tocamysteryhouse',
    'com.Majorariatto.Pureya', 'com.bowengames.farmingusa2', 'air.com.flipline.papasdonuteriatogo',
    'com.tocaboca.tocalabplants', 'com.rockstargames.gtactw', 'com.mlb.RBIBaseball21',
    'net.kairosoft.android.boxing', 'org.ppsspp.ppssppgold', 'com.disney.WMW', 
    'com.playdigious.cultist', 'air.com.flipline.papasburgeriatogo', 'com.ustwo.monumentvalley2',
    'com.beamdog.pstee', 'com.bennettracingsimulations.dirttrackin2', 'com.focushome.MudRunnerAndroid',
    'com.kiotgames.dripme', 'com.turner.ttgfigures2', 'com.newgeogamerni', 
    'com.gameloft.android.ANMP.GloftICHM', 'com.square_enix.android_googleplay.dq1_gp',
    'com.tipsworks.android.pascalswager.google', 'com.nekki.vector.paid', 
    'mycity.hospital', 'air.com.flipline.papaspizzeriatogo', 'com.team17.escapists2',
    'com.wb.goog.lbbg', 'com.EtherGaming.PocketRoguesUltimate', 'com.disney.castleofillusion_goo',
    'com.feralinteractive.companyofheroes_android', 'com.agaming.thesun.origin',
    'joybits.doodlegod', 'nz.co.codepoint.minimetro', 'jp.co.capcom.mhsspen',
    'com.daysofwonder.tt.android', 'com.younghorses.octodad', 'com.rockstargames.gtalcs',
    'com.ngmoco.pocketgod', 'com.hg.bfbb', 'air.com.flipline.papaswingeriatogo', 
    'com.maguni.geoguessr', 'mycity.friendshouse', 'com.AngryNeighbor',
    'com.refineryproductions_2112td', 'air.com.flipline.papasbakeriatogo',
    'com.hammerfall.regicide', 'com.splashworks.pawsomedays', 'com.drycactus.polybridge2',
    'air.com.flipline.papasscooperiatogo', 'air.com.flipline.papascheeseriatogo',
    'com.tresebrothers.games.startraders2', 'com.kalypsomedia.projecthighrise',
    'com.jds.batds', 'com.sega.sonic4epi', 'com.infinitygames.packageinc',
    'com.johnemulators.johngba', 'brownmonster.app.game.rushrally3',
    'com.tt2kgames.xcomew', 'com.notdoppler.earntodie', 'com.jdroid.gtasacheater',
    'air.com.flipline.papaspancakeriatogo', 'air.com.RustyLake.RustyLakeHotel',
    'com.turner.ttgfigures', 'ilmfinity.evocreo.main.android', 'com.turner.stevenrpg',
    'com.sega.score', 'com.uplayonline.youtubers', 'com.playdigious.dungeonoftheendless',
    'com.mageeks.android.trucksimulatorpro2', 'com.pockettrend.neomonsters', 
    'mytown.airport', 'com.drycactus.polybridge', 'air.com.flipline.papashotdoggeriatogo',
    'com.beamdog.baldursgateenhancededition', 'com.teachyourmonstertoread.tmapp',
    'com.coffeestainstudios.goatsimulator.mmo', 'com.NamcoNetworks.MsPacMan', 
    'com.tinybuild.graveyardkeeper', 'com.ninetailgames.roguehearts.paid',
    'com.nekki.shadowfight2.paid', 'com.astragon.cs3', 'co.uk.wixgames.ducklifebattle',
    'air.com.flipline.papaspastariatogo', 'mycity.pjparty', 'air.com.flipline.papascupcakeriatogo',
    'com.jutsugames.operator911', 'com.devolver.spaceplan', 'com.feralinteractive.gridas',
    'com.khg.doorkickers', 'com.superpsx.pro', 'air.com.flipline.papastacomiatogo',
    'com.coffeestainstudios.goatsimulator.wasteofspace', 'com.devolver.reigns',
    'com.king.crash', 'com.sega.sonic2.runner', 'com.sega.sonicdash', 
    'com.sega.soniccd.classic', 'com.outfit7.mytalkingtomfree', 'com.outfit7.mytalkingtom2',
    'com.dancing.smash.hop.game.tiles.circles.beat.paino', 'com.playgendary.tom', 
    'com.tocaboca.tocakitchen2', 'com.sega.sonicboomandroid', 'com.Earthkwak.Platformer', 
    'com.sega.sprint', 'com.aim.racing', 'com.outfit7.mytalkingtomfriends', 
    'com.fungames.blockcraft', 'com.outfit7.mytalkingangelafree', 'com.sinyee.babybus.taxi',
    'com.outfit7.talkingtomgoldrun', 'com.crazylabs.lady.bug', 'com.illumix.fnafar',
    'com.stickman.dragon.fight.stick.warriors.stickmanwarriors', 'mytown.friendshouse.free',
    'mytown.hotel.free', 'com.tutotoons.app.fluvsies.free', 'com.sinyee.babybus.world',
    'com.PoxelStudios.DudeTheftAuto', 'com.Neurononfire.SupremeDuelist', 
    'com.stickman.warriors.stickwarriors.dragon.shadow.fight', 'smellymoo.sand',
    'com.dancing.tiles.magic.music.beat.saber', 'com.tocaboca.tocalifeworld',
    'free.os.jump.superbros.adventure.world', 'net.mobigame.zombietsunami',
    'com.orange.kidspiano.music.songs', 'com.bandainamcoent.dblegends_ww',
    'com.wildspike.wormszone', 'com.fgol.HungrySharkEvolution', 'jp.pokemon.pokemonquest',
    'com.fungames.sniper3d', 'com.movile.playkids.pkxd', 'com.ea.game.pvzfree_row',
    'com.frojo.moy7', 'com.dts.freefireth', 'com.bandainamcogames.dbzdokkanww',
    'com.europosit.pixelcoloring', 'com.maxgames.stickwarlegacy', 'com.activision.callofduty.shooter',
    'com.dreamotion.ronin', 'com.halfbrick.dantheman', 'com.PlayMax.playergames',
    'com.playmini.miniworld', 'com.pixel.gun3d', 'com.netmarble.nanagb', 
    'com.JindoBlu.Antistress', 'com.klab.bleach', 'com.moonfrog.ludo.club',
    'com.wildlifestudios.free.online.games.suspects', 'com.igg.android.lordsmobile', 
    'com.moonactive.coinmaster', 'com.king.candycrushsaga', 'com.aladinfun.islandking.android',
    'com.nianticlabs.pokemongo', 'com.nekki.shadowfight',
    'air.com.buffalo_studios.newflashbingo', 'com.playrix.homescapes', 'com.plarium.raidlegends',
    'com.playrix.gardenscapes', 'com.aniplex.fategrandorder.en', 'com.king.candycrushsodasaga',
    'com.smallgiantgames.empires', 'com.topwar.gp', 'air.com.playtika.slotomania',
    'com.foxnextgames.m3', 'com.playrix.fishdomdd.gplay', 'net.peakgames.toonblast',
    'com.williamsinteractive.jackpotparty', 'com.funplus.kingofavalon',
    'com.playrix.township', 'slots.pcg.casino.games.free.android', 'com.chess',
    'com.lilithgame.roc.gp', 'com.playstudios.popslots', 'com.nekki.shadowfight3',
    'com.scopely.startrek', 'com.gsn.android.tripeaks', 'com.global.ztmslg',
    'com.more.dayzsurvival.gp', 'com.tencent.ig', 'com.gramgames.mergedragons',
    'com.productmadness.cashmancasino', 'com.diandian.gog', 'net.supertreat.solitaire',
    'com.huuuge.casino.slots', 'com.diamondlife.slots.vegas.free', 'com.yottagames.mafiawar',
    'com.ddi', 'net.peakgames.amy', 'com.miHoYo.GenshinImpact', 'com.vizorapps.klondike',
    'com.playdemic.golf.android', 'com.pacificinteractive.HouseOfFun', 'com.im30.ROE.gp',
    'com.kabam.marvelbattle', 'com.topgamesinc.evony', 'com.ea.game.starwarscapital_row',
    'com.doubleugames.DoubleUCasino', 'com.scopely.yux', 'dk.tactile.lilysgarden',
    'com.playtika.wsop.gp', 'com.bandainamcogames.dbzdokkanww', 'com.Seriously.BestFiends',
    'com.crowdstar.covetHome', 'com.dc.hwsj', 'com.camelgames.superking',
    'com.lilithgame.hgame.gp', 'com.supercell.clashofclans', 'com.ludo.king',
    'com.jellybtn.boardkings', 'com.matchington.mansion', 'com.yottagames.stoneage',
    'com.com2us.smon.normal.freefull.google.kr.android.common', 'com.miniclip.carrom',
    'com.square_enix.android_googleplay.WOTVffbeww', 'com.bigfishgames.mergetalesgoog',
    'com.wb.goog.got.conquest', 'com.nintendo.zaba', 'com.productmadness.lightninglink',
    'com.zynga.pottermatch', 'com.yottagames.gameofmafia', 'com.productmadness.hovmobile',
    'com.sports.real.golf.rival.online', 'leyi.westgame', 'com.selfawaregames.acecasino',
    'com.playtika.caesarscasino', 'net.wooga.junes_journey_hidden_object_mystery_game',
    'com.huuuge.casino.texas', 'com.clipwiregames.bingostory', 'com.zynga.wizardofoz',
    'com.zynga.hititrich', 'fi.reworks.redecor', 'com.everbytestudio.escape.room.hidden.object.puzzle.games',
    'com.miniclip.eightballpool', 'com.camelgames.aoz', 'com.YoStarEN.Arknights',
    'com.MelsoftGames.FamilyIslandFarm', 'air.com.bitrhymes.bingo', 'com.grandegames.slots.dafu.casino',
    'com.king.farmheroessaga', 'com.rovio.baba', 'com.belkatechnologies.clockmaker',
    'com.ballytechnologies.quickhitslots', 'com.stove.epic7.google', 'com.tinyco.potter',
    'com.tensquaregames.letsfish2', 'com.bbgame.sgzapk.tw', 'com.williamsinteractive.goldfish',
    'com.riotgames.league.wildrift', 'com.zynga.gotslots', 'com.scopely.whiplash',
    'com.pixonic.wwr', 'com.epicactiononline.ffxv.ane', 'com.murka.scatterslots',
    'com.mojang.minecraftpe', 'com.mattel163.phase10', 'com.dragonscapes.global',
    'com.topultragame.slotlasvega', 'com.playstudios.myvegas', 'com.nexters.herowars',
    'com.wondergames.warpath.gp', 'com.glu.baseball21', 'com.hcg.cok.gp',
    'com.supercell.hayday', 'com.rovio.dream', 'com.king.candycrush4',
    'com.mars.avgchapters', 'com.panoramik.mightyparty', 'com.king.bubblewitch3',
    'com.special.warship', 'air.com.sgn.cookiejam.gp', 'com.pixelberrystudios.choices',
    'com.uken.BingoPop', 'com.bagelcode.slots1', 'jp.konami.duellinks',
    'com.king.petrescuesaga', 'com.peoplefun.wordcross', 'com.bigfishgames.jackpotcityslotsf2pgoogle',
    'com.funtomic.matchmasters', 'com.droidhang.ad', 'com.naturalmotion.customstreetracer2',
    'com.ksrgland.goat', 'com.elex.nikkigp', 'com.blizzard.wtcg.hearthstone',
    'com.zynga.livepoker', 'com.innogames.foeandroid', 'com.playstudios.mykonami',
    'com.hts.ams', 'com.wizards.mtga', 'com.disney.emojimatch_goo', 'com.gameloft.android.ANMP.GloftA9HM',
    'dk.tactile.mansionstory', 'com.global.tmslg', 'com.loop.match3d',
    'com.mytona.cookingdiary.android', 'com.igs.fafafa', 'com.square_enix.android_googleplay.FFBEWW',
    'com.playrix.manormatters', 'es.socialpoint.DragonCity', 'com.mobile.legends',
    'com.netmarble.mherosgb', 'com.dreamgames.royalmatch', 'com.gigantic.clawee',
    'com.kakaogames.gdts', 'com.sevenpirates.infinitywar', 'com.everywear.game5',
    'com.scientificgames.monopolyslots', 'com.addictive.strategy.army', 'com.king.candycrushjellysaga',
    'com.square_enix.android_googleplay.FFBEWW', 'com.moonton.mobilehero', 'com.d3p.mpq',
    'com.yalla.yallagames', 'com.scopely.headshot', 'com.miHoYo.bh3global',
    'com.ea.gp.maddennfl21mobile', 'com.plarium.vikings', 'com.gsn.android.casino',
    'com.LDRLY.budfarmidletycoon', 'com.nintendo.zaka', 'com.bbumgames.spadesroyale',
    'com.YoStarEN.AzurLane', 'com.duige.hzw.multilingual', 'and.onemt.war.ar',
    'com.supercell.brawlstars', 'com.purplekiwii.vegaslive', 'com.ea.game.simcitymobile_row',
    'com.deuscraft.TurboTeam', 'com.crowdstar.covetfashion', 'com.catdaddy.cat22',
    'net.peakgames.mobile.spades.android', 'com.sgn.pandapop.gp', 'com.bingo.tour.party.crazy.free',
    'com.aqupepgames.projectpepe', 'jp.goodsmile.grandsummonersglobal_android',
    'com.supercell.clashroyale', 'com.nintendo.zaga', 'com.mytona.seekersnotes.android',
    'com.xdg.and.wll', 'com.ludia.jw2', 'com.zynga.wonka', 'com.igg.android.dressuptimeprincess',
    'com.ballytechnologies.f88', 'com.bingo.scape.android.free', 'com.gtarcade.ioe.global',
    'com.murka.slotsera', 'com.zloong.eu.dr.gp', 'com.zynga.words3', 'com.game.colorslime',
    'com.paradyme.solarsmash', 'com.playstrom.bob', 'com.drawpuzzle.dop.drawit.justdrawit',
    'com.innersloth.spacemafia', 'com.roblox.client', 'com.uncosoft.highheels',
    'com.bgg.jump', 'com.freeplay.runandfight', 'com.pencil.madness',
    'com.tgame.girlgenius', 'com.youmusic.magictiles', 'com.gma.water.sort.puzzle',
    'com.hypercarrot.giantrush', 'com.RBSSOFT.HyperMobile', 'com.playstrom.dop2',
    'com.kiloo.subwaysurf', 'com.sdpgames.sculptpeople', 'com.amanotes.beathopper',
    'com.Born2Play.StackyDash', 'com.imangi.templerun2', 'com.ea.gp.nbamobile',
    'games.bee.app', 'com.ea.game.nfs14_row', 'com.psv.vlad_and_nikita.supermarket',
    'com.rud.twelvelocksvn', 'com.wb.goog.mkx', 'com.masomo.basketballarena',
    'pvp.survival.rpg.fog', 'com.wb.goog.injustice.brawler2017', 'com.jetstartgames.chess',
    'com.ftt.boxingstar.gl.aos', 'com.igg.castleclash', 'com.ss.clg',
    'com.conicgames.exponentialidle', 'com.funcube.loa', 'com.zynga.words',
    'com.gameloft.android.ANMP.GloftDMHM', 'com.peekaphone.app', 'com.WildWorks.RyansTag',
    'com.habby.archero', 'com.nintendo.zara', 'com.webelinx.Rooms.Exits.EscapeRoom.FreeEscapeGames',
    'com.weplaydots.twodotsandroid', 'es.socialpoint.MonsterLegends', 'ru.crazypanda.ZombieShop',
    'com.firsttouchgames.dls7', 'com.nway.powerrangerslegacywars', 'com.riotgames.league.teamfighttactics',
    'com.riotgames.legendsofruneterra', 'com.dena.a12026418', 'com.ngame.allstar.eu',
    'com.wb.goog.ellen.psych', 'com.masomo.headball2', 'com.tfgco.games.sports.free.tennis.clash',
    'com.netease.g78na.gb', 'com.kitkagames.fallbuddies', 'com.devsisters.ck',
    'com.orange.coloring.learn.kids', 'com.gameloft.android.ANMP.GloftGGHM',
    'com.ea.gp.fifamobile', 'com.yanstarstudio.joss.undercover', 'com.reliancegames.wwemayhem',
    'com.MDickie.WrestlingEmpire', 'com.wildlife.games.battle.royale.free.zooba', 
    'com.bandainamcoent.opbrww', 'com.zeptolab.bulletecho.google', 'com.PepiPlay.PepiHospital',
    'com.vkslrzm.Zombie', 'com.haegin.overdox',
    'com.elex.twdsaw.gp', 'com.time.trigger', 'com.miniclip.minifootball',
    'com.amanotes.pamadancingroad', 'com.tinybuildgames.helloneighbor',
    'com.netmarble.kofg', 'com.pikpok.wtd.play', 'ee.Javelin.SpotlightRoomEscape',
    'com.rioo.runnersubway', 'com.sinyee.babybus.policemen', 'com.madfingergames.wargames.shooter',
    'com.netease.mrzhna', 'com.titan.cd.gb', 'com.playgendary.kickthebuddy',
    'air.com.RustyLake.WhiteDoor', 'com.azurgames.stackball', 'com.pearlabyss.blackdesertm.gl',
    'com.enigma.shadowhunter', 'com.nway.wweundisputed', 'com.stealthgame.master',
    'com.steelcrategames.keeptalkingandnobodyexplodes', 'com.bc.avenger',
    'com.sleepingbeastgames.spaceteam', 'com.stickclash.stickman.battle.war',
    'com.YovoGames.dentist', 'com.appsomniacs.da2', 'lol.onevone', 'com.haegin.playtogether',
    'com.zakg.scaryteacher.hellgame', 'com.netmarble.bnsmws', 'com.yolostudio.theimpostor',
    'com.playgendary.hitmasters', 'com.sports.eightball.pool.rival', 'com.ua.building.Lokicraft',
    'com.soccer.score.star', 'com.hit.master', 'com.neowiz.game.baseball.clash',
    'en.lrgame.sr.and.sa', 'com.nintendo.zaca', 'com.allstarunion.mw3', 'com.dayonegames.puzzles',
    'com.codigames.university.empire.idle.tycoon', 'com.mavis.slidey', 'com.catdaddy.nbasupercard',
    'com.bitmango.go.wordcookies', 'com.beingame.zc.zombie.shelter.survival',
    'com.traplight.battleslides', 'com.dobsoftstudios.wizquest', 'com.nautilus.RealCricket3D',
    'com.nexonm.dominations.adk', 'com.bushiroad.en.bangdreamgbp', 'com.divmob.heroesinfinity',
    'com.divmob.ageofheroes.braveheroes.battleheroes.epicheroeswar.epicheroes.en',
    'jp.konami.wecc', 'com.pandaarcade.picotanks', 'com.bandainamcoent.saoifww',
    'com.gamegos.mobile.manorcafe', 'com.gamevil.basebss.android.google.global.normal1',
    'com.belkagames.solitaire', 'air.com.and.games505.gemsofwar', 'com.innogames.elvenar',
    'com.electricnoirstudios.deadmansphone', 'com.seasun.shuangxiang.gp',
    'com.flaregames.rrtournament', 'com.cleverapps.scramble', 'mog.Christmas.Games.Xmas.Bubble.Shooter',
    'com.gamevilusa.mlbpilive.android.google.global.normal', 'sandbox.pixel.number.coloring.book.page.art.free',
    'com.minidragon.dw', 'com.com2us.ninepb3d.normal.freefull.google.global.android.common&hl=en_US&gl=US',
    'com.zeptolab.omnomrun.google', 'com.pocapp.dungeondogsgame', 'sniper.gun.zombie.shooting',
    'com.sonypicturestelevision.sharktank', 'com.epiczone.cyberfighters.stickman.shadow',
    'jp.co.imagineer.sumikkogurashi.farm', 'com.smokoko.careatscar3', 'com.twelvemoments.musicparty',
    'com.rmg.hell.park.tycoon', 'com.pikpok.dkc.play', 'com.utplus.shadowblood.google',
    'com.wazzapps.idle.beauty.salon', 'com.ignm.bokuneko.en', 'com.redbull.moto',
    'com.hyperbeard.kiki', 'com.qiiwi.puzzleton', 'com.fufafa.slotrip.socialcasino',
    'com.tangramgames.gourddoll.wordcrush', 'com.peoplefun.wordstacks', 'com.smilerlee.klondike',
    'com.easybrain.jigsaw.puzzles', 'at.ner.SolitaireKlondike', 'com.lemongame.klondike.solitaire',
    'eu.nordeus.topeleven.android', 'com.bandagames.mpuzzle.gp', 'com.fiogonia.spades',
    'net.skillcap.spades', 'com.gsr.wordcross', 'in.playsimple.wordtrip',
    'com.mobilityware.solitaire', 'com.flyclops.domino.android', 'com.boldcat.football',
    'com.gamma.find.diff', 'com.openmygame.games.android.jigsawpuzzle', 'com.qhost.aceanddice_domino',
    'com.dp.hidden.objects', 'com.IMStudio.WOS', 'com.fungames.flightpilot',
    'uk.co.aifactory.chessfree', 'block.puzzle.sudoku.free.game.classic.offline',
    'air.br.com.domino.mobile', 'com.betterforsol.solitaire.card.games.free',
    'com.dimcoms.checkers', 'com.LoopGames.Domino', 'es.socialpoint.wordlife',
    'jigsaw.puzzle.free.games', 'com.gamedevltd.wwh', 'air.com.beachbumgammon',
    'com.autumninteractive.myrummy', 'com.tripledot.solitaire', 'pl.lukok.chess',
    'com.iscoolentertainment.snc', 'com.skgames.trafficracer', 'com.tectumgames.unblock',
    'com.com2us.acefishing.normal.freefull.google.global.android.common',
    'chessfriends.online.chess','com.hotheadgames.google.free.ks2', 'com.bitmango.rolltheballunrollme',
    'com.billiards.shooting.ball.pool', 'pl.lukok.draughts', 'com.LoopGames.Solitaire',
    'com.hypgames.ultimategolf', 'com.rbx.city.android', 'com.oyeapps.logotestworld2',
    'com.skgames.trafficrider', 'sniper.honor.real3d.shooter.assassin.free.android',
    'com.codemasters.F1Mobile', 'com.hutchgames.rebelracing', 'com.crossfield.shogi',
    'com.tripledot.woodoku', 'com.billiards.city.pool.nation.club', 'com.playgendary.homes',
    'com.giraffegames.pool', 'com.karmangames.spades', 'com.huuuge.domino', 
    'com.tensquaregames.hunting.clash.wild.hunter.deer', 'ru.skillcap.dominoes',
    'com.kooapps.pictowordandroid', 'com.jima.modern.tuktuk.auto.rickshaw.driving.game.simulator',
    'uk.co.yakuto.TableTennisTouch', 'com.blacklightsw.ludo', 'com.eyesthegame.eyes',
    'com.gameloft.android.ANMP.GloftA3HM', 'com.netease.chiji', 'com.agedstudio.board.game.dominoes',
    'com.RetrostyleGames.LastPirate.deadthieves', 'com.xten.starfall', 'roll.unblock.ball.block.puzzle',
    'mobi.gameguru.racingfevermoto', 'com.zynga.chess.googleplay', 'com.miniclip.marblebattle',
    'com.chess.champ', 'com.fa.gym.fighting.game', 'com.vividgames.realboxing',
    'com.jimaapps.city.coach.bus.simulator.driving', 'com.gamovation.quickcheckers',
    'com.giraffegames.ggpool', 'com.boombitgames.DrivingSchoolParking', 'air.WR3DFree',
    'com.hagstrom.henrik.chess', 'com.gzl.drivebus.parking.game', 'com.nautilus.RealCricket3DLite',
    'com.fun.games.commando.black.shadow', 'com.ovilex.drivingschoolsim', 'com.CrescentMoonGames.TotalEggscape',
    'com.jamcity.joy_goo', 'com.OrubeGameStudio.DwarfJourney', 'com.RDaES.Wordsmyth.Word',
    'com.Thunderbox.TCID', 'com.FinifuguGames.google.OtterOcean', 'com.bluewizard.campcarnage',
    'com.tinybuildgames.killitwithfire', 'com.umusic.queenrocktourgp', 'com.bushiroad.en.invictus',
    'com.atari.mobile.daysofdoom', 'com.lofipeople.blinddrive', 'com.neutronized.slimelaboratory',
    'com.joxdev.towers', 'com.DefaultCompany.BulletPunk', 'air.com.GalMamalya.Mitoza',
    'ru.avv.game', 'creamative.clann.v1', 'com.nomadgames.furyofdracula',
    'com.okshur.JetscoutValunians', 'com.FlorianVanStrien.TheFinalEarth2',
    'com.ylungamestudio.breakinggatespass', 'com.ea.gp.simsmobile', 'com.cookapps.redesignstar.homemakeover',
    'com.techvision.hotelcraze', 'com.kiarygames.tinyroom', 'com.unicostudio.braintest',
    'ge.bebi.balloon.pop.game', 'com.sonypicturestelevision.jeopardy2', 'com.peppapig.worldofpeppapig_g',
    'com.rvappstudios.baby.games.piano.phone.kids', 'games.lightheart.mrautofire', 
    'com.etermax.trivialadder', 'com.GMA.Ball.Sort.Puzzle', 'com.appcraft.number.puzzle',
    'org.pbskids.gamesapp', 'com.jagex.runescape.android', 'com.trivia.star.android',
    'com.redcell.goldandgoblins', 'com.maroieqrwlk.unpin', 'com.candywriter.bitlife',
    'com.hitthebank.game', 'com.mochibits.google.leftvsright', 'com.braindom2riddle',
    'com.BeanstarGamesInc.WordGames', 'com.umi.feudlive', 'com.fiogonia.hearts',
    'com.gma.water.connect.puzzle', 'com.nanotribe.games.cashier3d', 'com.ASmallGame.themagicfinger',
    'com.slingshot.car', 'com.gameon.car.safety.check', 'com.bike.jump',
    'com.rmg.hotelteam', 'com.hasbro.riskbigscreen', 'com.bricksbreaker.balls.crusher.bricks',
    'air.com.pixelfederation.diggy', 'com.paperboatapps.google.kiddopia',
    'com.volcanoforce.lost', 'zombie.survival.craft.z', 'com.braindom', 
    'link.merge.puzzle.onnect.number', 'com.fanatee.stop', 'com.easybrain.find.the.difference',
    'com.haiku.adventure.escape.game.mystery.stories', 'com.colobolo.chainball',
    'com.dropdom.blockpuzzle.hwwgame', 'com.scopely.wheeloffortune', 'com.ubisoft.dance.justdance2015companion',
    'com.easybrain.killer.sudoku.free', 'com.usm.catanuniverse', 'com.wordgame.words.connect',
    'com.wordgame.newcross.android.en', 'com.bitmango.go.mergeblockstarfinders', 
    'com.glu.dashtown', 'com.tilemaster.puzzle.block.match', 'com.platinumplayer.word.addict',
    'com.my.defense', 'com.upland.app', 'com.gamebility.onet', 'com.easybrain.block.puzzle.games',
    'com.peoplefun.blockscapes', 'com.ferrero.applayduGP', 'com.littleengine.wordpal',
    'com.iposedon.bricksbreakerballs', 'com.jagex.oldscape.android', 'gen.tech.keiki.world.learning',
    'com.foxbet.super6', 'com.preschoolacademy.toddlerpreschoollearning', 'com.gokids.livenumbers',
    'com.rvappstudios.abc_kids_toddler_tracing_phonics', 'com.rvappstudios.shapes.colors.toddler',
    'com.pjmasks.moonlightheroes', 'com.sinyee.babybus.habits', 'com.budgestudios.googleplay.MyLittlePonyRainbowRunners',
    'com.sesameworkshop.alphabetkitchen.play', 'com.happytools.learning.kids.games',
    'com.rickyzoom.welcometowheelford', 'com.budgestudios.googleplay.MyLittlePonyColoring',
    'com.binibambini.abc', 'com.iabuzz.minigames.dino', 'com.pjmasks.heroacademy',
    'com.imaginalis.HouseFlipperMobile', 'com.budgestudios.googleplay.ThomasAndFriendsMinis',
    'com.sinyee.babybus.career', 'com.bubadu.bubbu', 'com.JindoBlu.TwoPlayerGamesChallenge',
    'com.kids.preschool.learning.games', 'com.tutotoons.app.smolsiesmycutepethouse.free',
    'com.dhxmedia.slugitout2', 'com.gokids.transportbuilding', 'com.budgestudios.googleplay.DCSuperHeroGirls',
    'com.sinyee.babybus.foodstory', 'com.sinyee.babybus.rescueII', 'com.sinyee.babybus.adventure',
    'biz.arrowstar.funnyfood2', 'com.sinyee.babybus.dinosaurIII', 'com.rvappstudios.kids.coloring.book.color.painting',
    'com.rvappstudios.numbers123.toddler.counting.tracing', 'com.sinyee.babybus.princessII', 
    'com.budgestudios.TransformersRescueBotsHeroAdventures', 'com.sinyee.babybus.firemanII',
    'com.sinyee.babybus.diyII', 'biz.arrowstar.funnyfood3', 'com.sinyee.babybus.homesafe.global',
    'com.sinyee.babybus.cosmetology', 'com.budgestudios.googleplay.TransformersDisasterDash',
    'com.crayolallc.crayola_scribble_scrubbie_pets', 'com.tutotoons.app.mybabyunicorn.free',
    'com.orange.gamesforkids.coloring.princess', 'com.sinyee.babybus.tailor',
    'com.sinyee.babybus.colour', 'com.budgestudios.googleplay.BarbieDreamhouse',
    'com.wb.goog.legoswtfa', 'com.edujoy.kidecats', 'com.gameloft.android.ANMP.GloftPOHM',
    'mytown.home', 'com.razmobi.kidsdinosaurgame','com.rvappstudios.jigsaw.puzzles.kids',
    'com.razmobi.monstertrucks2', 'com.budgestudios.MyLittlePonyHarmonyQuest',
    'com.sinyee.babybus.kindergartenII', 'com.budgestudios.HelloKittyLunchBox',
    'com.sinyee.babybus.hero', 'com.turborocketgames.wildcraft', 'mytown.firestation.free',
    'com.PepiPlay.KingsCastle', 'com.sinyee.babybus.restaurant', 'com.budgestudios.HelloKittyNailSalon',
    'com.rvappstudios.abc.spelling.toddler.spell.phonics', 'com.sinyee.babybus.superman',
    'com.budgestudios.googleplay.HotWheelsUnlimited', 'com.tutotoons.app.sweetbabygirlcleanup5.free',
    'com.sinyee.babybus.designer', 'com.lego.friends.heartlake', 'com.sinyee.babybus.careII',
    'mytown.hauntedhouse.free', 'com.sinyee.babybus.dentistII', 'com.sinyee.babybus.shopping',
    'com.sinyee.babybus.kitchens', 'com.edujoy.masha.games', 'com.kidsfoodinc.unicorn.cooking.game',
    'com.rvappstudios.math.kids.counting', 'com.tutotoons.app.kikififipetfriends.free',
    'com.bubadu.bubbuschool', 'com.sinyee.babybus.drinks', 'com.oki.colors',
    'mytown.police', 'mytown.amusementpark.free', 'com.budgestudios.googleplay.hellokittyfashionstar',
    'com.bubadu.supermarket', 'com.tabtale.babytwins', 'com.gi.talkinggummybear', 
    'com.pepiplay.pepihome', 'com.infigames.babyphonetoy', 'com.gokids.tablet', 
    'com.spinmaster.gabbysdollhouse', 'babyphone.freebabygames.com.babyphone',
    'com.sinyee.babybus.earthquake', 'com.sinyee.babybus.magichouse', 'com.tutotoons.app.kpopsiescuteunicornpets',
    'com.sinyee.babybus.market', 'com.sinyee.babybus.pen', 'com.hasbro.beybladesenterprise',
    'com.iz.world.pretend.play.life.my.princess.games.town.city.house.wonder.doll',
    'com.sinyee.babybus.math', 'com.psvnMaB.Goodnight', 'com.animedressupgames.chibi',
    'com.tutotoons.app.mybabyunicorn2.free', 'com.sinyee.babybus.holiday',
    'com.GamesForKids.Mathgames.MultiplicationTables', 'com.binibambini.MiniLite',
    'com.playtoddlers.urbancitystories.free', 'com.aquiris.horizonchase', 
    'com.gamesforkids.preschoolworksheets.alphabets', 'br.com.tapps.donotdisturb',
    'com.kid58.lianyong.princessIII', 'com.gokids.bphone1', 'mytown.preschool.free',
    'com.KidsGames.SuperHippo', 'com.devgame.masha.and.bear.pizzeria.games',
    'com.forqan.tech.PrincessColoring', 'com.kidgame.supermarket', 'com.psvn.traumatologist',
    'com.iz.coloring.games.kids.drawing.book.color.by.number', 'mytown.wedding.free',
    'wedding.games', 'com.indigokids.mim', 'com.minibuu.princessphone',
    'com.edutainment.mashadentist', 'mytown.grandparents.free', 'com.psv.vlad_and_nikita.racing',
    'com.coloring.mermaids', 'com.princess.coloring', 'com.iz.pretend.play.my.monster.town.airport.games.kids',
    'mytown.cinema.free', 'com.devgame.robocar.poli.postman.kids.games', 'com.Metrafilms.KidECatsDollHouse',
    'com.gamesforgirlsfree.dressupgames'
]

# %%
len(app_packages)
# Out:
# 914

# %%
for number, letter in enumerate(app_packages):
    print((number), letter)
# Out:
# 0 com.robtopx.geometryjump
# 1 com.marmalade.monopoly
# 2 com.chucklefish.stardewvalley
# 3 com.and.games505.TerrariaPaid
# 4 com.clickteam.ultimatecustomnight
# 5 com.rockstargames.gtasa
# 6 net.kairosoft.android.bouken2
# 7 com.playdead.limbo.full
# 8 eu.bandainamcoent.verylittlenightmares
# 9 com.marmalade.gol2
# 10 com.scottgames.fnaf2
# 11 com.and.games505.humanfallflat
# 12 com.scottgames.sisterlocation
# 13 com.dsemu.drastic
# 14 com.scottgames.fnaf4
# 15 com.FireproofStudios.TheRoom
# 16 com.clickteam.freddyfazbearspizzeriasimulator
# 17 com.prpr.musedash
# 18 com.humble.SlayTheSpire
# 19 com.rockstargames.gtavc
# 20 com.fastemulator.gba
# 21 com.ninjakiwi.bloonstd5
# 22 com.topgames100.ClassicSolitaireTycoon
# 23 com.trueaxis.trueskate
# 24 com.squareenixmontreal.hitmansniperandroid
# 25 com.sofarsogood.incredibox
# 26 com.activision.boz
# 27 com.marmalade.golmobile
# 28 com.playdigious.deadcells.mobile
# 29 com.steelwoolgames.fnaf.hw
# 30 com.explodingkittens.projectbombsquad
# 31 com.scottgames.fnaf3
# 32 it.rortos.realflightsimulator
# 33 com.marmalade.cluedogame
# 34 com.wb.goog.scribbleremix
# 35 com.giantssoftware.fs20.google
# 36 com.ubisoft.assassinscreed.identity
# 37 com.fizzd.connectedworlds
# 38 air.com.flipline.papasmochariatogo
# 39 com.piratesoutlaws.fabledgame
# 40 com.wb.goog.scribblenauts3
# 41 com.jds.batim
# 42 com.topgames100.angry.knife
# 43 com.robotgentleman.game60seconds
# 44 com.corrodinggames.rts
# 45 com.t2ksports.nba2k20and
# 46 com.atari.mobile.rctclassic
# 47 com.rockstar.gta3
# 48 com.humblebundle.forager
# 49 air.com.flipline.papasfreezeriatogo
# 50 com.DMAP.Ting_WD
# 51 com.square_enix.android_googleplay.FFVIII
# 52 com.headupgames.bridgeconstructorportal
# 53 com.babotech.NOHA
# 54 com.greenheartgames.gdt
# 55 com.ironhidegames.android.kingdomrushfrontiers
# 56 com.FireproofStudios.TheRoom2
# 57 com.fastemulator.gbc
# 58 com.fds.infiniteflight
# 59 com.ea.games.nfs13_na
# 60 com.coffeestainstudios.goatsimulator
# 61 com.rockstargames.bully
# 62 com.ironhidegames.android.ironmarines
# 63 com.FireproofStudios.TheRoom4
# 64 com.wb.lego.marvel
# 65 com.square_enix.android_googleplay.chrono
# 66 com.ustwo.monumentvalley
# 67 com.bluebraingames.houseofdavinci2
# 68 com.FireproofStudios.TheRoom3
# 69 com.mazetheory.dwla
# 70 com.wb.goog.legojurassicworld
# 71 com.codebrewgames.pocketcitygame
# 72 com.MontanaGames.Lowriders.Comeback2
# 73 com.PlausibleConcept.BadNorthFull
# 74 com.etermax.preguntados.pro
# 75 com.aspyr.swkotorii
# 76 com.damonplay.damonps2.pro.ppsspp
# 77 com.feralinteractive.rometw
# 78 com.D3Go.mendel
# 79 com.giantssoftware.fs18.google
# 80 com.square_enix.android_googleplay.FFT_en2
# 81 com.bethsoft.DOOM
# 82 com.aspyr.swkotor
# 83 com.eamobile.nbajam_na_wf
# 84 com.rockstar.maxpayne
# 85 jp.konami.epjCastlevania2
# 86 com.tocaboca.tocaboo
# 87 com.ironhidegames.android.kingdomrushorigins
# 88 com.ironhidegames.android.kingdomrush4
# 89 com.KiotGames.BasketballPusher
# 90 com.bluebraingames.thehouseofdavinci
# 91 com.coffeestainstudios.goatsimulator.payday
# 92 com.pixelcurves.terlauncher
# 93 com.square_enix.android_googleplay.FFVII
# 94 it.dbtecno.pizzaboygbapro
# 95 com.kleientertainment.doNotStarvePocket
# 96 uk.co.aifactory.chess
# 97 air.com.flipline.papassushiriatogo
# 98 com.marmalade.golv
# 99 com.noodlecake.gettingoverit
# 100 com.wb.goog.lnjgo
# 101 com.halfbrick.fruitninja
# 102 com.tocaboca.tocamysteryhouse
# 103 com.Majorariatto.Pureya
# 104 com.bowengames.farmingusa2
# 105 air.com.flipline.papasdonuteriatogo
# 106 com.tocaboca.tocalabplants
# 107 com.rockstargames.gtactw
# 108 com.mlb.RBIBaseball21
# 109 net.kairosoft.android.boxing
# 110 org.ppsspp.ppssppgold
# 111 com.disney.WMW
# 112 com.playdigious.cultist
# 113 air.com.flipline.papasburgeriatogo
# 114 com.ustwo.monumentvalley2
# 115 com.beamdog.pstee
# 116 com.bennettracingsimulations.dirttrackin2
# 117 com.focushome.MudRunnerAndroid
# 118 com.kiotgames.dripme
# 119 com.turner.ttgfigures2
# 120 com.newgeogamerni
# 121 com.gameloft.android.ANMP.GloftICHM
# 122 com.square_enix.android_googleplay.dq1_gp
# 123 com.tipsworks.android.pascalswager.google
# 124 com.nekki.vector.paid
# 125 mycity.hospital
# 126 air.com.flipline.papaspizzeriatogo
# 127 com.team17.escapists2
# 128 com.wb.goog.lbbg
# 129 com.EtherGaming.PocketRoguesUltimate
# 130 com.disney.castleofillusion_goo
# 131 com.feralinteractive.companyofheroes_android
# 132 com.agaming.thesun.origin
# 133 joybits.doodlegod
# 134 nz.co.codepoint.minimetro
# 135 jp.co.capcom.mhsspen
# 136 com.daysofwonder.tt.android
# 137 com.younghorses.octodad
# 138 com.rockstargames.gtalcs
# 139 com.ngmoco.pocketgod
# 140 com.hg.bfbb
# 141 air.com.flipline.papaswingeriatogo
# 142 com.maguni.geoguessr
# 143 mycity.friendshouse
# 144 com.AngryNeighbor
# 145 com.refineryproductions_2112td
# 146 air.com.flipline.papasbakeriatogo
# 147 com.hammerfall.regicide
# 148 com.splashworks.pawsomedays
# 149 com.drycactus.polybridge2
# 150 air.com.flipline.papasscooperiatogo
# 151 air.com.flipline.papascheeseriatogo
# 152 com.tresebrothers.games.startraders2
# 153 com.kalypsomedia.projecthighrise
# 154 com.jds.batds
# 155 com.sega.sonic4epi
# 156 com.infinitygames.packageinc
# 157 com.johnemulators.johngba
# 158 brownmonster.app.game.rushrally3
# 159 com.tt2kgames.xcomew
# 160 com.notdoppler.earntodie
# 161 com.jdroid.gtasacheater
# 162 air.com.flipline.papaspancakeriatogo
# 163 air.com.RustyLake.RustyLakeHotel
# 164 com.turner.ttgfigures
# 165 ilmfinity.evocreo.main.android
# 166 com.turner.stevenrpg
# 167 com.sega.score
# 168 com.uplayonline.youtubers
# 169 com.playdigious.dungeonoftheendless
# 170 com.mageeks.android.trucksimulatorpro2
# 171 com.pockettrend.neomonsters
# 172 mytown.airport
# 173 com.drycactus.polybridge
# 174 air.com.flipline.papashotdoggeriatogo
# 175 com.beamdog.baldursgateenhancededition
# 176 com.teachyourmonstertoread.tmapp
# 177 com.coffeestainstudios.goatsimulator.mmo
# 178 com.NamcoNetworks.MsPacMan
# 179 com.tinybuild.graveyardkeeper
# 180 com.ninetailgames.roguehearts.paid
# 181 com.nekki.shadowfight2.paid
# 182 com.astragon.cs3
# 183 co.uk.wixgames.ducklifebattle
# 184 air.com.flipline.papaspastariatogo
# 185 mycity.pjparty
# 186 air.com.flipline.papascupcakeriatogo
# 187 com.jutsugames.operator911
# 188 com.devolver.spaceplan
# 189 com.feralinteractive.gridas
# 190 com.khg.doorkickers
# 191 com.superpsx.pro
# 192 air.com.flipline.papastacomiatogo
# 193 com.coffeestainstudios.goatsimulator.wasteofspace
# 194 com.devolver.reigns
# 195 com.king.crash
# 196 com.sega.sonic2.runner
# 197 com.sega.sonicdash
# 198 com.sega.soniccd.classic
# 199 com.outfit7.mytalkingtomfree
# 200 com.outfit7.mytalkingtom2
# 201 com.dancing.smash.hop.game.tiles.circles.beat.paino
# 202 com.playgendary.tom
# 203 com.tocaboca.tocakitchen2
# 204 com.sega.sonicboomandroid
# 205 com.Earthkwak.Platformer
# 206 com.sega.sprint
# 207 com.aim.racing
# 208 com.outfit7.mytalkingtomfriends
# 209 com.fungames.blockcraft
# 210 com.outfit7.mytalkingangelafree
# 211 com.sinyee.babybus.taxi
# 212 com.outfit7.talkingtomgoldrun
# 213 com.crazylabs.lady.bug
# 214 com.illumix.fnafar
# 215 com.stickman.dragon.fight.stick.warriors.stickmanwarriors
# 216 mytown.friendshouse.free
# 217 mytown.hotel.free
# 218 com.tutotoons.app.fluvsies.free
# 219 com.sinyee.babybus.world
# 220 com.PoxelStudios.DudeTheftAuto
# 221 com.Neurononfire.SupremeDuelist
# 222 com.stickman.warriors.stickwarriors.dragon.shadow.fight
# 223 smellymoo.sand
# 224 com.dancing.tiles.magic.music.beat.saber
# 225 com.tocaboca.tocalifeworld
# 226 free.os.jump.superbros.adventure.world
# 227 net.mobigame.zombietsunami
# 228 com.orange.kidspiano.music.songs
# 229 com.bandainamcoent.dblegends_ww
# 230 com.wildspike.wormszone
# 231 com.fgol.HungrySharkEvolution
# 232 jp.pokemon.pokemonquest
# 233 com.fungames.sniper3d
# 234 com.movile.playkids.pkxd
# 235 com.ea.game.pvzfree_row
# 236 com.frojo.moy7
# 237 com.dts.freefireth
# 238 com.bandainamcogames.dbzdokkanww
# 239 com.europosit.pixelcoloring
# 240 com.maxgames.stickwarlegacy
# 241 com.activision.callofduty.shooter
# 242 com.dreamotion.ronin
# 243 com.halfbrick.dantheman
# 244 com.PlayMax.playergames
# 245 com.playmini.miniworld
# 246 com.pixel.gun3d
# 247 com.netmarble.nanagb
# 248 com.JindoBlu.Antistress
# 249 com.klab.bleach
# 250 com.moonfrog.ludo.club
# 251 com.wildlifestudios.free.online.games.suspects
# 252 com.igg.android.lordsmobile
# 253 com.moonactive.coinmaster
# 254 com.king.candycrushsaga
# 255 com.aladinfun.islandking.android
# 256 com.nianticlabs.pokemongo
# 257 com.nekki.shadowfight
# 258 air.com.buffalo_studios.newflashbingo
# 259 com.playrix.homescapes
# 260 com.plarium.raidlegends
# 261 com.playrix.gardenscapes
# 262 com.aniplex.fategrandorder.en
# 263 com.king.candycrushsodasaga
# 264 com.smallgiantgames.empires
# 265 com.topwar.gp
# 266 air.com.playtika.slotomania
# 267 com.foxnextgames.m3
# 268 com.playrix.fishdomdd.gplay
# 269 net.peakgames.toonblast
# 270 com.williamsinteractive.jackpotparty
# 271 com.funplus.kingofavalon
# 272 com.playrix.township
# 273 slots.pcg.casino.games.free.android
# 274 com.chess
# 275 com.lilithgame.roc.gp
# 276 com.playstudios.popslots
# 277 com.nekki.shadowfight3
# 278 com.scopely.startrek
# 279 com.gsn.android.tripeaks
# 280 com.global.ztmslg
# 281 com.more.dayzsurvival.gp
# 282 com.tencent.ig
# 283 com.gramgames.mergedragons
# 284 com.productmadness.cashmancasino
# 285 com.diandian.gog
# 286 net.supertreat.solitaire
# 287 com.huuuge.casino.slots
# 288 com.diamondlife.slots.vegas.free
# 289 com.yottagames.mafiawar
# 290 com.ddi
# 291 net.peakgames.amy
# 292 com.miHoYo.GenshinImpact
# 293 com.vizorapps.klondike
# 294 com.playdemic.golf.android
# 295 com.pacificinteractive.HouseOfFun
# 296 com.im30.ROE.gp
# 297 com.kabam.marvelbattle
# 298 com.topgamesinc.evony
# 299 com.ea.game.starwarscapital_row
# 300 com.doubleugames.DoubleUCasino
# 301 com.scopely.yux
# 302 dk.tactile.lilysgarden
# 303 com.playtika.wsop.gp
# 304 com.bandainamcogames.dbzdokkanww
# 305 com.Seriously.BestFiends
# 306 com.crowdstar.covetHome
# 307 com.dc.hwsj
# 308 com.camelgames.superking
# 309 com.lilithgame.hgame.gp
# 310 com.supercell.clashofclans
# 311 com.ludo.king
# 312 com.jellybtn.boardkings
# 313 com.matchington.mansion
# 314 com.yottagames.stoneage
# 315 com.com2us.smon.normal.freefull.google.kr.android.common
# 316 com.miniclip.carrom
# 317 com.square_enix.android_googleplay.WOTVffbeww
# 318 com.bigfishgames.mergetalesgoog
# 319 com.wb.goog.got.conquest
# 320 com.nintendo.zaba
# 321 com.productmadness.lightninglink
# 322 com.zynga.pottermatch
# 323 com.yottagames.gameofmafia
# 324 com.productmadness.hovmobile
# 325 com.sports.real.golf.rival.online
# 326 leyi.westgame
# 327 com.selfawaregames.acecasino
# 328 com.playtika.caesarscasino
# 329 net.wooga.junes_journey_hidden_object_mystery_game
# 330 com.huuuge.casino.texas
# 331 com.clipwiregames.bingostory
# 332 com.zynga.wizardofoz
# 333 com.zynga.hititrich
# 334 fi.reworks.redecor
# 335 com.everbytestudio.escape.room.hidden.object.puzzle.games
# 336 com.miniclip.eightballpool
# 337 com.camelgames.aoz
# 338 com.YoStarEN.Arknights
# 339 com.MelsoftGames.FamilyIslandFarm
# 340 air.com.bitrhymes.bingo
# 341 com.grandegames.slots.dafu.casino
# 342 com.king.farmheroessaga
# 343 com.rovio.baba
# 344 com.belkatechnologies.clockmaker
# 345 com.ballytechnologies.quickhitslots
# 346 com.stove.epic7.google
# 347 com.tinyco.potter
# 348 com.tensquaregames.letsfish2
# 349 com.bbgame.sgzapk.tw
# 350 com.williamsinteractive.goldfish
# 351 com.riotgames.league.wildrift
# 352 com.zynga.gotslots
# 353 com.scopely.whiplash
# 354 com.pixonic.wwr
# 355 com.epicactiononline.ffxv.ane
# 356 com.murka.scatterslots
# 357 com.mojang.minecraftpe
# 358 com.mattel163.phase10
# 359 com.dragonscapes.global
# 360 com.topultragame.slotlasvega
# 361 com.playstudios.myvegas
# 362 com.nexters.herowars
# 363 com.wondergames.warpath.gp
# 364 com.glu.baseball21
# 365 com.hcg.cok.gp
# 366 com.supercell.hayday
# 367 com.rovio.dream
# 368 com.king.candycrush4
# 369 com.mars.avgchapters
# 370 com.panoramik.mightyparty
# 371 com.king.bubblewitch3
# 372 com.special.warship
# 373 air.com.sgn.cookiejam.gp
# 374 com.pixelberrystudios.choices
# 375 com.uken.BingoPop
# 376 com.bagelcode.slots1
# 377 jp.konami.duellinks
# 378 com.king.petrescuesaga
# 379 com.peoplefun.wordcross
# 380 com.bigfishgames.jackpotcityslotsf2pgoogle
# 381 com.funtomic.matchmasters
# 382 com.droidhang.ad
# 383 com.naturalmotion.customstreetracer2
# 384 com.ksrgland.goat
# 385 com.elex.nikkigp
# 386 com.blizzard.wtcg.hearthstone
# 387 com.zynga.livepoker
# 388 com.innogames.foeandroid
# 389 com.playstudios.mykonami
# 390 com.hts.ams
# 391 com.wizards.mtga
# 392 com.disney.emojimatch_goo
# 393 com.gameloft.android.ANMP.GloftA9HM
# 394 dk.tactile.mansionstory
# 395 com.global.tmslg
# 396 com.loop.match3d
# 397 com.mytona.cookingdiary.android
# 398 com.igs.fafafa
# 399 com.square_enix.android_googleplay.FFBEWW
# 400 com.playrix.manormatters
# 401 es.socialpoint.DragonCity
# 402 com.mobile.legends
# 403 com.netmarble.mherosgb
# 404 com.dreamgames.royalmatch
# 405 com.gigantic.clawee
# 406 com.kakaogames.gdts
# 407 com.sevenpirates.infinitywar
# 408 com.everywear.game5
# 409 com.scientificgames.monopolyslots
# 410 com.addictive.strategy.army
# 411 com.king.candycrushjellysaga
# 412 com.square_enix.android_googleplay.FFBEWW
# 413 com.moonton.mobilehero
# 414 com.d3p.mpq
# 415 com.yalla.yallagames
# 416 com.scopely.headshot
# 417 com.miHoYo.bh3global
# 418 com.ea.gp.maddennfl21mobile
# 419 com.plarium.vikings
# 420 com.gsn.android.casino
# 421 com.LDRLY.budfarmidletycoon
# 422 com.nintendo.zaka
# 423 com.bbumgames.spadesroyale
# 424 com.YoStarEN.AzurLane
# 425 com.duige.hzw.multilingual
# 426 and.onemt.war.ar
# 427 com.supercell.brawlstars
# 428 com.purplekiwii.vegaslive
# 429 com.ea.game.simcitymobile_row
# 430 com.deuscraft.TurboTeam
# 431 com.crowdstar.covetfashion
# 432 com.catdaddy.cat22
# 433 net.peakgames.mobile.spades.android
# 434 com.sgn.pandapop.gp
# 435 com.bingo.tour.party.crazy.free
# 436 com.aqupepgames.projectpepe
# 437 jp.goodsmile.grandsummonersglobal_android
# 438 com.supercell.clashroyale
# 439 com.nintendo.zaga
# 440 com.mytona.seekersnotes.android
# 441 com.xdg.and.wll
# 442 com.ludia.jw2
# 443 com.zynga.wonka
# 444 com.igg.android.dressuptimeprincess
# 445 com.ballytechnologies.f88
# 446 com.bingo.scape.android.free
# 447 com.gtarcade.ioe.global
# 448 com.murka.slotsera
# 449 com.zloong.eu.dr.gp
# 450 com.zynga.words3
# 451 com.game.colorslime
# 452 com.paradyme.solarsmash
# 453 com.playstrom.bob
# 454 com.drawpuzzle.dop.drawit.justdrawit
# 455 com.innersloth.spacemafia
# 456 com.roblox.client
# 457 com.uncosoft.highheels
# 458 com.bgg.jump
# 459 com.freeplay.runandfight
# 460 com.pencil.madness
# 461 com.tgame.girlgenius
# 462 com.youmusic.magictiles
# 463 com.gma.water.sort.puzzle
# 464 com.hypercarrot.giantrush
# 465 com.RBSSOFT.HyperMobile
# 466 com.playstrom.dop2
# 467 com.kiloo.subwaysurf
# 468 com.sdpgames.sculptpeople
# 469 com.amanotes.beathopper
# 470 com.Born2Play.StackyDash
# 471 com.imangi.templerun2
# 472 com.ea.gp.nbamobile
# 473 games.bee.app
# 474 com.ea.game.nfs14_row
# 475 com.psv.vlad_and_nikita.supermarket
# 476 com.rud.twelvelocksvn
# 477 com.wb.goog.mkx
# 478 com.masomo.basketballarena
# 479 pvp.survival.rpg.fog
# 480 com.wb.goog.injustice.brawler2017
# 481 com.jetstartgames.chess
# 482 com.ftt.boxingstar.gl.aos
# 483 com.igg.castleclash
# 484 com.ss.clg
# 485 com.conicgames.exponentialidle
# 486 com.funcube.loa
# 487 com.zynga.words
# 488 com.gameloft.android.ANMP.GloftDMHM
# 489 com.peekaphone.app
# 490 com.WildWorks.RyansTag
# 491 com.habby.archero
# 492 com.nintendo.zara
# 493 com.webelinx.Rooms.Exits.EscapeRoom.FreeEscapeGames
# 494 com.weplaydots.twodotsandroid
# 495 es.socialpoint.MonsterLegends
# 496 ru.crazypanda.ZombieShop
# 497 com.firsttouchgames.dls7
# 498 com.nway.powerrangerslegacywars
# 499 com.riotgames.league.teamfighttactics
# 500 com.riotgames.legendsofruneterra
# 501 com.dena.a12026418
# 502 com.ngame.allstar.eu
# 503 com.wb.goog.ellen.psych
# 504 com.masomo.headball2
# 505 com.tfgco.games.sports.free.tennis.clash
# 506 com.netease.g78na.gb
# 507 com.kitkagames.fallbuddies
# 508 com.devsisters.ck
# 509 com.orange.coloring.learn.kids
# 510 com.gameloft.android.ANMP.GloftGGHM
# 511 com.ea.gp.fifamobile
# 512 com.yanstarstudio.joss.undercover
# 513 com.reliancegames.wwemayhem
# 514 com.MDickie.WrestlingEmpire
# 515 com.wildlife.games.battle.royale.free.zooba
# 516 com.bandainamcoent.opbrww
# 517 com.zeptolab.bulletecho.google
# 518 com.PepiPlay.PepiHospital
# 519 com.vkslrzm.Zombie
# 520 com.haegin.overdox
# 521 com.elex.twdsaw.gp
# 522 com.time.trigger
# 523 com.miniclip.minifootball
# 524 com.amanotes.pamadancingroad
# 525 com.tinybuildgames.helloneighbor
# 526 com.netmarble.kofg
# 527 com.pikpok.wtd.play
# 528 ee.Javelin.SpotlightRoomEscape
# 529 com.rioo.runnersubway
# 530 com.sinyee.babybus.policemen
# 531 com.madfingergames.wargames.shooter
# 532 com.netease.mrzhna
# 533 com.titan.cd.gb
# 534 com.playgendary.kickthebuddy
# 535 air.com.RustyLake.WhiteDoor
# 536 com.azurgames.stackball
# 537 com.pearlabyss.blackdesertm.gl
# 538 com.enigma.shadowhunter
# 539 com.nway.wweundisputed
# 540 com.stealthgame.master
# 541 com.steelcrategames.keeptalkingandnobodyexplodes
# 542 com.bc.avenger
# 543 com.sleepingbeastgames.spaceteam
# 544 com.stickclash.stickman.battle.war
# 545 com.YovoGames.dentist
# 546 com.appsomniacs.da2
# 547 lol.onevone
# 548 com.haegin.playtogether
# 549 com.zakg.scaryteacher.hellgame
# 550 com.netmarble.bnsmws
# 551 com.yolostudio.theimpostor
# 552 com.playgendary.hitmasters
# 553 com.sports.eightball.pool.rival
# 554 com.ua.building.Lokicraft
# 555 com.soccer.score.star
# 556 com.hit.master
# 557 com.neowiz.game.baseball.clash
# 558 en.lrgame.sr.and.sa
# 559 com.nintendo.zaca
# 560 com.allstarunion.mw3
# 561 com.dayonegames.puzzles
# 562 com.codigames.university.empire.idle.tycoon
# 563 com.mavis.slidey
# 564 com.catdaddy.nbasupercard
# 565 com.bitmango.go.wordcookies
# 566 com.beingame.zc.zombie.shelter.survival
# 567 com.traplight.battleslides
# 568 com.dobsoftstudios.wizquest
# 569 com.nautilus.RealCricket3D
# 570 com.nexonm.dominations.adk
# 571 com.bushiroad.en.bangdreamgbp
# 572 com.divmob.heroesinfinity
# 573 com.divmob.ageofheroes.braveheroes.battleheroes.epicheroeswar.epicheroes.en
# 574 jp.konami.wecc
# 575 com.pandaarcade.picotanks
# 576 com.bandainamcoent.saoifww
# 577 com.gamegos.mobile.manorcafe
# 578 com.gamevil.basebss.android.google.global.normal1
# 579 com.belkagames.solitaire
# 580 air.com.and.games505.gemsofwar
# 581 com.innogames.elvenar
# 582 com.electricnoirstudios.deadmansphone
# 583 com.seasun.shuangxiang.gp
# 584 com.flaregames.rrtournament
# 585 com.cleverapps.scramble
# 586 mog.Christmas.Games.Xmas.Bubble.Shooter
# 587 com.gamevilusa.mlbpilive.android.google.global.normal
# 588 sandbox.pixel.number.coloring.book.page.art.free
# 589 com.minidragon.dw
# 590 com.com2us.ninepb3d.normal.freefull.google.global.android.common&hl=en_US&gl=US
# 591 com.zeptolab.omnomrun.google
# 592 com.pocapp.dungeondogsgame
# 593 sniper.gun.zombie.shooting
# 594 com.sonypicturestelevision.sharktank
# 595 com.epiczone.cyberfighters.stickman.shadow
# 596 jp.co.imagineer.sumikkogurashi.farm
# 597 com.smokoko.careatscar3
# 598 com.twelvemoments.musicparty
# 599 com.rmg.hell.park.tycoon
# 600 com.pikpok.dkc.play
# 601 com.utplus.shadowblood.google
# 602 com.wazzapps.idle.beauty.salon
# 603 com.ignm.bokuneko.en
# 604 com.redbull.moto
# 605 com.hyperbeard.kiki
# 606 com.qiiwi.puzzleton
# 607 com.fufafa.slotrip.socialcasino
# 608 com.tangramgames.gourddoll.wordcrush
# 609 com.peoplefun.wordstacks
# 610 com.smilerlee.klondike
# 611 com.easybrain.jigsaw.puzzles
# 612 at.ner.SolitaireKlondike
# 613 com.lemongame.klondike.solitaire
# 614 eu.nordeus.topeleven.android
# 615 com.bandagames.mpuzzle.gp
# 616 com.fiogonia.spades
# 617 net.skillcap.spades
# 618 com.gsr.wordcross
# 619 in.playsimple.wordtrip
# 620 com.mobilityware.solitaire
# 621 com.flyclops.domino.android
# 622 com.boldcat.football
# 623 com.gamma.find.diff
# 624 com.openmygame.games.android.jigsawpuzzle
# 625 com.qhost.aceanddice_domino
# 626 com.dp.hidden.objects
# 627 com.IMStudio.WOS
# 628 com.fungames.flightpilot
# 629 uk.co.aifactory.chessfree
# 630 block.puzzle.sudoku.free.game.classic.offline
# 631 air.br.com.domino.mobile
# 632 com.betterforsol.solitaire.card.games.free
# 633 com.dimcoms.checkers
# 634 com.LoopGames.Domino
# 635 es.socialpoint.wordlife
# 636 jigsaw.puzzle.free.games
# 637 com.gamedevltd.wwh
# 638 air.com.beachbumgammon
# 639 com.autumninteractive.myrummy
# 640 com.tripledot.solitaire
# 641 pl.lukok.chess
# 642 com.iscoolentertainment.snc
# 643 com.skgames.trafficracer
# 644 com.tectumgames.unblock
# 645 com.com2us.acefishing.normal.freefull.google.global.android.common
# 646 chessfriends.online.chess
# 647 com.hotheadgames.google.free.ks2
# 648 com.bitmango.rolltheballunrollme
# 649 com.billiards.shooting.ball.pool
# 650 pl.lukok.draughts
# 651 com.LoopGames.Solitaire
# 652 com.hypgames.ultimategolf
# 653 com.rbx.city.android
# 654 com.oyeapps.logotestworld2
# 655 com.skgames.trafficrider
# 656 sniper.honor.real3d.shooter.assassin.free.android
# 657 com.codemasters.F1Mobile
# 658 com.hutchgames.rebelracing
# 659 com.crossfield.shogi
# 660 com.tripledot.woodoku
# 661 com.billiards.city.pool.nation.club
# 662 com.playgendary.homes
# 663 com.giraffegames.pool
# 664 com.karmangames.spades
# 665 com.huuuge.domino
# 666 com.tensquaregames.hunting.clash.wild.hunter.deer
# 667 ru.skillcap.dominoes
# 668 com.kooapps.pictowordandroid
# 669 com.jima.modern.tuktuk.auto.rickshaw.driving.game.simulator
# 670 uk.co.yakuto.TableTennisTouch
# 671 com.blacklightsw.ludo
# 672 com.eyesthegame.eyes
# 673 com.gameloft.android.ANMP.GloftA3HM
# 674 com.netease.chiji
# 675 com.agedstudio.board.game.dominoes
# 676 com.RetrostyleGames.LastPirate.deadthieves
# 677 com.xten.starfall
# 678 roll.unblock.ball.block.puzzle
# 679 mobi.gameguru.racingfevermoto
# 680 com.zynga.chess.googleplay
# 681 com.miniclip.marblebattle
# 682 com.chess.champ
# 683 com.fa.gym.fighting.game
# 684 com.vividgames.realboxing
# 685 com.jimaapps.city.coach.bus.simulator.driving
# 686 com.gamovation.quickcheckers
# 687 com.giraffegames.ggpool
# 688 com.boombitgames.DrivingSchoolParking
# 689 air.WR3DFree
# 690 com.hagstrom.henrik.chess
# 691 com.gzl.drivebus.parking.game
# 692 com.nautilus.RealCricket3DLite
# 693 com.fun.games.commando.black.shadow
# 694 com.ovilex.drivingschoolsim
# 695 com.CrescentMoonGames.TotalEggscape
# 696 com.jamcity.joy_goo
# 697 com.OrubeGameStudio.DwarfJourney
# 698 com.RDaES.Wordsmyth.Word
# 699 com.Thunderbox.TCID
# 700 com.FinifuguGames.google.OtterOcean
# 701 com.bluewizard.campcarnage
# 702 com.tinybuildgames.killitwithfire
# 703 com.umusic.queenrocktourgp
# 704 com.bushiroad.en.invictus
# 705 com.atari.mobile.daysofdoom
# 706 com.lofipeople.blinddrive
# 707 com.neutronized.slimelaboratory
# 708 com.joxdev.towers
# 709 com.DefaultCompany.BulletPunk
# 710 air.com.GalMamalya.Mitoza
# 711 ru.avv.game
# 712 creamative.clann.v1
# 713 com.nomadgames.furyofdracula
# 714 com.okshur.JetscoutValunians
# 715 com.FlorianVanStrien.TheFinalEarth2
# 716 com.ylungamestudio.breakinggatespass
# 717 com.ea.gp.simsmobile
# 718 com.cookapps.redesignstar.homemakeover
# 719 com.techvision.hotelcraze
# 720 com.kiarygames.tinyroom
# 721 com.unicostudio.braintest
# 722 ge.bebi.balloon.pop.game
# 723 com.sonypicturestelevision.jeopardy2
# 724 com.peppapig.worldofpeppapig_g
# 725 com.rvappstudios.baby.games.piano.phone.kids
# 726 games.lightheart.mrautofire
# 727 com.etermax.trivialadder
# 728 com.GMA.Ball.Sort.Puzzle
# 729 com.appcraft.number.puzzle
# 730 org.pbskids.gamesapp
# 731 com.jagex.runescape.android
# 732 com.trivia.star.android
# 733 com.redcell.goldandgoblins
# 734 com.maroieqrwlk.unpin
# 735 com.candywriter.bitlife
# 736 com.hitthebank.game
# 737 com.mochibits.google.leftvsright
# 738 com.braindom2riddle
# 739 com.BeanstarGamesInc.WordGames
# 740 com.umi.feudlive
# 741 com.fiogonia.hearts
# 742 com.gma.water.connect.puzzle
# 743 com.nanotribe.games.cashier3d
# 744 com.ASmallGame.themagicfinger
# 745 com.slingshot.car
# 746 com.gameon.car.safety.check
# 747 com.bike.jump
# 748 com.rmg.hotelteam
# 749 com.hasbro.riskbigscreen
# 750 com.bricksbreaker.balls.crusher.bricks
# 751 air.com.pixelfederation.diggy
# 752 com.paperboatapps.google.kiddopia
# 753 com.volcanoforce.lost
# 754 zombie.survival.craft.z
# 755 com.braindom
# 756 link.merge.puzzle.onnect.number
# 757 com.fanatee.stop
# 758 com.easybrain.find.the.difference
# 759 com.haiku.adventure.escape.game.mystery.stories
# 760 com.colobolo.chainball
# 761 com.dropdom.blockpuzzle.hwwgame
# 762 com.scopely.wheeloffortune
# 763 com.ubisoft.dance.justdance2015companion
# 764 com.easybrain.killer.sudoku.free
# 765 com.usm.catanuniverse
# 766 com.wordgame.words.connect
# 767 com.wordgame.newcross.android.en
# 768 com.bitmango.go.mergeblockstarfinders
# 769 com.glu.dashtown
# 770 com.tilemaster.puzzle.block.match
# 771 com.platinumplayer.word.addict
# 772 com.my.defense
# 773 com.upland.app
# 774 com.gamebility.onet
# 775 com.easybrain.block.puzzle.games
# 776 com.peoplefun.blockscapes
# 777 com.ferrero.applayduGP
# 778 com.littleengine.wordpal
# 779 com.iposedon.bricksbreakerballs
# 780 com.jagex.oldscape.android
# 781 gen.tech.keiki.world.learning
# 782 com.foxbet.super6
# 783 com.preschoolacademy.toddlerpreschoollearning
# 784 com.gokids.livenumbers
# 785 com.rvappstudios.abc_kids_toddler_tracing_phonics
# 786 com.rvappstudios.shapes.colors.toddler
# 787 com.pjmasks.moonlightheroes
# 788 com.sinyee.babybus.habits
# 789 com.budgestudios.googleplay.MyLittlePonyRainbowRunners
# 790 com.sesameworkshop.alphabetkitchen.play
# 791 com.happytools.learning.kids.games
# 792 com.rickyzoom.welcometowheelford
# 793 com.budgestudios.googleplay.MyLittlePonyColoring
# 794 com.binibambini.abc
# 795 com.iabuzz.minigames.dino
# 796 com.pjmasks.heroacademy
# 797 com.imaginalis.HouseFlipperMobile
# 798 com.budgestudios.googleplay.ThomasAndFriendsMinis
# 799 com.sinyee.babybus.career
# 800 com.bubadu.bubbu
# 801 com.JindoBlu.TwoPlayerGamesChallenge
# 802 com.kids.preschool.learning.games
# 803 com.tutotoons.app.smolsiesmycutepethouse.free
# 804 com.dhxmedia.slugitout2
# 805 com.gokids.transportbuilding
# 806 com.budgestudios.googleplay.DCSuperHeroGirls
# 807 com.sinyee.babybus.foodstory
# 808 com.sinyee.babybus.rescueII
# 809 com.sinyee.babybus.adventure
# 810 biz.arrowstar.funnyfood2
# 811 com.sinyee.babybus.dinosaurIII
# 812 com.rvappstudios.kids.coloring.book.color.painting
# 813 com.rvappstudios.numbers123.toddler.counting.tracing
# 814 com.sinyee.babybus.princessII
# 815 com.budgestudios.TransformersRescueBotsHeroAdventures
# 816 com.sinyee.babybus.firemanII
# 817 com.sinyee.babybus.diyII
# 818 biz.arrowstar.funnyfood3
# 819 com.sinyee.babybus.homesafe.global
# 820 com.sinyee.babybus.cosmetology
# 821 com.budgestudios.googleplay.TransformersDisasterDash
# 822 com.crayolallc.crayola_scribble_scrubbie_pets
# 823 com.tutotoons.app.mybabyunicorn.free
# 824 com.orange.gamesforkids.coloring.princess
# 825 com.sinyee.babybus.tailor
# 826 com.sinyee.babybus.colour
# 827 com.budgestudios.googleplay.BarbieDreamhouse
# 828 com.wb.goog.legoswtfa
# 829 com.edujoy.kidecats
# 830 com.gameloft.android.ANMP.GloftPOHM
# 831 mytown.home
# 832 com.razmobi.kidsdinosaurgame
# 833 com.rvappstudios.jigsaw.puzzles.kids
# 834 com.razmobi.monstertrucks2
# 835 com.budgestudios.MyLittlePonyHarmonyQuest
# 836 com.sinyee.babybus.kindergartenII
# 837 com.budgestudios.HelloKittyLunchBox
# 838 com.sinyee.babybus.hero
# 839 com.turborocketgames.wildcraft
# 840 mytown.firestation.free
# 841 com.PepiPlay.KingsCastle
# 842 com.sinyee.babybus.restaurant
# 843 com.budgestudios.HelloKittyNailSalon
# 844 com.rvappstudios.abc.spelling.toddler.spell.phonics
# 845 com.sinyee.babybus.superman
# 846 com.budgestudios.googleplay.HotWheelsUnlimited
# 847 com.tutotoons.app.sweetbabygirlcleanup5.free
# 848 com.sinyee.babybus.designer
# 849 com.lego.friends.heartlake
# 850 com.sinyee.babybus.careII
# 851 mytown.hauntedhouse.free
# 852 com.sinyee.babybus.dentistII
# 853 com.sinyee.babybus.shopping
# 854 com.sinyee.babybus.kitchens
# 855 com.edujoy.masha.games
# 856 com.kidsfoodinc.unicorn.cooking.game
# 857 com.rvappstudios.math.kids.counting
# 858 com.tutotoons.app.kikififipetfriends.free
# 859 com.bubadu.bubbuschool
# 860 com.sinyee.babybus.drinks
# 861 com.oki.colors
# 862 mytown.police
# 863 mytown.amusementpark.free
# 864 com.budgestudios.googleplay.hellokittyfashionstar
# 865 com.bubadu.supermarket
# 866 com.tabtale.babytwins
# 867 com.gi.talkinggummybear
# 868 com.pepiplay.pepihome
# 869 com.infigames.babyphonetoy
# 870 com.gokids.tablet
# 871 com.spinmaster.gabbysdollhouse
# 872 babyphone.freebabygames.com.babyphone
# 873 com.sinyee.babybus.earthquake
# 874 com.sinyee.babybus.magichouse
# 875 com.tutotoons.app.kpopsiescuteunicornpets
# 876 com.sinyee.babybus.market
# 877 com.sinyee.babybus.pen
# 878 com.hasbro.beybladesenterprise
# 879 com.iz.world.pretend.play.life.my.princess.games.town.city.house.wonder.doll
# 880 com.sinyee.babybus.math
# 881 com.psvnMaB.Goodnight
# 882 com.animedressupgames.chibi
# 883 com.tutotoons.app.mybabyunicorn2.free
# 884 com.sinyee.babybus.holiday
# 885 com.GamesForKids.Mathgames.MultiplicationTables
# 886 com.binibambini.MiniLite
# 887 com.playtoddlers.urbancitystories.free
# 888 com.aquiris.horizonchase
# 889 com.gamesforkids.preschoolworksheets.alphabets
# 890 br.com.tapps.donotdisturb
# 891 com.kid58.lianyong.princessIII
# 892 com.gokids.bphone1
# 893 mytown.preschool.free
# 894 com.KidsGames.SuperHippo
# 895 com.devgame.masha.and.bear.pizzeria.games
# 896 com.forqan.tech.PrincessColoring
# 897 com.kidgame.supermarket
# 898 com.psvn.traumatologist
# 899 com.iz.coloring.games.kids.drawing.book.color.by.number
# 900 mytown.wedding.free
# 901 wedding.games
# 902 com.indigokids.mim
# 903 com.minibuu.princessphone
# 904 com.edutainment.mashadentist
# 905 mytown.grandparents.free
# 906 com.psv.vlad_and_nikita.racing
# 907 com.coloring.mermaids
# 908 com.princess.coloring
# 909 com.iz.pretend.play.my.monster.town.airport.games.kids
# 910 mytown.cinema.free
# 911 com.devgame.robocar.poli.postman.kids.games
# 912 com.Metrafilms.KidECatsDollHouse
# 913 com.gamesforgirlsfree.dressupgames

# %%
app_infos = []

for ap in tqdm(app_packages):
    info = app(ap, lang='en', country='us')
    del info['comments']
    app_infos.append(info)
# Out:
# 100%|████████████████████████████████████████| 914/914 [03:42<00:00,  4.12it/s]

# %%
def print_json(json_object):
    json_str = json.dumps(
        json_object,
        indent=2,
        sort_keys=True,
        default=str
    )
    
    print(highlight(json_str, JsonLexer(), TerminalFormatter()))

# %%
print_json(app_infos[:3])
# Out:
# [
#   {
#     "adSupported": null,
#     "androidVersion": "4.0",
#     "androidVersionText": "4.0 and up",
#     "appId": "com.robtopx.geometryjump",
#     "containsAds": false,
#     "contentRating": "Everyone",
#     "contentRatingDescription": null,
#     "currency": "USD",
#     "description": "Jump and fly your way through danger in this rhythm-based action platformer!\r\n\r\nPrepare for a near impossible challenge in the world of Geometry Dash. Push your skills to the limit as you jump, fly and flip your way through dangerous passages and spiky obstacles.\r\n\r\nSimple one touch game play with lots of levels that will keep you entertained for hours!\r\n\r\nGame Features\r\n\r\n\u2022 Rhythm-based Action Platforming!\r\n\u2022 Lots of levels with unique soundtracks!\r\n\u2022 Build and share your own levels using the level editor!\r\n\u2022 Unlock new icons and colors to customize your character!\r\n\u2022 Fly rockets, flip gravity and much more!\r\n\u2022 Use practice mode to sharpen your skills!\r\n\u2022 Lots of achievements and rewards!\r\n\u2022 No in-app purchases!\r\n\u2022 Challenge yourself with the near impossible!\r\n\r\nContact: support@robtopgames.com",
#     "descriptionHTML": "Jump and fly your way through danger in this rhythm-based action platformer!<br><br>Prepare for a near impossible challenge in the world of Geometry Dash. Push your skills to the limit as you jump, fly and flip your way through dangerous passages and spiky obstacles.<br><br>Simple one touch game play with lots of levels that will keep you entertained for hours!<br><br>Game Features<br><br>\u2022 Rhythm-based Action Platforming!<br>\u2022 Lots of levels with unique soundtracks!<br>\u2022 Build and share your own levels using the level editor!<br>\u2022 Unlock new icons and colors to customize your character!<br>\u2022 Fly rockets, flip gravity and much more!<br>\u2022 Use practice mode to sharpen your skills!<br>\u2022 Lots of achievements and rewards!<br>\u2022 No in-app purchases!<br>\u2022 Challenge yourself with the near impossible!<br><br>Contact: support@robtopgames.com",
#     "developer": "RobTop Games",
#     "developerAddress": "Fresta kyrkv\u00e4g 10\n19454 Upplands V\u00e4sby\nSweden",
#     "developerEmail": "support@robtopgames.com",
#     "developerId": "RobTop+Games",
#     "developerInternalID": "6052107525807351579",
#     "developerWebsite": "http://www.robtopgames.com",
#     "editorsChoice": false,
#     "free": false,
#     "genre": "Arcade",
#     "genreId": "GAME_ARCADE",
#     "headerImage": "https://play-lh.googleusercontent.com/bqgxeBONR2MXzv_6mrxl22KL2j3SYsdjKM6ov0JAiO6Un5pjhQGb-rxX3W_puOI274Q",
#     "histogram": [
#       34859,
#       9632,
#       25217,
#       73817,
#       625131
#     ],
#     "icon": "https://play-lh.googleusercontent.com/gSJ1oQ4a5pxvNHEktd21Gh36QbtZMMx5vqFZfe47VDs1fzCEeMCyThqOfg3DsTisYCo",
#     "inAppProductPrice": null,
#     "installs": "1,000,000+",
#     "minInstalls": 1000000,
#     "offersIAP": false,
#     "originalPrice": null,
#     "price": 1.99,
#     "privacyPolicy": "http://www.robtopgames.com/privacy_policy.pdf",
#     "ratings": 768656,
#     "recentChanges": "Update 2.11 is here!\r\n\r\nThis update will function as a smaller \"pre-update\" before Update 2.2. Lots of fun stuff planned :)\r\n\r\n- New icons and effects!\r\n- New community shop!\r\n- Weekly Demon challenge!\r\n- Folders and level sorting!\r\n- New demon chests!\r\n- Level leaderboards!\r\n- Lots of bugfixes and tweaks.\r\n\r\n- Some rewards were duplicated because of a bug. This has been fixed and duplicated rewards have been removed. If you have lost any orbs/diamonds/shards after loading 2.11, thats why :)\r\n\r\n/RubRub",
#     "recentChangesHTML": "Update 2.11 is here!<br><br>This update will function as a smaller &quot;pre-update&quot; before Update 2.2. Lots of fun stuff planned :)<br><br>- New icons and effects!<br>- New community shop!<br>- Weekly Demon challenge!<br>- Folders and level sorting!<br>- New demon chests!<br>- Level leaderboards!<br>- Lots of bugfixes and tweaks.<br><br>- Some rewards were duplicated because of a bug. This has been fixed and duplicated rewards have been removed. If you have lost any orbs/diamonds/shards after loading 2.11, thats why :)<br><br>/RubRub",
#     "released": "Aug 12, 2013",
#     "reviews": 351474,
#     "sale": false,
#     "saleText": null,
#     "saleTime": null,
#     "score": 4.6193523,
#     "screenshots": [
#       "https://play-lh.googleusercontent.com/QPS_wlJHQgy3G6KgWAcjjoXKOWJURujcw0LK70mzqBOCtFxoz0LSscWgoy0IYH97Dg",
#       "https://play-lh.googleusercontent.com/sq0hNhqNiuA6j0JW5nMOQCv_wJ6XBq1KpeMNkPN6TsGrrYNsaPrfZ-GiOkk1ap4SqBDA",
#       "https://play-lh.googleusercontent.com/ys1QONuCD-Cn20E7qy03rrBAM5UE-PIUKnosWxYkJGnj2LROYAJ_5KZVv22UEKAbRDk",
#       "https://play-lh.googleusercontent.com/WC1ktmQTv49vSOYNNoscsE0Q14djF1ifRDLc-Eacidzq-mtzkyBRgMbIzmC6TcqxasI",
#       "https://play-lh.googleusercontent.com/jeXVA_HnpbOiffYUUMvFpfVKA2DTMPCDtGejF4CGB4IRw3PoYi9n_O7H45h3mu5_iQ",
#       "https://play-lh.googleusercontent.com/er0-hnwfHoAx8PsU4ARsONOogw45KnYP3oxayWdwQOXfo6le8XlGBATnInvXs5r78c8",
#       "https://play-lh.googleusercontent.com/ejbcfd31sYjE7634xrKS91zDSC8IYHauzZvxBtGSvk8Y-eoNopwOjA3Au-Ok1dGtecA",
#       "https://play-lh.googleusercontent.com/ENdA4uhAgiVsnAunein6hoC8MHzF1hka6Piv-MSpWwCyFXX1gcGkuM2bRssYBWVCcFc",
#       "https://play-lh.googleusercontent.com/F7Lo7hiM_50WzZEbuKJCD1AN7bnHk9czNBayu7wCtd8nmW5VJVdocwB83slLD9IX9dWS",
#       "https://play-lh.googleusercontent.com/WO-zrl52JssM8MP-w0jrB9PQRVjhhLYd6f7173h1VCu3XofkeIgepjzRtLHAJpVDuS8",
#       "https://play-lh.googleusercontent.com/1L5RFpydHyFNYAoXChRxN2cLGZW4Yf2C1RQu2-JfNHNzhPIB-adA3rvTrDzNTvNjD_0Z",
#       "https://play-lh.googleusercontent.com/_ZpXy_AnKf2yOECinjNTLcbdG7lRDYOjJ4cpswULr7_7HBrtk4MT3spTANJ8W5FdLqo",
#       "https://play-lh.googleusercontent.com/y1MjpXQ3cQjgoOE8iV7Towg0sCSJRG2mM_fWk3aIPJYN4G9_bGfTprNkHKlSZLBRXX0",
#       "https://play-lh.googleusercontent.com/-QNr14Oydecna2dM9mCkCqFNbcVGL1ymRGI55a-uFfGD8KSKxYzh7WWo0lD__LhkzMI",
#       "https://play-lh.googleusercontent.com/W_s8x-BX2J6DZc0FCqAH1o8Dswsh6HlMQD3LAWh0-gwmd4vn_UjeDFgWow_QNZX_oNk",
#       "https://play-lh.googleusercontent.com/z19es3OCGAuLtEpKIRlUN8bUcrBxwOOcIffdfAukbrt8mobpsqcyG4h__eGIF5z1k7I",
#       "https://play-lh.googleusercontent.com/RrS3gJchtbfCtBU_f_vLAR1Zyrb3xkTwKKonL00xLIkAGzel1HiDOT20Uy-d1JQYDuo"
#     ],
#     "size": "85M",
#     "summary": "Jump and fly your way through danger in this rythm-based action platformer!",
#     "summaryHTML": "Jump and fly your way through danger in this rythm-based action platformer!",
#     "title": "Geometry Dash",
#     "updated": 1510762834,
#     "url": "https://play.google.com/store/apps/details?id=com.robtopx.geometryjump&hl=en&gl=us",
#     "version": "2.111",
#     "video": "https://www.youtube.com/embed/k90y6PIzIaE?ps=play&vq=large&rel=0&autohide=1&showinfo=0",
#     "videoImage": "https://i.ytimg.com/vi/k90y6PIzIaE/hqdefault.jpg"
#   },
#   {
#     "adSupported": null,
#     "androidVersion": "5.0",
#     "androidVersionText": "5.0 and up",
#     "appId": "com.marmalade.monopoly",
#     "containsAds": false,
#     "contentRating": "Everyone",
#     "contentRatingDescription": null,
#     "currency": "USD",
#     "description": "Roll the dice, buy, sell, build and scheme your way to become a rich landlord in MONOPOLY! It\u2019s the Hasbro board game and family classic loved by over a billion people in cities and countries worldwide. The classic board game you know and love is available on mobile and tablets and playable both offline and online!\r\n\r\nExperience the classic board game in a completely new way. MONOPOLY by Marmalade Game Studio on Android brings the board to life with a beautiful animated and designed 3D city board with hotels and houses.\r\n\r\n<h2>Popular Features</h2>\r\n- <b>ORIGINAL BOARD GAME</b> - Play the Hasbro classic by yourself or with family and friends on mobile or tablet!\r\n- <b>A PREMIUM EXPERIENCE</b> - No pay-to-win, no ad pop-ups, no risk, and fully approved by Hasbro\r\n- <b>HOUSE RULES</b> - Play with the most common house rules\r\n- <b>QUICK MODE</b> - Finish the Hasbro board game faster than ever\r\n- <b>SINGLE-PLAYER</b> - Play against our challenging AI. No need for friends or family\r\n- <b>OFFLINE MULTIPLAYER</b> - Play together and pass the phone between turns\r\n- <b>ONLINE MULTIPLAYER</b> - Play MONOPOLY online with people all over the world from different cities or countries. Or create private multiplayer games to play with your friends and family without any risk\r\n\r\nAre you ready to experience the thrill of bankrupting your family and friends in MONOPOLY? Roll the dice, take risks, make your way around the board and BUY real estate, COLLECT rent and BUILD hotels to become a landlord tycoon. It\u2019s the popular Hasbro family board game on your mobile.\r\n\r\n<h2>Don\u2019t get bored and challenge up to FOUR PLAYERS on one mobile device in multiplayer!</h2>\r\n\r\nPlay a game of MONOPOLY anytime and anywhere, out and about or at home, offline and online! Play by yourself or with friends in multiplayer. Try this multiplayer with up to four players on one device. Or invite family and friends to play in online multiplayer. When you\u2019re ready to roll the dice, you can host a private multiplayer lobby or share public games with friends online from different cities.\r\n\r\n<h2>Finish a game of MONOPOLY FASTER in QUICK MODE!</h2>\r\n\r\nDon\u2019t worry about the risk of a game taking too long. Use Quick Mode to complete it in one hour or less. You\u2019ll spend less time in jail, build hotels sooner, become a successful landlord faster, and end the game after the first player is bankrupt; the richest player wins and becomes the MONOPOLY King.\r\n\r\n<h2>Our MONOPOLY game includes well-known, POPULAR HOUSE RULES</h2>\r\n\r\nDo you receive M400 instead of M200 when you land directly on GO in your usual games? Create a custom game with your family's favourite house rules and become the MONOPOLY king in your family.\r\n\r\n<h2>Our MONOPOLY game classic is FAMILY-FRIENDLY and risk free for kids</h2>\r\n\r\nWe have made sure our game is safe for kids, without any risk, and easy to play for the whole family online or offline in multiplayer. Like the original Hasbro board game, everyone can buy, sell, collect, build, and play! Since the game is ad-free, you won't risk bumping into inappropriate ads. And with private online multiplayer, you don't have to share a game with strangers and can simply play with your friends.\r\n\r\n<h2>Play with your LOCAL EDITION of MONOPOLY!</h2>\r\n\r\nOur game includes the largest number of localised boards any of the digital MONOPOLY board games has ever offered. Play with a board from select countries and unlock the \u2018Explorer Pack\u2019 to discover different cities and its real estate! Roll the dice, take risk, BUY or SELL real estate, COLLECT rent and BUILD hotels as a landlord in cities and countries all around the world.\r\n\r\n<h2>Let\u2019s jump into the MONOPOLY Universe!</h2>",
#     "descriptionHTML": "Roll the dice, buy, sell, build and scheme your way to become a rich landlord in MONOPOLY! It\u2019s the Hasbro board game and family classic loved by over a billion people in cities and countries worldwide. The classic board game you know and love is available on mobile and tablets and playable both offline and online!<br><br>Experience the classic board game in a completely new way. MONOPOLY by Marmalade Game Studio on Android brings the board to life with a beautiful animated and designed 3D city board with hotels and houses.<br><br><h2>Popular Features</h2><br>- <b>ORIGINAL BOARD GAME</b> - Play the Hasbro classic by yourself or with family and friends on mobile or tablet!<br>- <b>A PREMIUM EXPERIENCE</b> - No pay-to-win, no ad pop-ups, no risk, and fully approved by Hasbro<br>- <b>HOUSE RULES</b> - Play with the most common house rules<br>- <b>QUICK MODE</b> - Finish the Hasbro board game faster than ever<br>- <b>SINGLE-PLAYER</b> - Play against our challenging AI. No need for friends or family<br>- <b>OFFLINE MULTIPLAYER</b> - Play together and pass the phone between turns<br>- <b>ONLINE MULTIPLAYER</b> - Play MONOPOLY online with people all over the world from different cities or countries. Or create private multiplayer games to play with your friends and family without any risk<br><br>Are you ready to experience the thrill of bankrupting your family and friends in MONOPOLY? Roll the dice, take risks, make your way around the board and BUY real estate, COLLECT rent and BUILD hotels to become a landlord tycoon. It\u2019s the popular Hasbro family board game on your mobile.<br><br><h2>Don\u2019t get bored and challenge up to FOUR PLAYERS on one mobile device in multiplayer!</h2><br><br>Play a game of MONOPOLY anytime and anywhere, out and about or at home, offline and online! Play by yourself or with friends in multiplayer. Try this multiplayer with up to four players on one device. Or invite family and friends to play in online multiplayer. When you\u2019re ready to roll the dice, you can host a private multiplayer lobby or share public games with friends online from different cities.<br><br><h2>Finish a game of MONOPOLY FASTER in QUICK MODE!</h2><br><br>Don\u2019t worry about the risk of a game taking too long. Use Quick Mode to complete it in one hour or less. You\u2019ll spend less time in jail, build hotels sooner, become a successful landlord faster, and end the game after the first player is bankrupt; the richest player wins and becomes the MONOPOLY King.<br><br><h2>Our MONOPOLY game includes well-known, POPULAR HOUSE RULES</h2><br><br>Do you receive M400 instead of M200 when you land directly on GO in your usual games? Create a custom game with your family&#39;s favourite house rules and become the MONOPOLY king in your family.<br><br><h2>Our MONOPOLY game classic is FAMILY-FRIENDLY and risk free for kids</h2><br><br>We have made sure our game is safe for kids, without any risk, and easy to play for the whole family online or offline in multiplayer. Like the original Hasbro board game, everyone can buy, sell, collect, build, and play! Since the game is ad-free, you won&#39;t risk bumping into inappropriate ads. And with private online multiplayer, you don&#39;t have to share a game with strangers and can simply play with your friends.<br><br><h2>Play with your LOCAL EDITION of MONOPOLY!</h2><br><br>Our game includes the largest number of localised boards any of the digital MONOPOLY board games has ever offered. Play with a board from select countries and unlock the \u2018Explorer Pack\u2019 to discover different cities and its real estate! Roll the dice, take risk, BUY or SELL real estate, COLLECT rent and BUILD hotels as a landlord in cities and countries all around the world.<br><br><h2>Let\u2019s jump into the MONOPOLY Universe!</h2>",
#     "developer": "Marmalade Game Studio",
#     "developerAddress": "33 Charlotte Street\nFitzrovia\nLondon\nW1T 1RR\nUnited Kingdom",
#     "developerEmail": "contactus@marmalademail.com",
#     "developerId": "8684502731112464883",
#     "developerInternalID": "8684502731112464883",
#     "developerWebsite": "https://marmaladegamestudio.com/",
#     "editorsChoice": false,
#     "free": false,
#     "genre": "Board",
#     "genreId": "GAME_BOARD",
#     "headerImage": "https://play-lh.googleusercontent.com/O3KYkcY5VuvKh-prh0vMFEN9DJQ5M_cNwoYAqfCdNFfuvknCRfNveN5WYXQ2_4iQWQ",
#     "histogram": [
#       5337,
#       1996,
#       3509,
#       9410,
#       44226
#     ],
#     "icon": "https://play-lh.googleusercontent.com/ZfVX0LLMo8YeRn6CWvP20hA7eAdUYdZw81v7NT2jxGKHiKq8sRdQv4EzRD0O85PR_Io",
#     "inAppProductPrice": "$1.99 - $34.99 per item",
#     "installs": "1,000,000+",
#     "minInstalls": 1000000,
#     "offersIAP": true,
#     "originalPrice": null,
#     "price": 3.99,
#     "privacyPolicy": "https://marmaladegamestudio.com/wp-content/uploads/2016/12/Privacy_Policy.pdf",
#     "ratings": 64478,
#     "recentChanges": "MONOPOLY is now available in Korean! PLUS Hasbro\u2019s Community Chest challenge!\r\n\r\n- Have your say on the future of MONOPOLY with the Hasbro Community Chest Challenge! The Community Chest cards are getting an update. Vote in-game on what the new cards will be and help shape all physical and digital MONOPOLY boards forever!\r\n- A new translation is bringing the official MONOPOLY mobile game to Korean speakers!",
#     "recentChangesHTML": "MONOPOLY is now available in Korean! PLUS Hasbro\u2019s Community Chest challenge!<br><br>- Have your say on the future of MONOPOLY with the Hasbro Community Chest Challenge! The Community Chest cards are getting an update. Vote in-game on what the new cards will be and help shape all physical and digital MONOPOLY boards forever!<br>- A new translation is bringing the official MONOPOLY mobile game to Korean speakers!",
#     "released": "Dec 4, 2019",
#     "reviews": 25479,
#     "sale": false,
#     "saleText": null,
#     "saleTime": null,
#     "score": 4.3211713,
#     "screenshots": [
#       "https://play-lh.googleusercontent.com/Q654-xG0wdUGotQHAwdwQ3Vm1w7m_xVcQ46yXjp-u1LZqCskslNCVXqIfcmZJh74qFNi",
#       "https://play-lh.googleusercontent.com/ByaOMLBORj8kR0P7znk_pc8estTacTcv1iYIDcmj9k_kCHq95pS1ZDG5WTbuw13oEVI",
#       "https://play-lh.googleusercontent.com/1wtksOY-2oDOfnS28xvDyPDiM3Vs8np7k2Ori7e8tFIhioButy37xilYxmxSX7QHgQ",
#       "https://play-lh.googleusercontent.com/crX7BO2nYECFDA-ndIl6O52T8GNk_nk3mNnlKuESlxRvz6VaXnzgBAFijjw-FJbGgvTr",
#       "https://play-lh.googleusercontent.com/ewjkbk2gNhqT262k0BIBHHCh2klyzsO3i5zE66mkWD_kxYkuNmYEjK3e6WO78MoZ4Q",
#       "https://play-lh.googleusercontent.com/VALtmZ60zq3KkpZh2xsXAmK10MK_cxoc_ZQSbO9V6Y2Lhqzbz25BRiXsaCJYAd6Q_vc",
#       "https://play-lh.googleusercontent.com/HBp7Y_elTub8v4xTKp76wCr4GzIsbsT4ME-iU6CvHTSzzT5EGBIGS_wTJLWujLSNqg",
#       "https://play-lh.googleusercontent.com/nxg_pLLKMBO1dtdYEZUf7WA-bUSvC2020bFQtxB-8cMB_4p5e0tfb7cZHa8rOmtMc1E",
#       "https://play-lh.googleusercontent.com/-Cj3JpO-wENxZcXnFpj7vpQJmu9nG_ZDJXW0N0IvXJjNqXUJr0cChmgOnlT5R4aZYA",
#       "https://play-lh.googleusercontent.com/IpNOO2KzCz4QaiSjSTXV6eEvvgPR9CpObSKmn4tDdLW2f1hvXKCeUZ1u4vBo4Z6D56mc",
#       "https://play-lh.googleusercontent.com/XwF4aXETXBKIDBfCgHBDz2eMVYgUL6ExIyIuEU0_RLuNy6OVfQeFNT5kpS_gtA7Xs3Y",
#       "https://play-lh.googleusercontent.com/HpsfatzNY1R_w77dBZm8wMtxNXwDmzr_Zw-up-p471iTA3TFflzwIgwAZ9jeM0G9TEQ",
#       "https://play-lh.googleusercontent.com/0cpNPZoCqDECcMEDBNn1kcbYE9ZKbs-OhkBNhtlmIGZgogEnJytWQUPWJU61O-DBoP8",
#       "https://play-lh.googleusercontent.com/zdSkPl44_UuV3sR3Y4uP_Cw_TPddHz5UGbuqYFZ7Q1NykWHM6myIBMeTh9R7IrheV2C7",
#       "https://play-lh.googleusercontent.com/-ccQk1HUw7dezT7m_GkgsspXgVAgi4Dr3VIEvF1e5eD-A-KW0SmZe_FQhVhOTiKnrA",
#       "https://play-lh.googleusercontent.com/VlJ46NDJMftekfRCrbZPHx0g3gaOmwI3X2rnCqodpG0TLbjle31kDOMU_K4YftlWPg",
#       "https://play-lh.googleusercontent.com/ucsbhWdciEtfjtKQqckkzKlFHhmZakTDJ045KWdTetzoaHkaExTxbJp0T51r3AA-HVP_",
#       "https://play-lh.googleusercontent.com/ObxmOwzaMTHKx1Vh2kWF-AzvXlxQ_L-_JKPWjNuCo2SsKeGAlT_i1XwscFJUnTvFGYc0",
#       "https://play-lh.googleusercontent.com/xfT2n0mz81fbLCMti7qMHEPuq0HLwTRCBP8HC1643xDb7JC7_-x56ZovvHCCtJuYCXY",
#       "https://play-lh.googleusercontent.com/VsFJ1W8YZm2qCFujxdV8kr9czO-FnlUWGEnPaMHW9nnrHt43sIIvK3UMOIi2DdaHiTE",
#       "https://play-lh.googleusercontent.com/UDvzenLsdN0viOHrx0jcNBYwQYhGQ2Nftuaxx2vo6ZtAq6XFspDcRR76B_5Y_3WfkA",
#       "https://play-lh.googleusercontent.com/d02txRCzrRxd5XmGpDJBREZIeXhOT-IvGsBR4ZULRO65Ms3nKgErfz1j-yPruX-cvA",
#       "https://play-lh.googleusercontent.com/z1stsVa2r8jfGEHyS949oAKzdDS0IfYuNwByPbm6TX2xUgKjgGkIkDip3rADnzZJcyaN",
#       "https://play-lh.googleusercontent.com/psoedTMcrJdP8MhLkxeaWezGKpCrnF70UtQW9Bjv_ztEeIIjSYTzLtAcbX-E8POSPSg"
#     ],
#     "size": "52M",
#     "summary": "Take risk & play the board game for friends & family by Hasbro online & offline!",
#     "summaryHTML": "Take risk &amp; play the board game for friends &amp; family by Hasbro online &amp; offline!",
#     "title": "Monopoly - Board game classic about real-estate!",
#     "updated": 1616675814,
#     "url": "https://play.google.com/store/apps/details?id=com.marmalade.monopoly&hl=en&gl=us",
#     "version": "1.4.8",
#     "video": "https://www.youtube.com/embed/kXSazDfbrEI?ps=play&vq=large&rel=0&autohide=1&showinfo=0",
#     "videoImage": "https://i.ytimg.com/vi/kXSazDfbrEI/hqdefault.jpg"
#   },
#   {
#     "adSupported": null,
#     "androidVersion": "4.4",
#     "androidVersionText": "4.4 and up",
#     "appId": "com.chucklefish.stardewvalley",
#     "containsAds": false,
#     "contentRating": "Everyone 10+",
#     "contentRatingDescription": "Fantasy Violence, Mild Blood, Mild Language, Simulated Gambling, Use of Alcohol and Tobacco",
#     "currency": "USD",
#     "description": "ConcernedApe's smash hit farming RPG comes to Mobile!\r\n\r\nMove to the countryside, and cultivate a new life in this award-winning open-ended farming RPG! With over 50+ hours of gameplay content and new Mobile-specific features, such as auto-save and multiple controls options.\r\n\r\nNow with brand new end-game content! Discover more heart events, new crops to grow, new pets, and so much more...\r\n\r\n**Winner of the Golden Joysticks' Breakthrough Award**\r\n**Nominee of Game of the Year 2017 - BAFTA Games Awards**\r\n\r\n---\r\n\r\nBUILD THE FARM OF YOUR DREAMS:\r\n\r\n\u25a0 Turn your overgrown fields into a lively and bountiful farm\r\n\r\n\u25a0 Raise and breed happy animals, grow a variety of seasonal crops and design your farm, your way\r\n\r\n\u25a0 Customize your farmer and home! With hundreds of options to choose from\r\n\r\n\u25a0 Settle down and start a family with 12 potential marriage candidates\r\n\r\n\u25a0 Become part of the community by taking part in seasonal festivals and villager quests\r\n\r\n\u25a0 Explore vast, mysterious caves, encountering dangerous monsters and valuable treasure\r\n\r\n\u25a0 Spend a relaxing afternoon at one of the local fishing spots or go crabbing by the seaside\r\n\r\n\u25a0 Forage, grow crops and produce artisan goods to cook up as a delicious meal\r\n\r\n\u25a0 Rebuilt for touch-screen gameplay on Android with mobile-specific features, such as auto-select to toggle quickly between your farming tools and auto-attack to swiftly take down fiendish monsters in the mines\r\n\r\n\u25a0 Newly Updated Single Player Content - Including new town upgrades, dating events, crops, fishing ponds, hats, clothing, and new pets! Plus more to be discovered...\r\n\r\n\u25a0 Play the game your way with multiple controls options, such as touch-screen, virtual joystick, and external controller support.\r\n\r\n---\r\n\r\n\u201cThe best version of Stardew Valley is the one you have with you \u2026 This game is absolutely incredible, and will not disappoint.\u201d - TouchArcade\r\n\r\n\"Stardew Valley beautifully combines farm simulation with RPG elements to create an intriguing, absorbing rural world.\" - IGN\r\n\r\n\u201cFar more than just a farming game... filled with seemingly endless content and heart.\u201d Giant Bomb\r\n\r\n\"Village life has never been so accessible and satisfying\" - The Telegraph\r\n\r\n\u201cStardew Valley has been the most rich and heartwarming experience I\u2019ve had in a game in years.\u201d CG Magazine\r\n\r\n---\r\n\r\nNote: Features new 1.4 update story content, multiplayer functionality not supported. No in-app purchases.",
#     "descriptionHTML": "ConcernedApe&#39;s smash hit farming RPG comes to Mobile!<br><br>Move to the countryside, and cultivate a new life in this award-winning open-ended farming RPG! With over 50+ hours of gameplay content and new Mobile-specific features, such as auto-save and multiple controls options.<br><br>Now with brand new end-game content! Discover more heart events, new crops to grow, new pets, and so much more...<br><br>**Winner of the Golden Joysticks&#39; Breakthrough Award**<br>**Nominee of Game of the Year 2017 - BAFTA Games Awards**<br><br>---<br><br>BUILD THE FARM OF YOUR DREAMS:<br><br>\u25a0 Turn your overgrown fields into a lively and bountiful farm<br><br>\u25a0 Raise and breed happy animals, grow a variety of seasonal crops and design your farm, your way<br><br>\u25a0 Customize your farmer and home! With hundreds of options to choose from<br><br>\u25a0 Settle down and start a family with 12 potential marriage candidates<br><br>\u25a0 Become part of the community by taking part in seasonal festivals and villager quests<br><br>\u25a0 Explore vast, mysterious caves, encountering dangerous monsters and valuable treasure<br><br>\u25a0 Spend a relaxing afternoon at one of the local fishing spots or go crabbing by the seaside<br><br>\u25a0 Forage, grow crops and produce artisan goods to cook up as a delicious meal<br><br>\u25a0 Rebuilt for touch-screen gameplay on Android with mobile-specific features, such as auto-select to toggle quickly between your farming tools and auto-attack to swiftly take down fiendish monsters in the mines<br><br>\u25a0 Newly Updated Single Player Content - Including new town upgrades, dating events, crops, fishing ponds, hats, clothing, and new pets! Plus more to be discovered...<br><br>\u25a0 Play the game your way with multiple controls options, such as touch-screen, virtual joystick, and external controller support.<br><br>---<br><br>\u201cThe best version of Stardew Valley is the one you have with you \u2026 This game is absolutely incredible, and will not disappoint.\u201d - TouchArcade<br><br>&quot;Stardew Valley beautifully combines farm simulation with RPG elements to create an intriguing, absorbing rural world.&quot; - IGN<br><br>\u201cFar more than just a farming game... filled with seemingly endless content and heart.\u201d Giant Bomb<br><br>&quot;Village life has never been so accessible and satisfying&quot; - The Telegraph<br><br>\u201cStardew Valley has been the most rich and heartwarming experience I\u2019ve had in a game in years.\u201d CG Magazine<br><br>---<br><br>Note: Features new 1.4 update story content, multiplayer functionality not supported. No in-app purchases.",
#     "developer": "Chucklefish Limited",
#     "developerAddress": "Unit 3 Beaufort Court, Admirals Way, London E14 9XL, United Kingdom",
#     "developerEmail": "contact@chucklefish.org",
#     "developerId": "7107975034578576294",
#     "developerInternalID": "7107975034578576294",
#     "developerWebsite": "https://www.stardewvalley.net",
#     "editorsChoice": true,
#     "free": false,
#     "genre": "Role Playing",
#     "genreId": "GAME_ROLE_PLAYING",
#     "headerImage": "https://play-lh.googleusercontent.com/6gmXEuF66Vdr_PLJ-HD8zMo57jq-aGEbN5wWFX4f97alu0uJ0rdfPMmQManpBzuFehc",
#     "histogram": [
#       2144,
#       853,
#       2074,
#       6324,
#       74222
#     ],
#     "icon": "https://play-lh.googleusercontent.com/He92papZcOmkgTi1sLHXQQb02aoyRtJ8ml96njM_cSAcpHhILvxMjhLix4mYEIKXPq4",
#     "inAppProductPrice": null,
#     "installs": "1,000,000+",
#     "minInstalls": 1000000,
#     "offersIAP": false,
#     "originalPrice": null,
#     "price": 4.99,
#     "privacyPolicy": "https://chucklefish.org/privacy/",
#     "ratings": 85617,
#     "recentChanges": "Fix for Pam 9 heart event.",
#     "recentChangesHTML": "Fix for Pam 9 heart event.",
#     "released": "Mar 13, 2019",
#     "reviews": 37001,
#     "sale": false,
#     "saleText": null,
#     "saleTime": null,
#     "score": 4.747565,
#     "screenshots": [
#       "https://play-lh.googleusercontent.com/9uy1ZwSwrhXDrIXQMySQgOgoMU8T3oSjf85T68_HDLtTuc6iqDPSYVZ5D6Vysg-D9DY",
#       "https://play-lh.googleusercontent.com/cYewDYY9nudl75kNKpL1aiDO_ZseAVJnuim2FweDBHheEWzJpfsap-LaXEsX2rA-zg",
#       "https://play-lh.googleusercontent.com/K3iTDHZUEWPARrou2r_30gaXIoKXZfirTkNpY2I6YvGGoNfPLhXDIvJGd1cGQ-9UxA",
#       "https://play-lh.googleusercontent.com/pes5bS_toMehtprdAAAExCblDzsRHUTY-ktQ2fneN1lZPYc-P7VzS-8QcfXmBwd9CeI",
#       "https://play-lh.googleusercontent.com/LyHFCSzFwBajMuKmZ95-guNF1eNqHz9c6B3G5s8IgfwDHNCvZacNsMSMn-SFTS8pQN8",
#       "https://play-lh.googleusercontent.com/3657QN94eYalXsYbduUGDQ_iuEtyg26YjosXxLlkcm1v2JfLUIOjxm8l5QsqeKBRu1c3",
#       "https://play-lh.googleusercontent.com/I4GyppX9i3nmpPIxtWT39mTL0-cwZc_OCEoDFNAwDoyPlURHyJSxc0P6ch_55PkALLQ0",
#       "https://play-lh.googleusercontent.com/J7e5k1zOyVoEgFeDT2Td56vwyn-rp8cozTaNQEFlVrc9WhsygAJQCoqTbj86ldEvsMpm",
#       "https://play-lh.googleusercontent.com/kw7q1ywlOA84nF7zMjAm1dUiBLCmaVg_VZtANv8rsXJQc_-EPdJTbQ6gzbzm2o_2g28",
#       "https://play-lh.googleusercontent.com/kA2_Lbm2gXfxSRmiRfm4W-1hbVGDQY53RlTEtdfe9n4JzmyXh6qeVwophWUx-HvRkg",
#       "https://play-lh.googleusercontent.com/0P9lz0AKI7K3PHGywYQ9u4gPvkM2VdvGr2-As72GFklw7czE3y2OrtyBzOsai0kDUr4",
#       "https://play-lh.googleusercontent.com/GltG4lICe8G-EaV0IqGGoX34zjrTlbXXTJV-xyfOnKXKrddc-6vT9XgDh0U6kBE0Ir4",
#       "https://play-lh.googleusercontent.com/_SybwMqI1_a7eNQcaGh_JTgZkYP_OT-74VSWzKsbk5TEl2fV3F8zuj7hczQGJAmViUSE",
#       "https://play-lh.googleusercontent.com/LSc9RbZAjxlw-QaA-kXcB2V2WD1tMrHUSZEJPH8_xbVhPFVea76Snrp_dGdOpZwz4Mvi",
#       "https://play-lh.googleusercontent.com/UBlIicrbPrjXdqJbdxWFfoZbfjnN45e6tmwYVxbpHfWWvkmXVpL5mksU5g5dNLGhg-0",
#       "https://play-lh.googleusercontent.com/IwTiUXbPKtYZKcUMEPdmneuucMqbPPQ7O85ThnHTokRx8zkUy0ivts9IRQy7QzsfoQ",
#       "https://play-lh.googleusercontent.com/hcmUMGY8RFO1In5UUhXtifxth76jBB5J_QD29dF1Ja9mzBN1gOU0nhu2kPf8d0VH_2Pj",
#       "https://play-lh.googleusercontent.com/Sq3d4Xdc8lqgcItDv4Xw1GgPsjCZmCDRFAnOpvLaklu6YgHxyKLj5ZcHRiE2PbFTAQ",
#       "https://play-lh.googleusercontent.com/rfpkP70xI86fBcoLqr_u4SKtJ90CMzJ9y2zxy07O77XXiJDSurfG99BzgAv_toAkgGg",
#       "https://play-lh.googleusercontent.com/Ao4vaz7pvFPB0f5LO01hzzI7o9e1wJ7OLCT29RrS3m3oOsVzWYIY66Kp2xABismxSg",
#       "https://play-lh.googleusercontent.com/iIcZccsxFkPLj_y_UFJLaK7-BA2QI5l_-lt8JHcg1dbEQ9lPvfl8vsfogLaWh1DlQIE",
#       "https://play-lh.googleusercontent.com/iMYDViObxpvieM0zRi4LDTTeXhcP499qfIN1MgPY3Aw8P8rSo2SyfmHGaoyfpEE7Sg",
#       "https://play-lh.googleusercontent.com/sAXzlDJZOzJmsrqSDqoSUuDAIPLdLUOW21t6ClRzWcbZFBulMNXcGW35JD0ZTHAijOZA",
#       "https://play-lh.googleusercontent.com/thXhByCxXZQBvIrMSJGzaQEVaQVe0h9gXIQZZUovRpK-ef6xHykmuR3te1byu8Mxxck"
#     ],
#     "size": "80M",
#     "summary": "ConcernedApe's smash hit indie farming RPG!",
#     "summaryHTML": "ConcernedApe&#39;s smash hit indie farming RPG!",
#     "title": "Stardew Valley",
#     "updated": 1610463698,
#     "url": "https://play.google.com/store/apps/details?id=com.chucklefish.stardewvalley&hl=en&gl=us",
#     "version": "1.4.5.151",
#     "video": "https://www.youtube.com/embed/pHUqhYslji4?ps=play&vq=large&rel=0&autohide=1&showinfo=0",
#     "videoImage": "https://i.ytimg.com/vi/pHUqhYslji4/hqdefault.jpg"
#   }
# ]

# %%
app_info_df = pd.DataFrame(app_infos)
app_info_df.head()
# Out:
#                                               title  \
# 0                                     Geometry Dash
# 1  Monopoly - Board game classic about real-estate!
# 2                                    Stardew Valley
# 3                                          Terraria
# 4                             Ultimate Custom Night
#
#                                          description  \
# 0  Jump and fly your way through danger in this r...
# 1  Roll the dice, buy, sell, build and scheme you...
# 2  ConcernedApe's smash hit farming RPG comes to ...
# 3  DIG! FIGHT! EXPLORE! BUILD! Join the community...
# 4  NOTE: A device with at least 2 GB of RAM is re...
#
#                                      descriptionHTML  \
# 0  Jump and fly your way through danger in this r...
# 1  Roll the dice, buy, sell, build and scheme you...
# 2  ConcernedApe&#39;s smash hit farming RPG comes...
# 3  DIG! FIGHT! EXPLORE! BUILD! Join the community...
# 4  NOTE: A device with at least 2 GB of RAM is re...
#
#                                              summary  \
# 0  Jump and fly your way through danger in this r...
# 1  Take risk & play the board game for friends & ...
# 2        ConcernedApe's smash hit indie farming RPG!
# 3  DIG! FIGHT! EXPLORE! BUILD! Join the community...
# 4                                     Face them all!
#
#                                          summaryHTML    installs  minInstalls  \
# 0  Jump and fly your way through danger in this r...  1,000,000+      1000000
# 1  Take risk &amp; play the board game for friend...  1,000,000+      1000000
# 2    ConcernedApe&#39;s smash hit indie farming RPG!  1,000,000+      1000000
# 3  DIG! FIGHT! EXPLORE! BUILD! Join the community...  1,000,000+      1000000
# 4                                     Face them all!    100,000+       100000
#
#       score   ratings   reviews  ... adSupported  containsAds      released  \
# 0  4.619352  768656.0  351474.0  ...        None        False  Aug 12, 2013
# 1  4.321171   64478.0   25479.0  ...        None        False   Dec 4, 2019
# 2  4.747565   85617.0   37001.0  ...        None        False  Mar 13, 2019
# 3  4.647140  318303.0  165091.0  ...        None        False  Sep 25, 2013
# 4  4.634942   14673.0    7796.0  ...        None        False  Apr 24, 2020
#
#       updated      version                                      recentChanges  \
# 0  1510762834        2.111  Update 2.11 is here!\r\n\r\nThis update will f...
# 1  1616675814        1.4.8  MONOPOLY is now available in Korean! PLUS Hasb...
# 2  1610463698    1.4.5.151                         Fix for Pam 9 heart event.
# 3  1607427949  1.4.0.5.2.1                                    Minor bug fixes
# 4  1589660606        1.0.3  - Improved user interface\r\n- Resampled some ...
#
#                                    recentChangesHTML editorsChoice  \
# 0  Update 2.11 is here!<br><br>This update will f...         False
# 1  MONOPOLY is now available in Korean! PLUS Hasb...         False
# 2                         Fix for Pam 9 heart event.          True
# 3                                    Minor bug fixes         False
# 4  - Improved user interface<br>- Resampled some ...         False
#
#                                appId  \
# 0           com.robtopx.geometryjump
# 1             com.marmalade.monopoly
# 2      com.chucklefish.stardewvalley
# 3      com.and.games505.TerrariaPaid
# 4  com.clickteam.ultimatecustomnight
#
#                                                  url
# 0  https://play.google.com/store/apps/details?id=...
# 1  https://play.google.com/store/apps/details?id=...
# 2  https://play.google.com/store/apps/details?id=...
# 3  https://play.google.com/store/apps/details?id=...
# 4  https://play.google.com/store/apps/details?id=...
#
# [5 rows x 49 columns]

# %%
app_info_df.to_csv('google_games.csv', index=None, header=True)

# %% [markdown]
# # Get App Reviews

# %%
app_reviews = []

for ap in tqdm(app_packages):
    for score in range(1,6):
        for sort_order in [Sort.MOST_RELEVANT, Sort.NEWEST]:
            rvs = reviews(
            ap,
            lang='en',
            country='us',
            sort=sort_order,
            count= 200 if score == 3 else 100,
            filter_score_with=score
            )[0]
            
            for r in rvs:
                r['sortOrder'] = 'most_relevant' if sort_order == Sort.MOST_RELEVANT else 'newest'
                r['appID']= ap
            app_reviews.extend(rvs)

# %%
# print_json(app_reviews[0])

# %%
app_reviews_df = pd.DataFrame(app_reviews)
app_reviews_df.shape

# %%
app_reviews_df.head()

# %%
app_reviews_df.to_csv('game_reviews.csv', index=None, header=True)
