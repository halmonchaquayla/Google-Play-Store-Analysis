# %% [markdown]
# # Import Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option('display.max_columns', 500)

# %%
gg_data = pd.read_csv('data/googleplaystore.csv')
# new_data = pd.read_csv('data/new_app_data.csv')

# %%
data = gg_data.copy()

# %%
for col in data:
    print(col)
    print(data[col].value_counts(normalize=True))
    print('-------------------------------')
# Out:
# App
# ROBLOX                                               0.000830
# CBS Sports App - Scores, News, Stats & Watch Live    0.000738
# Candy Crush Saga                                     0.000646
# 8 Ball Pool                                          0.000646
# ESPN                                                 0.000646
#                                                        ...
# Toca Builders                                        0.000092
# FO STELIA Méaulte                                    0.000092
# Quiz for Clash Royale™                               0.000092
# Skiplagged — Exclusive Flights & Hotels              0.000092
# CX Summit                                            0.000092
# Name: App, Length: 9660, dtype: float64
# -------------------------------
# Category
# FAMILY                 0.181902
# GAME                   0.105525
# TOOLS                  0.077760
# MEDICAL                0.042708
# BUSINESS               0.042432
# PRODUCTIVITY           0.039111
# PERSONALIZATION        0.036159
# COMMUNICATION          0.035698
# SPORTS                 0.035421
# LIFESTYLE              0.035237
# FINANCE                0.033761
# HEALTH_AND_FITNESS     0.031455
# PHOTOGRAPHY            0.030901
# SOCIAL                 0.027212
# NEWS_AND_MAGAZINES     0.026105
# SHOPPING               0.023983
# TRAVEL_AND_LOCAL       0.023799
# DATING                 0.021585
# BOOKS_AND_REFERENCE    0.021308
# VIDEO_PLAYERS          0.016142
# EDUCATION              0.014390
# ENTERTAINMENT          0.013744
# MAPS_AND_NAVIGATION    0.012637
# FOOD_AND_DRINK         0.011715
# HOUSE_AND_HOME         0.008117
# AUTO_AND_VEHICLES      0.007841
# LIBRARIES_AND_DEMO     0.007841
# WEATHER                0.007564
# ART_AND_DESIGN         0.005996
# EVENTS                 0.005904
# COMICS                 0.005535
# PARENTING              0.005535
# BEAUTY                 0.004889
# 1.9                    0.000092
# Name: Category, dtype: float64
# -------------------------------
# Rating
# 4.4     0.118394
# 4.3     0.114871
# 4.5     0.110815
# 4.2     0.101633
# 4.6     0.087862
# 4.1     0.075584
# 4.0     0.060638
# 4.7     0.053272
# 3.9     0.041208
# 3.8     0.032348
# 5.0     0.029252
# 3.7     0.025515
# 4.8     0.024981
# 3.6     0.018576
# 3.5     0.017402
# 3.4     0.013665
# 3.3     0.010889
# 4.9     0.009288
# 3.0     0.008861
# 3.1     0.007366
# 3.2     0.006832
# 2.9     0.004804
# 2.8     0.004484
# 2.6     0.002669
# 2.7     0.002669
# 2.5     0.002242
# 2.3     0.002135
# 2.4     0.002028
# 1.0     0.001708
# 2.2     0.001495
# 1.9     0.001388
# 2.0     0.001281
# 2.1     0.000854
# 1.7     0.000854
# 1.8     0.000854
# 1.6     0.000427
# 1.4     0.000320
# 1.5     0.000320
# 1.2     0.000107
# 19.0    0.000107
# Name: Rating, dtype: float64
# -------------------------------
# Reviews
# 0          0.054976
# 1          0.025090
# 2          0.019740
# 3          0.016142
# 4          0.012637
#              ...
# 26649      0.000092
# 19232      0.000092
# 176487     0.000092
# 2440695    0.000092
# 22167      0.000092
# Name: Reviews, Length: 6002, dtype: float64
# -------------------------------
# Size
# Varies with device    0.156351
# 11M                   0.018264
# 12M                   0.018080
# 14M                   0.017895
# 13M                   0.017618
#                         ...
# 387k                  0.000092
# 108k                  0.000092
# 220k                  0.000092
# 658k                  0.000092
# 350k                  0.000092
# Name: Size, Length: 462, dtype: float64
# -------------------------------
# Installs
# 1,000,000+        0.145651
# 10,000,000+       0.115488
# 100,000+          0.107831
# 10,000+           0.097224
# 1,000+            0.083664
# 5,000,000+        0.069366
# 100+              0.066322
# 500,000+          0.049719
# 50,000+           0.044184
# 5,000+            0.044000
# 100,000,000+      0.037727
# 10+               0.035606
# 500+              0.030440
# 50,000,000+       0.026658
# 50+               0.018910
# 5+                0.007564
# 500,000,000+      0.006641
# 1+                0.006180
# 1,000,000,000+    0.005350
# 0+                0.001291
# 0                 0.000092
# Free              0.000092
# Name: Installs, dtype: float64
# -------------------------------
# Type
# Free    0.926107
# Paid    0.073801
# 0       0.000092
# Name: Type, dtype: float64
# -------------------------------
# Price
# 0          0.926114
# $0.99      0.013652
# $2.99      0.011899
# $1.99      0.006734
# $4.99      0.006641
#              ...
# $15.46     0.000092
# $28.99     0.000092
# $400.00    0.000092
# $2.59      0.000092
# $4.84      0.000092
# Name: Price, Length: 93, dtype: float64
# -------------------------------
# Content Rating
# Everyone           0.803875
# Teen               0.111439
# Mature 17+         0.046033
# Everyone 10+       0.038192
# Adults only 18+    0.000277
# Unrated            0.000185
# Name: Content Rating, dtype: float64
# -------------------------------
# Genres
# Tools                           0.077668
# Entertainment                   0.057467
# Education                       0.050641
# Medical                         0.042708
# Business                        0.042432
#                                   ...
# Comics;Creativity               0.000092
# Strategy;Education              0.000092
# Parenting;Brain Games           0.000092
# Music & Audio;Music & Video     0.000092
# Books & Reference;Creativity    0.000092
# Name: Genres, Length: 120, dtype: float64
# -------------------------------
# Last Updated
# August 3, 2018       0.030071
# August 2, 2018       0.028042
# July 31, 2018        0.027119
# August 1, 2018       0.026289
# July 30, 2018        0.019463
#                        ...
# December 14, 2015    0.000092
# March 25, 2014       0.000092
# February 8, 2012     0.000092
# April 2, 2017        0.000092
# February 13, 2015    0.000092
# Name: Last Updated, Length: 1378, dtype: float64
# -------------------------------
# Current Ver
# Varies with device    0.134681
# 1.0                   0.074679
# 1.1                   0.024370
# 1.2                   0.016431
# 2.0                   0.013939
#                         ...
# 4.76                  0.000092
# 1.0.B+.Exceed.Paid    0.000092
# 18.30.22              0.000092
# 1.16.33               0.000092
# v2.7.10.6             0.000092
# Name: Current Ver, Length: 2832, dtype: float64
# -------------------------------
# Android Ver
# 4.1 and up            0.226149
# 4.0.3 and up          0.138494
# 4.0 and up            0.126868
# Varies with device    0.125669
# 4.4 and up            0.090423
# 2.3 and up            0.060159
# 5.0 and up            0.055453
# 4.2 and up            0.036354
# 2.3.3 and up          0.025927
# 2.2 and up            0.022513
# 4.3 and up            0.022421
# 3.0 and up            0.022237
# 2.1 and up            0.012364
# 1.6 and up            0.010703
# 6.0 and up            0.005536
# 7.0 and up            0.003875
# 3.2 and up            0.003322
# 2.0 and up            0.002953
# 5.1 and up            0.002214
# 1.5 and up            0.001845
# 4.4W and up           0.001107
# 3.1 and up            0.000923
# 2.0.1 and up          0.000646
# 8.0 and up            0.000554
# 7.1 and up            0.000277
# 5.0 - 8.0             0.000185
# 1.0 and up            0.000185
# 4.0.3 - 7.1.1         0.000185
# 4.1 - 7.1.1           0.000092
# 5.0 - 7.1.1           0.000092
# 5.0 - 6.0             0.000092
# 2.2 - 7.1.1           0.000092
# 7.0 - 7.1.1           0.000092
# Name: Android Ver, dtype: float64
# -------------------------------

# %% [markdown]
# **Observations**
# 1. **App - there seems to be a few duplicates in app. have to deal with deleting those.**
# 2. **Category - need to look into '1.9'.**
# 3. **Rating - the rating is from 1-5, but there's a rating of 19. Need to delete that one.**
# 4. **Reviews - might drop the '0' reviews or filter the amount of reviews.**
# 5. **Size - the 'varies with device' need to be replace with the average size and the "M" needs to be taken out.**
# 6. **Installs - need to get rid of the '+' and maybe filter a min-max scale.**
# 7. **Change Type into a numeric column**
# 8. **Change last update into days.**

# %% [markdown]
# # Cleaning

# %% [markdown]
# ## App Duplicates

# %%
# let's check to make sure we have duplicates
data[data['App'] == 'ROBLOX']
# Out:
#          App Category  Rating  Reviews Size      Installs  Type Price  \
# 1653  ROBLOX     GAME     4.5  4447388  67M  100,000,000+  Free     0
# 1701  ROBLOX     GAME     4.5  4447346  67M  100,000,000+  Free     0
# 1748  ROBLOX     GAME     4.5  4448791  67M  100,000,000+  Free     0
# 1841  ROBLOX     GAME     4.5  4449882  67M  100,000,000+  Free     0
# 1870  ROBLOX     GAME     4.5  4449910  67M  100,000,000+  Free     0
# 2016  ROBLOX   FAMILY     4.5  4449910  67M  100,000,000+  Free     0
# 2088  ROBLOX   FAMILY     4.5  4450855  67M  100,000,000+  Free     0
# 2206  ROBLOX   FAMILY     4.5  4450890  67M  100,000,000+  Free     0
# 4527  ROBLOX   FAMILY     4.5  4443407  67M  100,000,000+  Free     0
#
#      Content Rating                        Genres   Last Updated  \
# 1653   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1701   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1748   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1841   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1870   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 2016   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 2088   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 2206   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 4527   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
#
#        Current Ver Android Ver
# 1653  2.347.225742  4.1 and up
# 1701  2.347.225742  4.1 and up
# 1748  2.347.225742  4.1 and up
# 1841  2.347.225742  4.1 and up
# 1870  2.347.225742  4.1 and up
# 2016  2.347.225742  4.1 and up
# 2088  2.347.225742  4.1 and up
# 2206  2.347.225742  4.1 and up
# 4527  2.347.225742  4.1 and up

# %%
data[data['App'] == 'ESPN']
# Out:
#        App Category  Rating Reviews                Size     Installs  Type  \
# 2959  ESPN   SPORTS     4.2  521138  Varies with device  10,000,000+  Free
# 3010  ESPN   SPORTS     4.2  521138  Varies with device  10,000,000+  Free
# 3018  ESPN   SPORTS     4.2  521138  Varies with device  10,000,000+  Free
# 3048  ESPN   SPORTS     4.2  521140  Varies with device  10,000,000+  Free
# 3060  ESPN   SPORTS     4.2  521140  Varies with device  10,000,000+  Free
# 3072  ESPN   SPORTS     4.2  521140  Varies with device  10,000,000+  Free
# 4069  ESPN   SPORTS     4.2  521081  Varies with device  10,000,000+  Free
#
#      Price Content Rating  Genres   Last Updated         Current Ver  \
# 2959     0   Everyone 10+  Sports  July 19, 2018  Varies with device
# 3010     0   Everyone 10+  Sports  July 19, 2018  Varies with device
# 3018     0   Everyone 10+  Sports  July 19, 2018  Varies with device
# 3048     0   Everyone 10+  Sports  July 19, 2018  Varies with device
# 3060     0   Everyone 10+  Sports  July 19, 2018  Varies with device
# 3072     0   Everyone 10+  Sports  July 19, 2018  Varies with device
# 4069     0   Everyone 10+  Sports  July 19, 2018  Varies with device
#
#      Android Ver
# 2959  5.0 and up
# 3010  5.0 and up
# 3018  5.0 and up
# 3048  5.0 and up
# 3060  5.0 and up
# 3072  5.0 and up
# 4069  5.0 and up

# %%
data[data['App'] == 'Candy Crush Saga']
# Out:
#                    App Category  Rating   Reviews Size      Installs  Type  \
# 1655  Candy Crush Saga     GAME     4.4  22426677  74M  500,000,000+  Free
# 1705  Candy Crush Saga     GAME     4.4  22428456  74M  500,000,000+  Free
# 1751  Candy Crush Saga     GAME     4.4  22428456  74M  500,000,000+  Free
# 1842  Candy Crush Saga     GAME     4.4  22429716  74M  500,000,000+  Free
# 1869  Candy Crush Saga     GAME     4.4  22430188  74M  500,000,000+  Free
# 1966  Candy Crush Saga     GAME     4.4  22430188  74M  500,000,000+  Free
# 3994  Candy Crush Saga   FAMILY     4.4  22419455  74M  500,000,000+  Free
#
#      Price Content Rating  Genres  Last Updated Current Ver Android Ver
# 1655     0       Everyone  Casual  July 5, 2018   1.129.0.2  4.1 and up
# 1705     0       Everyone  Casual  July 5, 2018   1.129.0.2  4.1 and up
# 1751     0       Everyone  Casual  July 5, 2018   1.129.0.2  4.1 and up
# 1842     0       Everyone  Casual  July 5, 2018   1.129.0.2  4.1 and up
# 1869     0       Everyone  Casual  July 5, 2018   1.129.0.2  4.1 and up
# 1966     0       Everyone  Casual  July 5, 2018   1.129.0.2  4.1 and up
# 3994     0       Everyone  Casual  July 5, 2018   1.129.0.2  4.1 and up

# %% [markdown]
# **Looking at some of the duplicates it seems that the only difference is the amount of reviews and/or the category name. For now I think I'll stick with the first value and drop the rest.**

# %%
data = data.drop_duplicates(subset=['App'], keep='first')

# %% [markdown]
# ## Category

# %%
data[data['Category'] == '1.9']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %% [markdown]
# Since this is one entry I can easily find the correct info and plug it in.
# Category = Lifestyle
# Rating = 1.9
# Reviews = 19.0
# Size = 3.0M
# Installs = 1,000
# Type = Free
# Price = 0
# Content Rating = Everyone

# %%
data.at[10472,"Category"]="LIFESTYLE"
data.at[10472, "Rating"] = 1.9
data.at[10472, "Reviews"] = "19.0"
data.at[10472, "Size"] = "3.0M"
data.at[10472, "Installs"] = "1,000+"
data.at[10472, "Type"] = "Free"
data.at[10472,'Price']= 0
data.at[10472, "Content Rating"] = "Everyone"
data.at[10472, "Last Updated"] = "February 11, 2018"

# %%
data[data['App'] == 'Life Made WI-Fi Touchscreen Photo Frame']
# Out:
#                                            App   Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame  LIFESTYLE     1.9    19.0
#
#        Size Installs  Type Price Content Rating             Genres  \
# 10472  3.0M   1,000+  Free     0       Everyone  February 11, 2018
#
#             Last Updated Current Ver Android Ver
# 10472  February 11, 2018  4.0 and up         NaN

# %% [markdown]
# ## Last Updated

# %%
data['Last Updated'] = pd.to_datetime(data['Last Updated'], format="%B %d, %Y", errors='coerce')

# %%
# data['Date'] = pd.to_datetime(data['Last Updated'])
release_month = data['Last Updated'].dt.month
data['Month'] = release_month

# %%
data = data.drop(['Last Updated'], axis =1)

# %% [markdown]
# ## Rating

# %%
# replacing the NAN values with the average rating
data['Rating'] = data['Rating'].fillna(data['Rating'].mean())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9660 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9660 non-null   object
#  1   Category        9660 non-null   object
#  2   Rating          9660 non-null   float64
#  3   Reviews         9660 non-null   object
#  4   Size            9660 non-null   object
#  5   Installs        9660 non-null   object
#  6   Type            9659 non-null   object
#  7   Price           9660 non-null   object
#  8   Content Rating  9660 non-null   object
#  9   Genres          9660 non-null   object
#  10  Current Ver     9652 non-null   object
#  11  Android Ver     9657 non-null   object
#  12  Month           9660 non-null   int64
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.3+ MB

# %% [markdown]
# ## Add new data

# %%
new_data = pd.read_csv('data/new_app_data.csv')
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 827 entries, 0 to 826
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             827 non-null    object
#  1   Installs        826 non-null    object
#  2   Rating          826 non-null    float64
#  3   Reviews         826 non-null    float64
#  4   Price           826 non-null    float64
#  5   Size            827 non-null    object
#  6   Genres          827 non-null    object
#  7   Category        827 non-null    object
#  8   Content Rating  827 non-null    object
#  9   Last Updated    819 non-null    object
#  10  Current Ver     827 non-null    object
#  11  Android Ver     825 non-null    object
#  12  Type            827 non-null    object
#  13  Date            819 non-null    object
#  14  Month           819 non-null    float64
# dtypes: float64(4), object(11)
# memory usage: 97.0+ KB

# %%
new_data = new_data.drop(['Last Updated', 'Date'], axis=1)

# %%
app_data = new_data.copy()
app_data
# Out:
#                                                    App      Installs  Rating  \
# 0                                            Jelly Dye    1,000,000+     4.2
# 1                                          Solar Smash   10,000,000+     4.6
# 2                                           Comics Bob    5,000,000+     3.8
# 3                          Draw Puzzle - Draw one part    5,000,000+     4.3
# 4                                             Among Us  100,000,000+     3.8
# ..                                                 ...           ...     ...
# 822               Mathway: Scan Photos, Solve Problems   10,000,000+     4.6
# 823     Avast Antivirus – Scan & Remove Virus, Cleaner  100,000,000+     4.7
# 824                     Wattpad - Read & Write Stories  100,000,000+     3.9
# 825    MotorTrend: Stream Roadkill, Top Gear, and more    1,000,000+     4.4
# 826  FitOn - Free Fitness Workouts & Personalized P...    1,000,000+     4.7
#
#        Reviews  Price                Size             Genres  \
# 0       3010.0    0.0  Varies with device         Simulation
# 1      99185.0    0.0                 83M         Simulation
# 2      10227.0    0.0                 81M             Puzzle
# 3       8889.0    0.0                 47M             Puzzle
# 4    5620232.0    0.0                102M             Action
# ..         ...    ...                 ...                ...
# 822   105363.0    0.0                 31M          Education
# 823   165252.0    0.0                 34M              Tools
# 824  1406630.0    0.0  Varies with device  Books & Reference
# 825     7285.0    0.0                 25M      Entertainment
# 826     7648.0    0.0                 42M   Health & Fitness
#
#                 Category Content Rating         Current Ver  \
# 0        GAME_SIMULATION       Everyone                1.49
# 1        GAME_SIMULATION   Everyone 10+               1.4.1
# 2            GAME_PUZZLE           Teen               1.1.0
# 3            GAME_PUZZLE       Everyone              1.0.29
# 4            GAME_ACTION   Everyone 10+            2021.3.9
# ..                   ...            ...                 ...
# 822            EDUCATION       Everyone              3.3.32
# 823                TOOLS       Everyone              6.37.0
# 824  BOOKS_AND_REFERENCE           Teen  Varies with device
# 825        ENTERTAINMENT       Everyone               4.8.2
# 826   HEALTH_AND_FITNESS       Everyone                 3.6
#
#             Android Ver  Type  Month
# 0            5.0 and up  Free    2.0
# 1           4.4W and up  Free    1.0
# 2            5.0 and up  Free   10.0
# 3            4.4 and up  Free   12.0
# 4            4.4 and up  Free    6.0
# ..                  ...   ...    ...
# 822          4.4 and up  Free    2.0
# 823          5.0 and up  Free   12.0
# 824  Varies with device  Free    3.0
# 825          5.0 and up  Free    5.0
# 826          4.1 and up  Free   12.0
#
# [827 rows x 13 columns]

# %%
app_data = app_data.dropna()
app_data
# Out:
#                                                    App      Installs  Rating  \
# 0                                            Jelly Dye    1,000,000+     4.2
# 1                                          Solar Smash   10,000,000+     4.6
# 2                                           Comics Bob    5,000,000+     3.8
# 3                          Draw Puzzle - Draw one part    5,000,000+     4.3
# 4                                             Among Us  100,000,000+     3.8
# ..                                                 ...           ...     ...
# 822               Mathway: Scan Photos, Solve Problems   10,000,000+     4.6
# 823     Avast Antivirus – Scan & Remove Virus, Cleaner  100,000,000+     4.7
# 824                     Wattpad - Read & Write Stories  100,000,000+     3.9
# 825    MotorTrend: Stream Roadkill, Top Gear, and more    1,000,000+     4.4
# 826  FitOn - Free Fitness Workouts & Personalized P...    1,000,000+     4.7
#
#        Reviews  Price                Size             Genres  \
# 0       3010.0    0.0  Varies with device         Simulation
# 1      99185.0    0.0                 83M         Simulation
# 2      10227.0    0.0                 81M             Puzzle
# 3       8889.0    0.0                 47M             Puzzle
# 4    5620232.0    0.0                102M             Action
# ..         ...    ...                 ...                ...
# 822   105363.0    0.0                 31M          Education
# 823   165252.0    0.0                 34M              Tools
# 824  1406630.0    0.0  Varies with device  Books & Reference
# 825     7285.0    0.0                 25M      Entertainment
# 826     7648.0    0.0                 42M   Health & Fitness
#
#                 Category Content Rating         Current Ver  \
# 0        GAME_SIMULATION       Everyone                1.49
# 1        GAME_SIMULATION   Everyone 10+               1.4.1
# 2            GAME_PUZZLE           Teen               1.1.0
# 3            GAME_PUZZLE       Everyone              1.0.29
# 4            GAME_ACTION   Everyone 10+            2021.3.9
# ..                   ...            ...                 ...
# 822            EDUCATION       Everyone              3.3.32
# 823                TOOLS       Everyone              6.37.0
# 824  BOOKS_AND_REFERENCE           Teen  Varies with device
# 825        ENTERTAINMENT       Everyone               4.8.2
# 826   HEALTH_AND_FITNESS       Everyone                 3.6
#
#             Android Ver  Type  Month
# 0            5.0 and up  Free    2.0
# 1           4.4W and up  Free    1.0
# 2            5.0 and up  Free   10.0
# 3            4.4 and up  Free   12.0
# 4            4.4 and up  Free    6.0
# ..                  ...   ...    ...
# 822          4.4 and up  Free    2.0
# 823          5.0 and up  Free   12.0
# 824  Varies with device  Free    3.0
# 825          5.0 and up  Free    5.0
# 826          4.1 and up  Free   12.0
#
# [817 rows x 13 columns]

# %%
df = pd.concat([data, app_data])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10477 entries, 0 to 826
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10477 non-null  object
#  1   Category        10477 non-null  object
#  2   Rating          10477 non-null  float64
#  3   Reviews         10477 non-null  object
#  4   Size            10477 non-null  object
#  5   Installs        10477 non-null  object
#  6   Type            10476 non-null  object
#  7   Price           10477 non-null  object
#  8   Content Rating  10477 non-null  object
#  9   Genres          10477 non-null  object
#  10  Current Ver     10469 non-null  object
#  11  Android Ver     10474 non-null  object
#  12  Month           10477 non-null  float64
# dtypes: float64(2), object(11)
# memory usage: 1.1+ MB

# %%
df['App'].value_counts(normalize=True)
# Out:
# DRAGON BALL Z DOKKAN BATTLE                                           0.000286
# DRAGON BALL LEGENDS                                                   0.000286
# 8 Ball Pool                                                           0.000286
# RollerCoaster Tycoon® Classic                                         0.000191
# Toca Builders                                                         0.000191
#                                                                         ...
# REG - Check the regnumber, find information about Swedish vehicles    0.000095
# Neon Blue Gaming Wallpaper&Theme fo Lenovo K8 Note                    0.000095
# Real DJ Simulator                                                     0.000095
# Don't Hug Me I'm So Scared                                            0.000095
# CX Summit                                                             0.000095
# Name: App, Length: 10352, dtype: float64

# %%
df = df.drop_duplicates(subset=['App'], keep='first')

# %%
df= df.drop(columns={'Price','Current Ver', 'Android Ver'}, axis=1)

# %%
df
# Out:
#                                                    App             Category  \
# 0       Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                  Coloring book moana       ART_AND_DESIGN
# 2    U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                Sketch - Draw & Paint       ART_AND_DESIGN
# 4                Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ..                                                 ...                  ...
# 822               Mathway: Scan Photos, Solve Problems            EDUCATION
# 823     Avast Antivirus – Scan & Remove Virus, Cleaner                TOOLS
# 824                     Wattpad - Read & Write Stories  BOOKS_AND_REFERENCE
# 825    MotorTrend: Stream Roadkill, Top Gear, and more        ENTERTAINMENT
# 826  FitOn - Free Fitness Workouts & Personalized P...   HEALTH_AND_FITNESS
#
#      Rating      Reviews                Size      Installs  Type  \
# 0       4.1          159                 19M       10,000+  Free
# 1       3.9          967                 14M      500,000+  Free
# 2       4.7        87510                8.7M    5,000,000+  Free
# 3       4.5       215644                 25M   50,000,000+  Free
# 4       4.3          967                2.8M      100,000+  Free
# ..      ...          ...                 ...           ...   ...
# 822     4.6       105363                 31M   10,000,000+  Free
# 823     4.7       165252                 34M  100,000,000+  Free
# 824     3.9  1.40663e+06  Varies with device  100,000,000+  Free
# 825     4.4         7285                 25M    1,000,000+  Free
# 826     4.7         7648                 42M    1,000,000+  Free
#
#     Content Rating                     Genres  Month
# 0         Everyone               Art & Design    1.0
# 1         Everyone  Art & Design;Pretend Play    1.0
# 2         Everyone               Art & Design    8.0
# 3             Teen               Art & Design    6.0
# 4         Everyone    Art & Design;Creativity    6.0
# ..             ...                        ...    ...
# 822       Everyone                  Education    2.0
# 823       Everyone                      Tools   12.0
# 824           Teen          Books & Reference    3.0
# 825       Everyone              Entertainment    5.0
# 826       Everyone           Health & Fitness   12.0
#
# [10352 rows x 10 columns]

# %% [markdown]
# ## Reviews

# %%
df.shape
# Out:
# (10352, 10)

# %%
df = df.dropna().reset_index(drop =True)

# %%
df.shape
# Out:
# (10351, 10)

# %%
df.Reviews.value_counts(normalize=True)
# Out:
# 0          0.057193
# 1          0.026278
# 2          0.020578
# 3          0.016424
# 4          0.013235
#              ...
# 44087.0    0.000097
# 162.0      0.000097
# 6210998    0.000097
# 36606      0.000097
# 22167      0.000097
# Name: Reviews, Length: 6008, dtype: float64

# %%
df['Reviews'] = pd.to_numeric(df['Reviews'])

# %% [markdown]
# ## Size

# %%
df[df['Size'] == "Varies with device"]
# Out:
#                                         App             Category  Rating  \
# 37                       Floor Plan Creator       ART_AND_DESIGN     4.1
# 42               Textgram - write on photos       ART_AND_DESIGN     4.4
# 52            Used Cars and Trucks for Sale    AUTO_AND_VEHICLES     4.6
# 67                       Ulysse Speedometer    AUTO_AND_VEHICLES     4.3
# 68                                   REPUVE    AUTO_AND_VEHICLES     3.9
# ...                                     ...                  ...     ...
# 10332  MangaToon-Good comics, Great stories               COMICS     4.4
# 10336                     Azar - Video Chat        COMMUNICATION     4.1
# 10339       Scanner App To PDF - TapScanner             BUSINESS     4.6
# 10345                               MotoGP™               SPORTS     3.9
# 10348        Wattpad - Read & Write Stories  BOOKS_AND_REFERENCE     3.9
#
#          Reviews                Size      Installs  Type Content Rating  \
# 37       36639.0  Varies with device    5,000,000+  Free       Everyone
# 42      295221.0  Varies with device   10,000,000+  Free       Everyone
# 52       17057.0  Varies with device    1,000,000+  Free       Everyone
# 67       40211.0  Varies with device    5,000,000+  Free       Everyone
# 68         356.0  Varies with device      100,000+  Free       Everyone
# ...          ...                 ...           ...   ...            ...
# 10332   199171.0  Varies with device   10,000,000+  Free           Teen
# 10336   704483.0  Varies with device  100,000,000+  Free     Mature 17+
# 10339   285941.0  Varies with device   50,000,000+  Free       Everyone
# 10345     6617.0  Varies with device    1,000,000+  Free       Everyone
# 10348  1406630.0  Varies with device  100,000,000+  Free           Teen
#
#                   Genres  Month
# 37          Art & Design    7.0
# 42          Art & Design    7.0
# 52       Auto & Vehicles    7.0
# 67       Auto & Vehicles    7.0
# 68       Auto & Vehicles    5.0
# ...                  ...    ...
# 10332             Comics    7.0
# 10336      Communication   10.0
# 10339           Business   10.0
# 10345             Sports   11.0
# 10348  Books & Reference    3.0
#
# [1363 rows x 10 columns]

# %%
df['Size'].value_counts(normalize=True)
# Out:
# 20.39551    0.131678
# 11.00000    0.018452
# 12.00000    0.018356
# 14.00000    0.017679
# 13.00000    0.017486
#               ...
# 0.15300     0.000097
# 0.93200     0.000097
# 0.55600     0.000097
# 0.62800     0.000097
# 0.87800     0.000097
# Name: Size, Length: 528, dtype: float64

# %%
# create a variable to hold a certain value
mask = df['Size'].str.startswith('V')

# %%
#replace that value with zero
df.loc[mask, 'Size'] = 0

# %%
# convert the K and M to thousands and millions using regex
df.Size = (df.Size.replace(r'[kMG]+$', '', regex=True).astype(float) * \
           df.Size.str.extract(r'[\d\.]+([kMG]+)', expand=False).fillna(1)
           .replace(['k','M', 'G'], [2**10, 2**20, 2**30]).astype(int))

# %%
#df['A'] = (df['A'] / 100).round(2)
df['Size'] = (df['Size'] / 2**20).round(3)

# %%
# df['Size'] = df['Size'].apply(lambda x: x.strip('M'))
# df['Size'] = df['Size'].apply(lambda x: x.strip('G'))

# %%
# df['Size'] = df['Size'].astype('float')

# %%
#to retain some data replace zeros with the column's avearge
mean_size = df['Size'].mean()
df['Size'] = df.Size.mask(df.Size == 0.0,mean_size)

# %%
df.head(50)
# Out:
#                                                   App           Category  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook     ART_AND_DESIGN
# 1                                 Coloring book moana     ART_AND_DESIGN
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...     ART_AND_DESIGN
# 3                               Sketch - Draw & Paint     ART_AND_DESIGN
# 4               Pixel Draw - Number Art Coloring Book     ART_AND_DESIGN
# 5                          Paper flowers instructions     ART_AND_DESIGN
# 6             Smoke Effect Photo Maker - Smoke Editor     ART_AND_DESIGN
# 7                                    Infinite Painter     ART_AND_DESIGN
# 8                                Garden Coloring Book     ART_AND_DESIGN
# 9                       Kids Paint Free - Drawing Fun     ART_AND_DESIGN
# 10                            Text on Photo - Fonteee     ART_AND_DESIGN
# 11            Name Art Photo Editor - Focus n Filters     ART_AND_DESIGN
# 12                     Tattoo Name On My Photo Editor     ART_AND_DESIGN
# 13                              Mandala Coloring Book     ART_AND_DESIGN
# 14    3D Color Pixel by Number - Sandbox Art Coloring     ART_AND_DESIGN
# 15                    Learn To Draw Kawaii Characters     ART_AND_DESIGN
# 16       Photo Designer - Write your name with shapes     ART_AND_DESIGN
# 17                           350 Diy Room Decor Ideas     ART_AND_DESIGN
# 18                      FlipaClip - Cartoon animation     ART_AND_DESIGN
# 19                                       ibis Paint X     ART_AND_DESIGN
# 20                        Logo Maker - Small Business     ART_AND_DESIGN
# 21          Boys Photo Editor - Six Pack & Men's Suit     ART_AND_DESIGN
# 22            Superheroes Wallpapers | 4K Backgrounds     ART_AND_DESIGN
# 23                             Mcqueen Coloring pages     ART_AND_DESIGN
# 24                        HD Mickey Minnie Wallpapers     ART_AND_DESIGN
# 25                         Harley Quinn wallpapers HD     ART_AND_DESIGN
# 26                      Colorfit - Drawing & Coloring     ART_AND_DESIGN
# 27                              Animated Photo Editor     ART_AND_DESIGN
# 28                              Pencil Sketch Drawing     ART_AND_DESIGN
# 29                    Easy Realistic Drawing Tutorial     ART_AND_DESIGN
# 30                     Pink Silver Bow Keyboard Theme     ART_AND_DESIGN
# 31                                  Art Drawing Ideas     ART_AND_DESIGN
# 32                          Anime Manga Coloring Book     ART_AND_DESIGN
# 33                                 Easy Origami Ideas     ART_AND_DESIGN
# 34                                    I Creative Idea     ART_AND_DESIGN
# 35                   How to draw Ladybug and Cat Noir     ART_AND_DESIGN
# 36     UNICORN - Color By Number & Pixel Art Coloring     ART_AND_DESIGN
# 37                                 Floor Plan Creator     ART_AND_DESIGN
# 38                     PIP Camera - PIP Collage Maker     ART_AND_DESIGN
# 39      How To Color Disney Princess - Coloring Pages     ART_AND_DESIGN
# 40                      Drawing Clothes Fashion Ideas     ART_AND_DESIGN
# 41                       Sad Poetry Photo Frames 2018     ART_AND_DESIGN
# 42                         Textgram - write on photos     ART_AND_DESIGN
# 43                                      Paint Splash!     ART_AND_DESIGN
# 44        Popsicle Sticks and Similar DIY Craft Ideas     ART_AND_DESIGN
# 45  Canva: Poster, banner, card maker & graphic de...     ART_AND_DESIGN
# 46  Install images with music to make video withou...     ART_AND_DESIGN
# 47              Little Teddy Bear Colouring Book Game     ART_AND_DESIGN
# 48                                   How To Draw Food     ART_AND_DESIGN
# 49                        Monster Truck Stunt 3D 2019  AUTO_AND_VEHICLES
#
#       Rating   Reviews      Size     Installs  Type Content Rating  \
# 0   4.100000     159.0  19.00000      10,000+  Free       Everyone
# 1   3.900000     967.0  14.00000     500,000+  Free       Everyone
# 2   4.700000   87510.0   8.70000   5,000,000+  Free       Everyone
# 3   4.500000  215644.0  25.00000  50,000,000+  Free           Teen
# 4   4.300000     967.0   2.80000     100,000+  Free       Everyone
# 5   4.400000     167.0   5.60000      50,000+  Free       Everyone
# 6   3.800000     178.0  19.00000      50,000+  Free       Everyone
# 7   4.100000   36815.0  29.00000   1,000,000+  Free       Everyone
# 8   4.400000   13791.0  33.00000   1,000,000+  Free       Everyone
# 9   4.700000     121.0   3.10000      10,000+  Free       Everyone
# 10  4.400000   13880.0  28.00000   1,000,000+  Free       Everyone
# 11  4.400000    8788.0  12.00000   1,000,000+  Free       Everyone
# 12  4.200000   44829.0  20.00000  10,000,000+  Free           Teen
# 13  4.600000    4326.0  21.00000     100,000+  Free       Everyone
# 14  4.400000    1518.0  37.00000     100,000+  Free       Everyone
# 15  3.200000      55.0   2.70000       5,000+  Free       Everyone
# 16  4.700000    3632.0   5.50000     500,000+  Free       Everyone
# 17  4.500000      27.0  17.00000      10,000+  Free       Everyone
# 18  4.300000  194216.0  39.00000   5,000,000+  Free       Everyone
# 19  4.600000  224399.0  31.00000  10,000,000+  Free       Everyone
# 20  4.000000     450.0  14.00000     100,000+  Free       Everyone
# 21  4.100000     654.0  12.00000     100,000+  Free       Everyone
# 22  4.700000    7699.0   4.20000     500,000+  Free   Everyone 10+
# 23  4.172966      61.0   7.00000     100,000+  Free       Everyone
# 24  4.700000     118.0  23.00000      50,000+  Free       Everyone
# 25  4.800000     192.0   6.00000      10,000+  Free       Everyone
# 26  4.700000   20260.0  25.00000     500,000+  Free       Everyone
# 27  4.100000     203.0   6.10000     100,000+  Free       Everyone
# 28  3.900000     136.0   4.60000      10,000+  Free       Everyone
# 29  4.100000     223.0   4.20000     100,000+  Free       Everyone
# 30  4.200000    1120.0   9.20000     100,000+  Free       Everyone
# 31  4.100000     227.0   5.20000      50,000+  Free       Everyone
# 32  4.500000    5035.0  11.00000     100,000+  Free       Everyone
# 33  4.200000    1015.0  11.00000     100,000+  Free       Everyone
# 34  4.700000     353.0   4.20000      10,000+  Free           Teen
# 35  3.800000     564.0   9.20000     100,000+  Free       Everyone
# 36  4.700000    8145.0  24.00000     500,000+  Free       Everyone
# 37  4.100000   36639.0  20.39551   5,000,000+  Free       Everyone
# 38  4.700000     158.0  11.00000      10,000+  Free       Everyone
# 39  4.000000     591.0   9.40000     500,000+  Free       Everyone
# 40  4.200000     117.0  15.00000      10,000+  Free       Everyone
# 41  4.500000     176.0  10.00000     100,000+  Free       Everyone
# 42  4.400000  295221.0  20.39551  10,000,000+  Free       Everyone
# 43  3.800000    2206.0   1.20000     100,000+  Free       Everyone
# 44  4.200000      26.0  12.00000      10,000+  Free       Everyone
# 45  4.700000  174531.0  24.00000  10,000,000+  Free       Everyone
# 46  4.600000    1070.0  26.00000     100,000+  Free       Everyone
# 47  4.200000      85.0   8.00000     100,000+  Free       Everyone
# 48  4.300000     845.0   7.90000     100,000+  Free       Everyone
# 49  4.200000     367.0  25.00000     100,000+  Free       Everyone
#
#                              Genres  Month
# 0                      Art & Design    1.0
# 1         Art & Design;Pretend Play    1.0
# 2                      Art & Design    8.0
# 3                      Art & Design    6.0
# 4           Art & Design;Creativity    6.0
# 5                      Art & Design    3.0
# 6                      Art & Design    4.0
# 7                      Art & Design    6.0
# 8                      Art & Design    9.0
# 9           Art & Design;Creativity    7.0
# 10                     Art & Design   10.0
# 11                     Art & Design    7.0
# 12                     Art & Design    4.0
# 13                     Art & Design    6.0
# 14                     Art & Design    8.0
# 15                     Art & Design    6.0
# 16                     Art & Design    7.0
# 17                     Art & Design   11.0
# 18                     Art & Design    8.0
# 19                     Art & Design    7.0
# 20                     Art & Design    4.0
# 21                     Art & Design    3.0
# 22                     Art & Design    7.0
# 23  Art & Design;Action & Adventure    3.0
# 24                     Art & Design    7.0
# 25                     Art & Design    4.0
# 26          Art & Design;Creativity   10.0
# 27                     Art & Design    3.0
# 28                     Art & Design    7.0
# 29                     Art & Design    8.0
# 30                     Art & Design    7.0
# 31                     Art & Design    5.0
# 32                     Art & Design    7.0
# 33                     Art & Design    1.0
# 34                     Art & Design    4.0
# 35                     Art & Design    7.0
# 36          Art & Design;Creativity    8.0
# 37                     Art & Design    7.0
# 38                     Art & Design   11.0
# 39                     Art & Design    3.0
# 40                     Art & Design    7.0
# 41                     Art & Design    4.0
# 42                     Art & Design    7.0
# 43          Art & Design;Creativity    4.0
# 44                     Art & Design    1.0
# 45                     Art & Design    7.0
# 46                     Art & Design   11.0
# 47                     Art & Design   12.0
# 48                     Art & Design    5.0
# 49                  Auto & Vehicles    5.0

# %% [markdown]
# ## Installs

# %%
# remove the + sign from columns
df['Installs'] = df['Installs'].str.replace('+','').str.replace(',','')

# %%
df['Installs'] = pd.to_numeric(df['Installs'])

# %% [markdown]
# ## Free Apps

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10351 entries, 0 to 10350
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10351 non-null  object
#  1   Category        10351 non-null  object
#  2   Rating          10351 non-null  float64
#  3   Reviews         10351 non-null  float64
#  4   Size            10351 non-null  float64
#  5   Installs        10351 non-null  int64
#  6   Type            10351 non-null  object
#  7   Content Rating  10351 non-null  object
#  8   Genres          10351 non-null  object
#  9   Month           10351 non-null  float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 808.8+ KB

# %%
df.Type.value_counts(normalize=True)
# Out:
# Free    0.893827
# Paid    0.106173
# Name: Type, dtype: float64

# %%
df['is_free'] = df['Type'].map(lambda x: 1 if x == 'Free' else 0)

# %%
# df['Price'] = df['Price'].apply(lambda x : str(x).strip('$')).astype(float)
# df['Price'] = df['Price'].round()

# %%
# from sklearn import preprocessing
# def labelencode(col, df):
#     le = preprocessing.LabelEncoder()
#     df[col] = le.fit_transform(df[col])

# %%
# le = preprocessing.LabelEncoder()
# df['Content Rating'] = le.fit_transform(df['Content Rating'])

# le = preprocessing.LabelEncoder()
# df['Genres'] = le.fit_transform(df['Genres'])

# %%
main_df = df.copy()

# %%
main_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size  Installs  Type Content Rating                     Genres  \
# 0     159.0  19.0     10000  Free       Everyone               Art & Design
# 1     967.0  14.0    500000  Free       Everyone  Art & Design;Pretend Play
# 2   87510.0   8.7   5000000  Free       Everyone               Art & Design
# 3  215644.0  25.0  50000000  Free           Teen               Art & Design
# 4     967.0   2.8    100000  Free       Everyone    Art & Design;Creativity
#
#    Month  is_free
# 0    1.0        1
# 1    1.0        1
# 2    8.0        1
# 3    6.0        1
# 4    6.0        1

# %%
main_df = main_df.drop('Type', axis=1)

# %% [markdown]
# # Cleaned Data

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10351 entries, 0 to 10350
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10351 non-null  object
#  1   Category        10351 non-null  object
#  2   Rating          10351 non-null  float64
#  3   Reviews         10351 non-null  float64
#  4   Size            10351 non-null  float64
#  5   Installs        10351 non-null  int64
#  6   Content Rating  10351 non-null  object
#  7   Genres          10351 non-null  object
#  8   Month           10351 non-null  float64
#  9   is_free         10351 non-null  int64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 808.8+ KB

# %%
main_df.to_csv('cleaned_data.csv')
