# %%
import pandas as pd
pd.set_option('display.max_columns', 50)

# %%
first_20 = pd.read_csv('data/app_info.csv')
top_196 = pd.read_csv('data/top_196_grossing.csv')
top_paid = pd.read_csv('data/top_paid_games.csv')
grossing_games = pd.read_csv('data/grossing_apps.csv')

# %%
files = [first_20, top_196, top_paid, grossing_games]

# %%
df = pd.concat(files)

# %%
df
# Out:
#                                                  title  \
# 0                                            Jelly Dye
# 1                                          Solar Smash
# 2                                           Comics Bob
# 3                          Draw Puzzle - Draw one part
# 4                                             Among Us
# ..                                                 ...
# 351               Mathway: Scan Photos, Solve Problems
# 352     Avast Antivirus – Scan & Remove Virus, Cleaner
# 353                     Wattpad - Read & Write Stories
# 354    MotorTrend: Stream Roadkill, Top Gear, and more
# 355  FitOn - Free Fitness Workouts & Personalized P...
#
#                                            description  \
# 0    Inject Color Dyes into Jellies. Enjoy the Perf...
# 1    Solar Smash is a planet destruction simulator,...
# 2    🗿 <b> Comics Bob – Mind-bending puzzles and cl...
# 3    Do you know how to draw things? Do you know ho...
# ...

# %%
df = df.round({'score': 1})

# %%
df[df['title'] == 'Wattpad - Read & Write Stories']
# Out:
#                               title  \
# 353  Wattpad - Read & Write Stories
#
#                                            description  \
# 353  <b> Wattpad. Where stories live. </b>\r\n\r\n<...
#
#                                        descriptionHTML  \
# 353  <b> Wattpad. Where stories live. </b><br><br><...
#
#                                                summary  \
# 353  Wattpad - A Story Reading App, Read Stories, N...
#
#                                            summaryHTML      installs  \
# 353  Wattpad - A Story Reading App, Read Stories, N...  100,000,000+
#
#      minInstalls  score    ratings    reviews  \
# 353    100000000    3.9  4143181.0  1406630.0
#
#                                      histogram  price  free currency   sale  \
# 353  [699369, 218256, 309322, 447969, 2468265]    0.0  True      USD  False
#
#      saleTime  originalPrice saleText  offersIAP        inAppProductPrice  \
# ...

# %%
df.at[353,"released"]="Mar 31, 2021"

# %%
def bool_to_word(bool):
    if bool == True:
        return 'Free'
    else:
        return "Paid"

# %%
df['free'] = df['free'].apply(lambda x: bool_to_word(x))

# %%
df = df[['title', 'installs', 'score', 'reviews', 'price', 'size', 'genre', 'genreId', 'contentRating', 'released', 
         'version', 'androidVersionText', 'free']].reset_index(drop=True)

# %%
df.rename(columns={'title': 'App', 'installs': 'Installs', 'score':'Rating', 'reviews': 'Reviews', 'price':'Price', 
                  'contentRating':'Content Rating', 'released':'Last Updated', 'version':'Current Ver', 
                   'androidVersionText':'Android Ver', 'size':'Size', 'genre':'Genres', 'genreId':'Category',
                  'free':'Type'}, inplace=True)

# %%
df['Last Updated'] = pd.to_datetime(df['Last Updated'], format="%b %d, %Y", errors='coerce')

# %%
df.head()
# Out:
#                            App      Installs  Rating    Reviews  Price  \
# 0                    Jelly Dye    1,000,000+     4.2     3010.0    0.0
# 1                  Solar Smash   10,000,000+     4.6    99185.0    0.0
# 2                   Comics Bob    5,000,000+     3.8    10227.0    0.0
# 3  Draw Puzzle - Draw one part    5,000,000+     4.3     8889.0    0.0
# 4                     Among Us  100,000,000+     3.8  5620232.0    0.0
#
#                  Size      Genres         Category Content Rating  \
# 0  Varies with device  Simulation  GAME_SIMULATION       Everyone
# 1                 83M  Simulation  GAME_SIMULATION   Everyone 10+
# 2                 81M      Puzzle      GAME_PUZZLE           Teen
# 3                 47M      Puzzle      GAME_PUZZLE       Everyone
# 4                102M      Action      GAME_ACTION   Everyone 10+
#
#   Last Updated Current Ver  Android Ver  Type
# 0   2021-02-04        1.49   5.0 and up  Free
# 1   2020-01-19       1.4.1  4.4W and up  Free
# ...

# %%
df['Date'] = pd.to_datetime(df['Last Updated'])
release_month = df['Last Updated'].dt.month
df['Month'] = release_month

# %%
df
# Out:
#                                                    App      Installs  Rating  \
# 0                                            Jelly Dye    1,000,000+     4.2
# 1                                          Solar Smash   10,000,000+     4.6
# 2                                           Comics Bob    5,000,000+     3.8
# 3                          Draw Puzzle - Draw one part    5,000,000+     4.3
# 4                                             Among Us  100,000,000+     3.8
# ..                                                 ...           ...     ...
# 822               Mathway: Scan Photos, Solve Problems   10,000,000+     4.6
# 823     Avast Antivirus – Scan & Remove Virus, Cleaner  100,000,000+     4.7
# 824                     Wattpad - Read & Write Stories  100,000,000+     3.9
# 825    MotorTrend: Stream Roadkill, Top Gear, and more    1,000,000+     4.4
# 826  FitOn - Free Fitness Workouts & Personalized P...    1,000,000+     4.7
#
# ...

# %%
df.to_csv('new_app_data.csv', index=None, header=True)
